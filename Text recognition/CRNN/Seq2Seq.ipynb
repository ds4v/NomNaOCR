# %%
# https://github.com/bai-shang/crnn_seq2seq_ocr_pytorch
# https://github.com/chenjun2hao/Attention_ocr.pytorch
# https://github.com/alleveenstra/attentionocr
# https://github.com/koibiki/CRNN-ATTENTION
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'Seq2Seq'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../../Dataset/IHR-NomDB'
LABELS_PATH = r'../../Dataset/IHR-NomDB/labels.txt'
FONT_PATH = r'../../Dataset/NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, LABELS_PATH, min_length=1).remove_rare_chars(1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 101533
# - Number of labels found: 101533
# - Number of unique characters: 13168
# - Characters present: {'之': 8193, '以': 4931, '月': 4007, '人': 3927, '十': 3611, '年': 3381, '不': 3263, '帝': 2955, '二': 2722, '大': 2641, '有': 2634, '日': 2561, '為': 2548, '其': 2537, '公': 2476, '兵': 2469, '等': 2404, '固': 2381, '於': 2311, '如': 2252, '國': 2194, '時': 2171, '官': 2160, '太': 2153, '爲': 2142, '子': 2140, '一': 2136, '天': 2077, '王': 2061, '軍': 2052, '而': 2019, '三': 1981, '事': 1955, '吏': 1942, '明': 1910, '朱': 1880, '使': 1825, '阮': 1818, '至': 1808, '曰': 1791, '及': 1646, '者': 1638, '文': 1631, '㐌': 1617, '安': 1612, '臣': 1601, '所': 1600, '行': 1569, '埃': 1563, '黎': 1511, '麻': 1494, '上': 1485, '皇': 1469, '也': 1469, '士': 1462, '命': 1444, '民': 1424, '是': 1418, '中': 1409, '自': 1407, '𢚸': 1387, '四': 1354, '五': 1346, '生': 1333, '道': 1331, '爫': 1319, '下': 1293, '郡': 1249, '元': 1243, '山': 1214, '渃': 1201, '𠊛': 1192, '宗': 1174, '莫': 1173, '武': 1169, '南': 1167, '于': 1165, '将': 1153, '春': 1144, '外': 1138, '城': 1136, '都': 1131, '書': 1131, '名': 1127, '花': 1122, '各': 1116, '朝': 1115, '六': 1113, '拱': 1107, '進': 1096, '得': 1091, '群': 1073, '州': 1062, '尼': 1057, '拯': 1055, '制': 1038, '意': 1036, '無': 1032, '正': 1030, '世': 1027, '令': 1026, '特': 1016, '鄭': 1013, '平': 1012, '仍': 1012, '買': 1004, '𡗶': 1001, '諸': 995, '\U000f047c': 972, '入': 966, '分': 955, '部': 955, '侯': 953, '辰': 950, '出': 945, '浪': 940, '知': 936, '乃': 932, '同': 928, '清': 924, '頭': 920, '内': 920, '陳': 919, '共': 913, '後': 904, '師': 896, '遣': 892, '空': 887, '史': 885, '昆': 885, '八': 882, '情': 880, '身': 879, '七': 874, '可': 872, '德': 869, '府': 866, '本': 843, '方': 839, '功': 835, '東': 829, '定': 824, '欺': 824, '些': 819, '江': 813, '初': 807, '𡥵': 802, '羅': 795, '賊': 794, '蒸': 794, '𥙩': 792, '女': 791, '㗂': 787, '立': 782, '在': 781, '長': 781, '𠫾': 780, '家': 772, '先': 766, '茹': 757, '秋': 757, '\U000f0179': 754, '百': 752, '故': 751, '庄': 749, '蔑': 747, '咹': 745, '守': 741, '主': 739, '西': 736, '丐': 736, '御': 735, '司': 733, '渚': 733, '用': 732, '又': 732, '九': 729, '節': 725, '水': 721, '門': 716, '縣': 715, '𠄩': 712, '典': 712, '禮': 712, '英': 709, '則': 707, '相': 706, '饒': 703, '𧗱': 699, '來': 693, '沛': 690, '從': 690, '𣈜': 685, '娘': 685, '衛': 676, '咍': 675, '未': 674, '𢧚': 669, '政': 667, '興': 663, '地': 657, '底': 653, '前': 652, '聖': 652, '見': 649, '路': 645, '京': 645, '船': 644, '與': 643, '多': 643, '保': 639, '卒': 637, '今': 632, '北': 632, '光': 632, '左': 631, '海': 630, '化': 627, '重': 627, '詔': 627, '萬': 625, '連': 620, '丕': 619, '餘': 619, '仁': 619, '罪': 617, '此': 616, '領': 611, '督': 610, '碎': 605, '皆': 604, '言': 603, '宋': 602, '復': 602, '林': 602, '鐄': 602, '𫽄': 601, '几': 599, '賜': 596, '香': 596, '金': 595, '處': 594, '封': 594, '心': 592, '奏': 592, '牢': 586, '𦋦': 584, '黄': 579, '冬': 579, '當': 578, '我': 577, '𢬣': 576, '殿': 575, '㝵': 574, '別': 574, '郎': 572, '皮': 571, '\U000f070b': 571, '神': 570, '然': 567, '侍': 567, '玉': 560, '位': 559, '塘': 559, '永': 558, '義': 558, '差': 556, '箕': 549, '𧡊': 547, '呐': 543, '占': 543, '𦝄': 543, '隊': 542, '親': 541, '法': 541, '治': 540, '君': 539, '營': 538, '死': 533, '強': 532, '常': 530, '翁': 528, '奉': 525, '𠬠': 519, '馬': 519, '還': 519, '夫': 512, '除': 503, '𨕭': 503, '陽': 503, '少': 502, '通': 502, '成': 498, '坤': 498, '會': 496, '每': 496, '敬': 496, '后': 492, '𠳒': 492, '和': 489, '吳': 489, '夏': 489, '福': 489, '回': 487, '油': 486, '才': 486, '即': 485, '没': 485, '𠓨': 483, '奴': 483, '杜': 482, '𫥨': 479, '調': 475, '順': 475, '鎮': 473, '作': 472, '襖': 467, '𦖑': 467, '何': 466, '矣': 463, '經': 463, '包': 463, '𠊚': 462, '風': 462, '右': 461, '宜': 461, '停': 460, '將': 458, '監': 454, '𠀧': 454, '試': 453, '戈': 447, '因': 445, '宫': 443, '台': 443, '旦': 442, '户': 442, '率': 441, '默': 441, '払': 441, '𡽫': 441, '李': 440, '奇': 439, '丁': 438, '院': 436, '廷': 434, '亦': 433, '祖': 433, '居': 433, '計': 432, '柴': 432, '范': 431, '漢': 430, '体': 430, '能': 429, '庒': 428, '眾': 428, '改': 427, '土': 426, '傳': 425, '信': 424, '排': 424, '職': 423, '或': 423, '忠': 421, '古': 420, '龍': 419, '坦': 419, '氏': 418, '唐': 416, '高': 415, '象': 414, '廣': 413, '傷': 412, '殺': 411, '小': 409, '滝': 408, '撑': 407, '景': 404, '朋': 404, '並': 404, '吝': 404, '過': 399, '尋': 399, '恩' ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 8),
    font_path = FONT_PATH, 
    text_x = WIDTH + 3
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import (
    Input, Embedding, Dense, GRU, Average, 
    Bidirectional, Concatenate, Flatten
)
from layers import custom_cnn, reshape_features, BahdanauAttention
EMBEDDING_DIM = 512
UNITS = 256

# %% [markdown]
# ## The encoder

# %%
def Encoder(imagenet_model=None, imagenet_output_layer=None, name='Encoder'):
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 
            
            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)

    # Reshape accordingly before passing output to RNN
    feature_maps = reshape_features(x, dim_to_keep=1, name='rnn_input')
    
    # RNN layers
    bigru1, forward_state, backward_state = Bidirectional(GRU(
        units = UNITS, 
        return_sequences = True,
        return_state = True
    ), name = 'bigru1')(feature_maps)
    
    bigru2, forward_state, backward_state = Bidirectional(GRU(
        units = UNITS, 
        return_sequences = True,
        return_state = True
    ), name = 'bigru2')(bigru1, initial_state=[forward_state, backward_state])
    
    # Skip connection and concat states of 2 directions
    x = Average(name='skip_connection')([feature_maps, bigru2])
    final_state = Concatenate(name='encoder_state')([forward_state, backward_state])
    return tf.keras.Model(inputs=image_input, outputs=[x, final_state], name=name)

# %% [markdown]
# ## The decoder

# %%
def Decoder(enc_seq_shape, name='Decoder'):
    token_input = Input(shape=(1,), name='new_token')
    enc_seq_input = Input(shape=enc_seq_shape, name='encoder_sequence')
    
    # In encoder we used Bidirectional so we have to take double UNITS  
    # for single decoder GRU using encoder's final state as initial state
    dec_units = UNITS * 2
    pre_hidden_input = Input(shape=(dec_units,), name='previous_state')
    
    # Defining attention as a separate model
    attention = BahdanauAttention(dec_units)
    context_vector, attention_weights = attention(enc_seq_input, pre_hidden_input)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = Concatenate(axis=-1, name='context_and_embedding')([
        tf.expand_dims(context_vector, 1), 
        Embedding(VOCAB_SIZE, EMBEDDING_DIM)(token_input)
    ])
    
    # Passing the concatenated vector to the GRU
    rnn_output, state = GRU(
        units = dec_units, 
        return_state = True, 
        return_sequences = True,
    )(x, initial_state=pre_hidden_input)

    # Generate predictions
    x = Flatten()(rnn_output)
    y_pred = Dense(VOCAB_SIZE, name='prediction')(x)

    return tf.keras.Model(
        inputs = [token_input, enc_seq_input, pre_hidden_input], 
        outputs = [y_pred, state, attention_weights],
        name = name
    )

# %% [markdown]
# # Build the model

# %%
from models import get_imagenet_model, EncoderDecoderModel
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 1))
# imagenet_output_layer = 'block4_pool'
# imagenet_model.summary(line_length=100)

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
model = EncoderDecoderModel(encoder, decoder, data_handler)

# %%
encoder.summary(line_length=120)
print()
decoder.summary(line_length=125)
# Out:
# Model: "Encoder"
# ________________________________________________________________________________________________________________________
#  Layer (type)                          Output Shape               Param #       Connected to
# ========================================================================================================================
#  image (InputLayer)                    [(None, 432, 48, 3)]       0             []
#
#  block1_conv1 (Conv2D)                 (None, 432, 48, 64)        1792          ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)       (None, 432, 48, 64)        256           ['block1_conv1[0][0]']
#
#  block1_relu1 (Activation)             (None, 432, 48, 64)        0             ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)            (None, 216, 24, 64)        0             ['block1_relu1[0][0]']
#
#  block2_conv1 (Conv2D)                 (None, 216, 24, 128)       73856         ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)       (None, 216, 24, 128)       512           ['block2_conv1[0][0]']
#
#  block2_relu1 (Activation)             (None, 216, 24, 128)       0             ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)            (None, 108, 12, 128)       0             ['block2_relu1[0][0]']
#
#  block3_conv1 (Conv2D)                 (None, 108, 12, 256)       295168        ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv1[0][0]']
#
#  block3_relu1 (Activation)             (None, 108, 12, 256)       0             ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)                 (None, 108, 12, 256)       590080        ['block3_relu1[0][0]']
#
#  block3_bn2 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv2[0][0]']
#
#  block3_relu2 (Activation)             (None, 108, 12, 256)       0             ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)            (None, 54, 6, 256)         0             ['block3_relu2[0][0]']
#
#  block4_conv1 (Conv2D)                 (None, 54, 6, 512)         1180160       ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv1[0][0]']
#
#  block4_relu1 (Activation)             (None, 54, 6, 512)         0             ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)                 (None, 54, 6, 512)         2359808       ['block4_relu1[0][0]']
#
#  block4_bn2 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv2[0][0]']
#
#  block4_relu2 (Activation)             (None, 54, 6, 512)         0             ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)            (None, 27, 3, 512)         0             ['block4_relu2[0][0]']
#
#  block5_conv1 (Conv2D)                 (None, 26, 2, 512)         1049088       ['block4_pool[0][0]']
#
#  block5_bn1 (BatchNormalization)       (None, 26, 2, 512)         2048          ['block5_conv1[0][0]']
#
#  block5_relu1 (Activation)             (None, 26, 2, 512)         0             ['block5_bn1[0][0]']
#
#  block5_conv2 (Conv2D)                 (None, 25, 1, 512)         1049088       ['block5_relu1[0][0]']
#
#  block5_bn2 (BatchNormalization)       (None, 25, 1, 512)         2048          ['block5_conv2[0][0]']
#
#  block5_relu2 (Activation)             (None, 25, 1, 512)         0             ['block5_bn2[0][0]']
#
#  rnn_input (Reshape)                   (None, 25, 512)            0             ['block5_relu2[0][0]']
#
#  bigru1 (Bidirectional)                [(None, 25, 512),          1182720       ['rnn_input[0][0]']
#                                         (None, 256),
#                                         (None, 256)]
#
#  bigru2 (Bidirectional)                [(None, 25, 512),          1182720       ['bigru1[0][0]',
#                                         (None, 256),                             'bigru1[0][1]',
#                                         (None, 256)]                             'bigru1[0][2]']
#
#  skip_connection (Average)             (None, 25, 512)            0             ['rnn_input[0][0]',
#                                                                                  'bigru2[0][0]']
#
#  encoder_state (Concatenate)           (None, 512)                0             ['bigru2[0][1]',
#                                                                                  'bigru2[0][2]']
#
# ========================================================================================================================
# Total params: 8,975,488
# Trainable params: 8,969,984
# Non-trainable params: 5,504
# ________________________________________________________________________________________________________________________
#
# Model: "Decoder"
# _____________________________________________________________________________________________________________________________
#  Layer (type)                            Output Shape               Param #        Connected to
# =============================================================================================================================
#  encoder_sequence (InputLayer)           [(None, 25, 512)]          0              []
#
#  previous_state (InputLayer)             [(None, 512)]              0              []
#
#  BahdanauAttention (BahdanauAttention)   ((None, 512),              525825         ['encoder_sequence[0][0]',
#                                           (None, 25, 1))                            'previous_state[0][0]']
#
#  new_token (InputLayer)                  [(None, 1)]                0              []
#
#  tf.expand_dims (TFOpLambda)             (None, 1, 512)             0              ['BahdanauAttention[0][0]']
#
#  embedding (Embedding)                   (None, 1, 512)             6744064        ['new_token[0][0]']
#
#  context_and_embedding (Concatenate)     (None, 1, 1024)            0              ['tf.expand_dims[0][0]',
#                                                                                     'embedding[0][0]']
#
#  gru_2 (GRU)                             [(None, 1, 512),           2362368        ['context_and_embedding[0][0]',
#                                           (None, 512)]                              'previous_state[0][0]']
#
#  flatten (Flatten)                       (None, 512)                0              ['gru_2[0][0]']
#
#  prediction (Dense)                      (None, 13172)              6757236        ['flatten[0][0]']
#
# =============================================================================================================================
# Total params: 16,389,493
# Trainable params: 16,389,493
# Non-trainable params: 0
# _____________________________________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(int(dataset.size * 0.8)))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 81226
# Number of validate samples: 20307

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)
random.shuffle(valid_idxs)

# %%
# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(
    train_idxs, BATCH_SIZE, drop_remainder=True 
)
valid_tf_dataset = data_handler.prepare_tf_dataset(
    valid_idxs, BATCH_SIZE, drop_remainder=True
)

# %% [markdown]
# ## Callbacks

# %%
from callbacks import EarlyStoppingWithStuck
from tensorflow.keras.callbacks import ReduceLROnPlateau
early_stopping_callback = EarlyStoppingWithStuck(patience=5)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Train the IHR-NomDB dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [reduce_lr_callback, early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 399s 151ms/step - loss: 4.4868 - seq_acc: 2.4626e-05 - char_acc: 0.1654 - lev_distance: 0.7479 - val_loss: 4.9528 - val_seq_acc: 0.0000e+00 - val_char_acc: 0.1505 - val_lev_distance: 0.8074 - lr: 2.0000e-04
# Epoch 2/100
# 2538/2538 [==============================] - 369s 145ms/step - loss: 3.5923 - seq_acc: 8.3727e-04 - char_acc: 0.2702 - lev_distance: 0.7069 - val_loss: 2.9379 - val_seq_acc: 4.9290e-05 - val_char_acc: 0.3437 - val_lev_distance: 0.6364 - lr: 2.0000e-04
# Epoch 3/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 2.2775 - seq_acc: 0.0139 - char_acc: 0.4578 - lev_distance: 0.5250 - val_loss: 1.6627 - val_seq_acc: 0.0194 - val_char_acc: 0.6057 - val_lev_distance: 0.3839 - lr: 2.0000e-04
# Epoch 4/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 1.4098 - seq_acc: 0.0778 - char_acc: 0.6467 - lev_distance: 0.3429 - val_loss: 1.2063 - val_seq_acc: 0.0681 - val_char_acc: 0.7024 - val_lev_distance: 0.2705 - lr: 2.0000e-04
# Epoch 5/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.8528 - seq_acc: 0.2141 - char_acc: 0.7815 - lev_distance: 0.2133 - val_loss: 1.1028 - val_seq_acc: 0.1842 - val_char_acc: 0.8102 - val_lev_distance: 0.1781 - lr: 2.0000e-04
# Epoch 6/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.5693 - seq_acc: 0.3542 - char_acc: 0.8526 - lev_distance: 0.1444 - val_loss: 0.6393 - val_seq_acc: 0.2452 - val_char_acc: 0.8340 - val_lev_distance: 0.1496 - lr: 2.0000e-04
# Epoch 7/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.6119 - seq_acc: 0.3860 - char_acc: 0.8446 - lev_distance: 0.1479 - val_loss: 1.0379 - val_seq_acc: 0.1375 - val_char_acc: 0.7488 - val_lev_distance: 0.2054 - lr: 2.0000e-04
# Epoch 8/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.3182 - seq_acc: 0.5560 - char_acc: 0.9169 - lev_distance: 0.0817 - val_loss: 0.2926 - val_seq_acc: 0.4577 - val_char_acc: 0.9030 - val_lev_distance: 0.0821 - lr: 2.0000e-04
# Epoch 9/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.3099 - seq_acc: 0.5876 - char_acc: 0.9172 - lev_distance: 0.0799 - val_loss: 0.3996 - val_seq_acc: 0.4531 - val_char_acc: 0.8994 - val_lev_distance: 0.0865 - lr: 2.0000e-04
# Epoch 10/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.1925 - seq_acc: 0.7105 - char_acc: 0.9506 - lev_distance: 0.0485
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.1925 - seq_acc: 0.7105 - char_acc: 0.9506 - lev_distance: 0.0485 - val_loss: 0.3834 - val_seq_acc: 0.4420 - val_char_acc: 0.8913 - val_lev_distance: 0.0872 - lr: 2.0000e-04
# Epoch 11/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.2116 - seq_acc: 0.7298 - char_acc: 0.9511 - lev_distance: 0.0464 - val_loss: 0.4261 - val_seq_acc: 0.5010 - val_char_acc: 0.9064 - val_lev_distance: 0.0748 - lr: 1.0000e-04
# Epoch 12/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.1033 - seq_acc: 0.8528 - char_acc: 0.9779 - lev_distance: 0.0218 - val_loss: 0.2544 - val_seq_acc: 0.5883 - val_char_acc: 0.9383 - val_lev_distance: 0.0557 - lr: 1.0000e-04
# Epoch 13/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0894 - seq_acc: 0.8824 - char_acc: 0.9821 - lev_distance: 0.0172 - val_loss: 0.2083 - val_seq_acc: 0.6398 - val_char_acc: 0.9481 - val_lev_distance: 0.0477 - lr: 1.0000e-04
# Epoch 14/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0722 - seq_acc: 0.9110 - char_acc: 0.9868 - lev_distance: 0.0127 - val_loss: 0.3498 - val_seq_acc: 0.5792 - val_char_acc: 0.9291 - val_lev_distance: 0.0585 - lr: 1.0000e-04
# Epoch 15/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0461 - seq_acc: 0.9516 - char_acc: 0.9933 - lev_distance: 0.0064
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0461 - seq_acc: 0.9516 - char_acc: 0.9933 - lev_distance: 0.0064 - val_loss: 0.2513 - val_seq_acc: 0.6219 - val_char_acc: 0.9445 - val_lev_distance: 0.0495 - lr: 1.0000e-04
# Epoch 16/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0334 - seq_acc: 0.9754 - char_acc: 0.9966 - lev_distance: 0.0032 - val_loss: 0.2222 - val_seq_acc: 0.5843 - val_char_acc: 0.9234 - val_lev_distance: 0.0572 - lr: 5.0000e-05
# Epoch 17/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0296 - seq_acc: 0.9789 - char_acc: 0.9971 - lev_distance: 0.0027 - val_loss: 0.1947 - val_seq_acc: 0.6828 - val_char_acc: 0.9572 - val_lev_distance: 0.0394 - lr: 5.0000e-05
# Epoch 18/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0195 - seq_acc: 0.9912 - char_acc: 0.9988 - lev_distance: 0.0011 - val_loss: 0.1900 - val_seq_acc: 0.6781 - val_char_acc: 0.9542 - val_lev_distance: 0.0401 - lr: 5.0000e-05
# Epoch 19/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0177 - seq_acc: 0.9927 - char_acc: 0.9990 - lev_distance: 8.9639e-04 - val_loss: 0.1835 - val_seq_acc: 0.7243 - val_char_acc: 0.9658 - val_lev_distance: 0.0333 - lr: 5.0000e-05
# Epoch 20/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0126 - seq_acc: 0.9966 - char_acc: 0.9995 - lev_distance: 4.1711e-04 - val_loss: 0.1943 - val_seq_acc: 0.7302 - val_char_acc: 0.9663 - val_lev_distance: 0.0325 - lr: 5.0000e-05
# Epoch 21/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0145 - seq_acc: 0.9940 - char_acc: 0.9991 - lev_distance: 7.5055e-04
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0145 - seq_acc: 0.9940 - char_acc: 0.9991 - lev_distance: 7.5055e-04 - val_loss: 0.2017 - val_seq_acc: 0.7221 - val_char_acc: 0.9642 - val_lev_distance: 0.0336 - lr: 5.0000e-05
# Epoch 22/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0143 - seq_acc: 0.9950 - char_acc: 0.9992 - lev_distance: 6.4626e-04 - val_loss: 0.1800 - val_seq_acc: 0.7261 - val_char_acc: 0.9650 - val_lev_distance: 0.0330 - lr: 2.5000e-05
# Epoch 23/100
# 2538/2538 [==============================] - 369s 145ms/step - loss: 0.0086 - seq_acc: 0.9987 - char_acc: 0.9998 - lev_distance: 1.4955e-04 - val_loss: 0.1770 - val_seq_acc: 0.7336 - val_char_acc: 0.9663 - val_lev_distance: 0.0320 - lr: 2.5000e-05
# Epoch 24/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0095 - seq_acc: 0.9982 - char_acc: 0.9997 - lev_distance: 2.2488e-04 - val_loss: 0.1834 - val_seq_acc: 0.7350 - val_char_acc: 0.9656 - val_lev_distance: 0.0321 - lr: 2.5000e-05
# Epoch 25/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0084 - seq_acc: 0.9989 - char_acc: 0.9998 - lev_distance: 1.2646e-04
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0084 - seq_acc: 0.9989 - char_acc: 0.9998 - lev_distance: 1.2646e-04 - val_loss: 0.1871 - val_seq_acc: 0.7445 - val_char_acc: 0.9685 - val_lev_distance: 0.0304 - lr: 2.5000e-05
# Epoch 26/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0062 - seq_acc: 0.9992 - char_acc: 0.9998 - lev_distance: 9.7335e-05 - val_loss: 0.1789 - val_seq_acc: 0.7423 - val_char_acc: 0.9678 - val_lev_distance: 0.0308 - lr: 1.2500e-05
# Epoch 27/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0053 - seq_acc: 0.9994 - char_acc: 0.9999 - lev_distance: 7.7981e-05
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0053 - seq_acc: 0.9994 - char_acc: 0.9999 - lev_distance: 7.7981e-05 - val_loss: 0.1770 - val_seq_acc: 0.7487 - val_char_acc: 0.9692 - val_lev_distance: 0.0298 - lr: 1.2500e-05
# Epoch 28/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0045 - seq_acc: 0.9994 - char_acc: 0.9999 - lev_distance: 6.7002e-05 - val_loss: 0.1753 - val_seq_acc: 0.7503 - val_char_acc: 0.9694 - val_lev_distance: 0.0296 - lr: 6.2500e-06
# Epoch 29/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0042 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 6.4813e-05 - val_loss: 0.1749 - val_seq_acc: 0.7496 - val_char_acc: 0.9693 - val_lev_distance: 0.0296 - lr: 6.2500e-06
# Epoch 30/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0039 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 5.9756e-05 - val_loss: 0.1745 - val_seq_acc: 0.7497 - val_char_acc: 0.9694 - val_lev_distance: 0.0295 - lr: 6.2500e-06
# Epoch 31/100
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0036 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 5.5447e-05 - val_loss: 0.1745 - val_seq_acc: 0.7503 - val_char_acc: 0.9693 - val_lev_distance: 0.0295 - lr: 6.2500e-06
# Epoch 32/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0034 - seq_acc: 0.9996 - char_acc: 0.9999 - lev_distance: 4.8900e-05
# Epoch 32: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 2538/2538 [==============================] - 368s 145ms/step - loss: 0.0034 - seq_acc: 0.9996 - char_acc: 0.9999 - lev_distance: 4.8900e-05 - val_loss: 0.1747 - val_seq_acc: 0.7511 - val_char_acc: 0.9693 - val_lev_distance: 0.0294 - lr: 6.2500e-06
# Epoch 33/100
# 2538/2538 [==============================] - 369s 145ms/step - loss: 0.0032 - seq_acc: 0.9997 - char_acc: 0.9999 - lev_distance: 4.0759e-05 - val_loss: 0.1748 - val_seq_acc: 0.7514 - val_char_acc: 0.9693 - val_lev_distance: 0.0294 - lr: 3.1250e-06
# Epoch 34/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0031 - seq_acc: 0.9997 - char_acc: 0.9999 - lev_distance: 4.0759e-05
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 2538/2538 [==============================] - 370s 146ms/step - loss: 0.0031 - seq_acc: 0.9997 - char_acc: 0.9999 - lev_distance: 4.0759e-05 - val_loss: 0.1753 - val_seq_acc: 0.7516 - val_char_acc: 0.9693 - val_lev_distance: 0.0294 - lr: 3.1250e-06
# Epoch 35/100
# 2538/2538 [==============================] - 371s 146ms/step - loss: 0.0030 - seq_acc: 0.9997 - char_acc: 0.9999 - lev_distance: 3.2126e-05 - val_loss: 0.1759 - val_seq_acc: 0.7526 - val_char_acc: 0.9694 - val_lev_distance: 0.0294 - lr: 1.5625e-06
# Early stopping and restored the model weights from the end of epoch 30 - val_loss: 0.17445878684520721
#
# CPU times: total: 4h 41min 35s
# Wall time: 3h 35min 17s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_lev_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 0.17445878684520721
# - Sequence accuracy	: 0.7497042417526245
# - Character accuracy	: 0.9693595767021179
# - Levenshtein distance	: 0.029548346996307373

# %%
from visualizer import plot_training_results
plot_training_results(history, f'{APPROACH_NAME}.png')
model.encoder.save_weights(f'{APPROACH_NAME}_encoder.h5')
model.decoder.save_weights(f'{APPROACH_NAME}_decoder.h5')

# %% [markdown]
# # Inference

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
encoder.load_weights(f'{APPROACH_NAME}_encoder.h5')
decoder.load_weights(f'{APPROACH_NAME}_decoder.h5')

# %%
reset_model = EncoderDecoderModel(encoder, decoder, data_handler)
reset_model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)
reset_model.evaluate(valid_tf_dataset)
# Out:
# 634/634 [==============================] - 50s 67ms/step - loss: 0.1602 - seq_acc: 0.7497 - char_acc: 0.9694 - lev_distance: 0.0295
# [0.7497042417526245,
#  0.9693595767021179,
#  0.029548346996307373,
#  0.17445878684520721]

# %% [markdown]
# ## On test dataset

# %%
batch_results = []
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(2)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens, attentions = reset_model.predict(batch_images, return_attention=True)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    batch_results.append({'true': labels, 'pred': pred_labels, 'attentions': attentions})
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        figsize = (14, 20),
        subplot_size = (4, 8),
        legend_loc = (3.8, 4.28),
        annotate_loc = (4, 1.8),
        font_path = FONT_PATH, 
        text_x = WIDTH + 5 # Position of actual label to plot
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '二十日詔自今凣士人', 2: '及春秋髙而理明德', 3: '事其求封辝畧日國人徧', 4: '告立皇太子并賜綵幣', 5: '是皆揭標的於當時', 6: '因以上褚五十衣中褚', 7: '如各衙門應差捕得', 8: '脩政事有所舛紊人', 9: '帝親征何洞等四十九', 10: '下令各依圖次而退', 11: '咍𢶢𦷾渚底咹\U000f12d4𣈜𬧻', 12: '賭博之術不足以施', 13: '不能\U000f0c46\U000f0c47教士卒甚銳', 14: '命朝臣舉縣官聀有', 15: '至是令人排辨香花', 16: '及長容貌環偉聰明過', 17: '六月色旨禮部議定民', 18: '黎志兵部上書定功伯', 19: '冬十月詔傳位於皇太子', 20: '文武臣僚見者流涕', 21: '恩州阮啟使其子來行', 22: '長子昔以正位東宫', 23: '詔諸軍民不得服北人', 24: '上曰爾子幾人乎對', 25: '其村商賣怒廊百公', 26: '故合格黄袍者止八十', 27: '茂洽見有羙色心中悅', 28: '揮使掌衛事兼知豊祜堂', 29: '舍江至安决黔皷山駐營', 30: '後倚蘭夫人有娠生皇子', 31: '為以妾前年又𭁈宮女阮', 32: '號有厲致眾於朋來'}
# - Pred: {1: '二十日詔自今凣士人', 2: '及春秋髙而理明德', 3: '事其求封辝畧日國人徧', 4: '告立皇太子并賜綵幣', 5: '是皆揭標的於當時', 6: '因以上褚五十有中褚', 7: '如各衙門應差捕得', 8: '脩政事有所竹紊人', 9: '帝親征何洞等四十九', 10: '下令各依圖次而退', 11: '咍𢶢𦷾渚底咹\U000f12d4𣈜𬧻', 12: '賭博之術不足以施', 13: '不能月\U000f0c47教士卒甚鋭', 14: '命朝臣舉縣官聀有', 15: '至是令人排辨香花', 16: '及長容\U000f047c環偉聰明過', 17: '六月色旨禮部議定民', 18: '黎志兵部上書定功伯', 19: '冬十月詔傳位於皇太子', 20: '文武臣僚見者流涕', 21: '恩州阮馘使其子來行', 22: '長子昔以正位東宫', 23: '詔諸軍民不得服北人', 24: '上曰爾子幾人乎對', 25: '其村商賣怒廊百公', 26: '故合格黄袍者止八十', 27: '茂洽見有羙色心中悅', 28: '揮使掌衛事兼知豊𫀅堂', 29: '舍江至安决𣈜皷山駐營', 30: '後倚蘭夫人有娠生皇子', 31: '為以妾節年又𭁈宮女阮', 32: '號有厲致眾於朋來'}
#
# Batch 02:
# - True: {1: '令旨各處鎮守係諸犯人', 2: '若評諭官宜用法公平', 3: '矛麻咹鱠渃韓爫𦧘渃趙', 4: '慶二年春正月尊寧', 5: '初四日簡脩公即皇帝位', 6: '十二月大同偽武德恭', 7: '丐哿巴欲鹤奴劍双曰', 8: '于青林沿江以守之', 9: '壽𭁈天齊年率土臣', 10: '守安定逾永福攻畧宋山', 11: '令廣德縣作紙局造作大', 12: '祺敬宗長子也在位二', 13: '三月詔諸軍造戰噐戰船', 14: '元人溺死不可勝計', 15: '不足築大城五十年後必', 16: '十二月大同偽武德恭', 17: '一説義師逼近帝出幸', 18: '以致敗人事者自古有之', 19: '庚午三年明洪武二十', 20: '士出身入翰林院加一級', 21: '秋八月定補軍伍修造', 22: '伯大等二十一人惟', 23: '此一舉两得萬金之計也', 24: '天属鄕人不得入學', 25: '於刈公象草又被所', 26: '兵又遭江水之暴涨', 27: '白相間而見群臣辨', 28: '冬十一月以何於爲', 29: '臣窃見監生儒生年未', 30: '員等五名除東閣大', 31: '之輩紊乱朝綱勝种以', 32: '耒碎仕救娘𨖲𣦍朱脱'}
# - Pred: {1: '令旨各處鎮守係諸犯人', 2: '若評諭官宜用法公平', 3: '弋麻咹𪿀渃韓爫𦧘渃趙', 4: '慶二年春正月尊寧', 5: '初四日簡脩公即皇帝位', 6: '十二月大同偽武德恭', 7: '丐哿巴欲鹤奴劍双曰', 8: '于青林沿江以守之', 9: '壽𭁈天齊年率土臣', 10: '守安定逾永福攻畧宋山', 11: '令廣德縣作紙局造作大', 12: '\U000f0c50敬宗長子也在位二', 13: '三月詔諸軍造戰噐戰船', 14: '元人溺死不可勝計', 15: '不足築大城五十年後必', 16: '十二月大同偽武德恭', 17: '一説義師逼近帝出幸', 18: '以致敗人事者自古有之', 19: '庚午三年明洪武二十', 20: '士出身入翰林院加一級', 21: '秋八月定補軍伍修造', 22: '伯大等二十一人惟', 23: '此一舉两得萬金之計也', 24: '天属鄕人不得入學', 25: '於刘公象草又報所', 26: '兵又遭江水之暴漲', 27: '白相間而見群臣辨', 28: '冬十一月以何於爲', 29: '臣髙見監生儒生年未', 30: '員等五名除東閣大', 31: '之輩紊乱朝綱勝仲以', 32: '耒碎仕救娘𨖲踏朱脱'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
    text_x = 40 # Position to plot actual label
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 囷𦝄苔惮󰞺約𦬑囊
