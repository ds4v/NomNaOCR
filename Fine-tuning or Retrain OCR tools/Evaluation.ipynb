# %% [markdown]
# <a href="https://medium.com/technovators/review-of-best-open-source-ocr-tools-fc839a20e61f">
#     <img src="https://miro.medium.com/max/1400/1*pXOgDAJUY6Cv3ZxLaXbZXQ.png" target="_blank" />
# </a>

# %%
# https://medium.com/technovators/review-of-best-open-source-ocr-tools-fc839a20e61f
from google.colab import drive
drive.mount('/content/GoogleDrive', force_remount=True)

# %%
import os
PROJECT_PATH = '/content/GoogleDrive/My Drive/vietnamese-nom-script'
SOLUTION_PATH = os.path.join(PROJECT_PATH, 'Fine-tuning or Retrain OCR tools')
TOOL_PATH = os.path.join(SOLUTION_PATH, 'EasyOCR')
# %cd {TOOL_PATH}
# !ls

# %%
import numpy as np
import tensorflow as tf
import torch
tf.get_logger().setLevel('ERROR')
# !curl -s https://raw.githubusercontent.com/sivel/speedtest-cli/master/speedtest.py | python -
# Out:
# Retrieving speedtest.net configuration...
# Testing from Google Cloud (34.80.241.104)...
# Retrieving speedtest.net server list...
# Selecting best server based on ping...
# Hosted by Taiwan Mobile (Taipei) [1.90 km]: 5.919 ms
# Testing download speed................................................................................
# Download: 1620.39 Mbit/s
# Testing upload speed......................................................................................................
# Upload: 823.94 Mbit/s

# %% [markdown]
# # Check accelerator

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
n_gpus = torch.cuda.device_count()
torch.cuda.get_device_name(0)
# Out:
# Found GPU at: /device:GPU:0
# 'Tesla K80'

# %%
# !nvcc -V
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %% [markdown]
# # Compare
