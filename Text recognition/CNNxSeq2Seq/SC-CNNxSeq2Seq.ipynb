# %%
# https://github.com/bai-shang/crnn_seq2seq_ocr_pytorch
# https://github.com/chenjun2hao/Attention_ocr.pytorch
# https://github.com/alleveenstra/attentionocr
# https://github.com/koibiki/CRNN-ATTENTION
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'SC-CNNxSeq2Seq'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../Datasets/IHR-NomDB'
LABELS_PATH = r'../Datasets/IHR-NomDB/labels.txt'
FONT_PATH = r'../../NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, LABELS_PATH, min_length=1).remove_rare_chars(1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 101533
# - Number of labels found: 101533
# - Number of unique characters: 13168
# - Characters present: {'之': 8193, '以': 4931, '月': 4007, '人': 3927, '十': 3611, '年': 3381, '不': 3263, '帝': 2955, '二': 2722, '大': 2641, '有': 2634, '日': 2561, '為': 2548, '其': 2537, '公': 2476, '兵': 2469, '等': 2404, '固': 2381, '於': 2311, '如': 2252, '國': 2194, '時': 2171, '官': 2160, '太': 2153, '爲': 2142, '子': 2140, '一': 2136, '天': 2077, '王': 2061, '軍': 2052, '而': 2019, '三': 1981, '事': 1955, '吏': 1942, '明': 1910, '朱': 1880, '使': 1825, '阮': 1818, '至': 1808, '曰': 1791, '及': 1646, '者': 1638, '文': 1631, '㐌': 1617, '安': 1612, '臣': 1601, '所': 1600, '行': 1569, '埃': 1563, '黎': 1511, '麻': 1494, '上': 1485, '皇': 1469, '也': 1469, '士': 1462, '命': 1444, '民': 1424, '是': 1418, '中': 1409, '自': 1407, '𢚸': 1387, '四': 1354, '五': 1346, '生': 1333, '道': 1331, '爫': 1319, '下': 1293, '郡': 1249, '元': 1243, '山': 1214, '渃': 1201, '𠊛': 1192, '宗': 1174, '莫': 1173, '武': 1169, '南': 1167, '于': 1165, '将': 1153, '春': 1144, '外': 1138, '城': 1136, '都': 1131, '書': 1131, '名': 1127, '花': 1122, '各': 1116, '朝': 1115, '六': 1113, '拱': 1107, '進': 1096, '得': 1091, '群': 1073, '州': 1062, '尼': 1057, '拯': 1055, '制': 1038, '意': 1036, '無': 1032, '正': 1030, '世': 1027, '令': 1026, '特': 1016, '鄭': 1013, '平': 1012, '仍': 1012, '買': 1004, '𡗶': 1001, '諸': 995, '\U000f047c': 972, '入': 966, '分': 955, '部': 955, '侯': 953, '辰': 950, '出': 945, '浪': 940, '知': 936, '乃': 932, '同': 928, '清': 924, '頭': 920, '内': 920, '陳': 919, '共': 913, '後': 904, '師': 896, '遣': 892, '空': 887, '史': 885, '昆': 885, '八': 882, '情': 880, '身': 879, '七': 874, '可': 872, '德': 869, '府': 866, '本': 843, '方': 839, '功': 835, '東': 829, '定': 824, '欺': 824, '些': 819, '江': 813, '初': 807, '𡥵': 802, '羅': 795, '賊': 794, '蒸': 794, '𥙩': 792, '女': 791, '㗂': 787, '立': 782, '在': 781, '長': 781, '𠫾': 780, '家': 772, '先': 766, '茹': 757, '秋': 757, '\U000f0179': 754, '百': 752, '故': 751, '庄': 749, '蔑': 747, '咹': 745, '守': 741, '主': 739, '西': 736, '丐': 736, '御': 735, '司': 733, '渚': 733, '用': 732, '又': 732, '九': 729, '節': 725, '水': 721, '門': 716, '縣': 715, '𠄩': 712, '典': 712, '禮': 712, '英': 709, '則': 707, '相': 706, '饒': 703, '𧗱': 699, '來': 693, '沛': 690, '從': 690, '𣈜': 685, '娘': 685, '衛': 676, '咍': 675, '未': 674, '𢧚': 669, '政': 667, '興': 663, '地': 657, '底': 653, '前': 652, '聖': 652, '見': 649, '路': 645, '京': 645, '船': 644, '與': 643, '多': 643, '保': 639, '卒': 637, '今': 632, '北': 632, '光': 632, '左': 631, '海': 630, '化': 627, '重': 627, '詔': 627, '萬': 625, '連': 620, '丕': 619, '餘': 619, '仁': 619, '罪': 617, '此': 616, '領': 611, '督': 610, '碎': 605, '皆': 604, '言': 603, '宋': 602, '復': 602, '林': 602, '鐄': 602, '𫽄': 601, '几': 599, '賜': 596, '香': 596, '金': 595, '處': 594, '封': 594, '心': 592, '奏': 592, '牢': 586, '𦋦': 584, '黄': 579, '冬': 579, '當': 578, '我': 577, '𢬣': 576, '殿': 575, '㝵': 574, '別': 574, '郎': 572, '皮': 571, '\U000f070b': 571, '神': 570, '然': 567, '侍': 567, '玉': 560, '位': 559, '塘': 559, '永': 558, '義': 558, '差': 556, '箕': 549, '𧡊': 547, '呐': 543, '占': 543, '𦝄': 543, '隊': 542, '親': 541, '法': 541, '治': 540, '君': 539, '營': 538, '死': 533, '強': 532, '常': 530, '翁': 528, '奉': 525, '𠬠': 519, '馬': 519, '還': 519, '夫': 512, '除': 503, '𨕭': 503, '陽': 503, '少': 502, '通': 502, '成': 498, '坤': 498, '會': 496, '每': 496, '敬': 496, '后': 492, '𠳒': 492, '和': 489, '吳': 489, '夏': 489, '福': 489, '回': 487, '油': 486, '才': 486, '即': 485, '没': 485, '𠓨': 483, '奴': 483, '杜': 482, '𫥨': 479, '調': 475, '順': 475, '鎮': 473, '作': 472, '襖': 467, '𦖑': 467, '何': 466, '矣': 463, '經': 463, '包': 463, '𠊚': 462, '風': 462, '右': 461, '宜': 461, '停': 460, '將': 458, '監': 454, '𠀧': 454, '試': 453, '戈': 447, '因': 445, '宫': 443, '台': 443, '旦': 442, '户': 442, '率': 441, '默': 441, '払': 441, '𡽫': 441, '李': 440, '奇': 439, '丁': 438, '院': 436, '廷': 434, '亦': 433, '祖': 433, '居': 433, '計': 432, '柴': 432, '范': 431, '漢': 430, '体': 430, '能': 429, '庒': 428, '眾': 428, '改': 427, '土': 426, '傳': 425, '信': 424, '排': 424, '職': 423, '或': 423, '忠': 421, '古': 420, '龍': 419, '坦': 419, '氏': 418, '唐': 416, '高': 415, '象': 414, '廣': 413, '傷': 412, '殺': 411, '小': 409, '滝': 408, '撑': 407, '景': 404, '朋': 404, '並': 404, '吝': 404, '過': 399, '尋': 399, '恩' ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 8),
    font_path = FONT_PATH, 
    text_x = WIDTH + 3
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import (
    Input, Embedding, Dense, GRU, 
    Bidirectional, Concatenate, Flatten
)
from layers import custom_cnn, reshape_features, BahdanauAttention
EMBEDDING_DIM = 512
UNITS = 256

# %% [markdown]
# ## The encoder

# %%
def Encoder(imagenet_model=None, imagenet_output_layer=None, name='Encoder'):
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 
            
            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)

    # Reshape accordingly before passing output to RNN
    feature_maps = reshape_features(x, dim_to_keep=1, name='rnn_input')
    
    # RNN layers
    bigru1 = Bidirectional(GRU(UNITS, return_sequences=True), name='bigru1')(feature_maps)
    bigru2, forward_state, backward_state = Bidirectional(GRU(
        units = UNITS, 
        return_sequences = True,
        return_state = True
    ), name = 'bigru2')(bigru1)
    
    # Skip connection and concat states of 2 directions
    x = Concatenate(name='skip_connection')([feature_maps, bigru2])
    
    # Concat states of 2 directions
    final_state = Concatenate(name='encoder_state')([forward_state, backward_state])
    return tf.keras.Model(inputs=image_input, outputs=[x, final_state], name=name)

# %% [markdown]
# ## The decoder

# %%
def Decoder(enc_seq_shape, name='Decoder'):
    token_input = Input(shape=(1,), name='new_token')
    enc_seq_input = Input(shape=enc_seq_shape, name='encoder_sequence')
    
    # In encoder we used Bidirectional so we have to take double UNITS  
    # for single decoder GRU using encoder's final state as initial state
    dec_units = UNITS * 2
    pre_hidden_input = Input(shape=(dec_units,), name='previous_state')
    
    # Defining attention as a separate model
    attention = BahdanauAttention(dec_units)
    context_vector, attention_weights = attention(enc_seq_input, pre_hidden_input)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = Concatenate(axis=-1, name='context_and_embedding')([
        tf.expand_dims(context_vector, 1), 
        Embedding(VOCAB_SIZE, EMBEDDING_DIM)(token_input)
    ])
    
    # Passing the concatenated vector to the GRU
    rnn_output, state = GRU(
        units = dec_units, 
        return_state = True, 
        return_sequences = True,
        name = 'dec_gru'
    )(x, initial_state=pre_hidden_input)

    # Generate predictions
    x = Flatten()(rnn_output)
    y_pred = Dense(VOCAB_SIZE, name='prediction')(x)

    return tf.keras.Model(
        inputs = [token_input, enc_seq_input, pre_hidden_input], 
        outputs = [y_pred, state, attention_weights],
        name = name
    )

# %% [markdown]
# # Build the model

# %%
from models import get_imagenet_model, EncoderDecoderModel
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 3))
# imagenet_output_layer = 'block5_pool'
# imagenet_model.summary(line_length=100)

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
model = EncoderDecoderModel(encoder, decoder, data_handler)

# %%
encoder.summary(line_length=120)
print()
decoder.summary(line_length=125)
# Out:
# Model: "Encoder"
# ________________________________________________________________________________________________________________________
#  Layer (type)                          Output Shape               Param #       Connected to
# ========================================================================================================================
#  image (InputLayer)                    [(None, 432, 48, 3)]       0             []
#
#  block1_conv1 (Conv2D)                 (None, 432, 48, 64)        1792          ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)       (None, 432, 48, 64)        256           ['block1_conv1[0][0]']
#
#  block1_relu1 (Activation)             (None, 432, 48, 64)        0             ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)            (None, 216, 24, 64)        0             ['block1_relu1[0][0]']
#
#  block2_conv1 (Conv2D)                 (None, 216, 24, 128)       73856         ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)       (None, 216, 24, 128)       512           ['block2_conv1[0][0]']
#
#  block2_relu1 (Activation)             (None, 216, 24, 128)       0             ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)            (None, 108, 12, 128)       0             ['block2_relu1[0][0]']
#
#  block3_conv1 (Conv2D)                 (None, 108, 12, 256)       295168        ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv1[0][0]']
#
#  block3_relu1 (Activation)             (None, 108, 12, 256)       0             ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)                 (None, 108, 12, 256)       590080        ['block3_relu1[0][0]']
#
#  block3_bn2 (BatchNormalization)       (None, 108, 12, 256)       1024          ['block3_conv2[0][0]']
#
#  block3_relu2 (Activation)             (None, 108, 12, 256)       0             ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)            (None, 54, 6, 256)         0             ['block3_relu2[0][0]']
#
#  block4_conv1 (Conv2D)                 (None, 54, 6, 512)         1180160       ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv1[0][0]']
#
#  block4_relu1 (Activation)             (None, 54, 6, 512)         0             ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)                 (None, 54, 6, 512)         2359808       ['block4_relu1[0][0]']
#
#  block4_bn2 (BatchNormalization)       (None, 54, 6, 512)         2048          ['block4_conv2[0][0]']
#
#  block4_relu2 (Activation)             (None, 54, 6, 512)         0             ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)            (None, 27, 3, 512)         0             ['block4_relu2[0][0]']
#
#  block5_conv1 (Conv2D)                 (None, 26, 2, 512)         1049088       ['block4_pool[0][0]']
#
#  block5_bn1 (BatchNormalization)       (None, 26, 2, 512)         2048          ['block5_conv1[0][0]']
#
#  block5_relu1 (Activation)             (None, 26, 2, 512)         0             ['block5_bn1[0][0]']
#
#  block5_conv2 (Conv2D)                 (None, 25, 1, 512)         1049088       ['block5_relu1[0][0]']
#
#  block5_bn2 (BatchNormalization)       (None, 25, 1, 512)         2048          ['block5_conv2[0][0]']
#
#  block5_relu2 (Activation)             (None, 25, 1, 512)         0             ['block5_bn2[0][0]']
#
#  rnn_input (Reshape)                   (None, 25, 512)            0             ['block5_relu2[0][0]']
#
#  bigru1 (Bidirectional)                (None, 25, 512)            1182720       ['rnn_input[0][0]']
#
#  bigru2 (Bidirectional)                [(None, 25, 512),          1182720       ['bigru1[0][0]']
#                                         (None, 256),
#                                         (None, 256)]
#
#  skip_connection (Concatenate)         (None, 25, 1024)           0             ['rnn_input[0][0]',
#                                                                                  'bigru2[0][0]']
#
#  encoder_state (Concatenate)           (None, 512)                0             ['bigru2[0][1]',
#                                                                                  'bigru2[0][2]']
#
# ========================================================================================================================
# Total params: 8,975,488
# Trainable params: 8,969,984
# Non-trainable params: 5,504
# ________________________________________________________________________________________________________________________
#
# Model: "Decoder"
# _____________________________________________________________________________________________________________________________
#  Layer (type)                            Output Shape               Param #        Connected to
# =============================================================================================================================
#  encoder_sequence (InputLayer)           [(None, 25, 1024)]         0              []
#
#  previous_state (InputLayer)             [(None, 512)]              0              []
#
#  BahdanauAttention (BahdanauAttention)   ((None, 1024),             787969         ['encoder_sequence[0][0]',
#                                           (None, 25, 1))                            'previous_state[0][0]']
#
#  new_token (InputLayer)                  [(None, 1)]                0              []
#
#  tf.expand_dims (TFOpLambda)             (None, 1, 1024)            0              ['BahdanauAttention[0][0]']
#
#  embedding (Embedding)                   (None, 1, 512)             6744064        ['new_token[0][0]']
#
#  context_and_embedding (Concatenate)     (None, 1, 1536)            0              ['tf.expand_dims[0][0]',
#                                                                                     'embedding[0][0]']
#
#  dec_gru (GRU)                           [(None, 1, 512),           3148800        ['context_and_embedding[0][0]',
#                                           (None, 512)]                              'previous_state[0][0]']
#
#  flatten (Flatten)                       (None, 512)                0              ['dec_gru[0][0]']
#
#  prediction (Dense)                      (None, 13172)              6757236        ['flatten[0][0]']
#
# =============================================================================================================================
# Total params: 17,438,069
# Trainable params: 17,438,069
# Non-trainable params: 0
# _____________________________________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(int(dataset.size * 0.8)))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 81226
# Number of validate samples: 20307

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)

# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, drop_remainder=True)
valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping_callback = EarlyStopping(
    monitor = 'val_loss', 
    min_delta = 1e-3, # Change that less than 1e-3, will count as no improvement
    patience = 5, # Stop if no improvement after 5 epochs
    restore_best_weights = True, # Restore weights from the epoch with the best value
    verbose = 1
)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Train the IHR-NomDB dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [reduce_lr_callback, early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 410s 155ms/step - loss: 3.8738 - seq_acc: 6.2796e-04 - char_acc: 0.2163 - lev_distance: 0.7001 - val_loss: 3.0213 - val_seq_acc: 1.9716e-04 - val_char_acc: 0.4179 - val_lev_distance: 0.5447 - lr: 2.0000e-04
# Epoch 2/100
# 2538/2538 [==============================] - 377s 149ms/step - loss: 1.9469 - seq_acc: 0.0398 - char_acc: 0.5597 - lev_distance: 0.4175 - val_loss: 2.2364 - val_seq_acc: 0.0190 - val_char_acc: 0.4642 - val_lev_distance: 0.3633 - lr: 2.0000e-04
# Epoch 3/100
# 2538/2538 [==============================] - 377s 148ms/step - loss: 0.9540 - seq_acc: 0.2096 - char_acc: 0.7782 - lev_distance: 0.2150 - val_loss: 2.6749 - val_seq_acc: 0.0071 - val_char_acc: 0.3770 - val_lev_distance: 0.3960 - lr: 2.0000e-04
# Epoch 4/100
# 2538/2538 [==============================] - 376s 148ms/step - loss: 0.7109 - seq_acc: 0.3389 - char_acc: 0.8282 - lev_distance: 0.1627 - val_loss: 0.3965 - val_seq_acc: 0.4808 - val_char_acc: 0.9220 - val_lev_distance: 0.0763 - lr: 2.0000e-04
# Epoch 5/100
# 2538/2538 [==============================] - 378s 149ms/step - loss: 0.5331 - seq_acc: 0.4186 - char_acc: 0.8602 - lev_distance: 0.1333 - val_loss: 0.4131 - val_seq_acc: 0.3801 - val_char_acc: 0.8706 - val_lev_distance: 0.1066 - lr: 2.0000e-04
# Epoch 6/100
# 2538/2538 [==============================] - 376s 148ms/step - loss: 0.3782 - seq_acc: 0.5608 - char_acc: 0.9105 - lev_distance: 0.0857 - val_loss: 0.2838 - val_seq_acc: 0.5907 - val_char_acc: 0.9408 - val_lev_distance: 0.0553 - lr: 2.0000e-04
# Epoch 7/100
# 2538/2538 [==============================] - 378s 149ms/step - loss: 0.3338 - seq_acc: 0.5907 - char_acc: 0.9106 - lev_distance: 0.0842 - val_loss: 0.4846 - val_seq_acc: 0.2732 - val_char_acc: 0.8381 - val_lev_distance: 0.1425 - lr: 2.0000e-04
# Epoch 8/100
# 2538/2538 [==============================] - 397s 156ms/step - loss: 0.2089 - seq_acc: 0.6960 - char_acc: 0.9484 - lev_distance: 0.0504 - val_loss: 0.2110 - val_seq_acc: 0.5111 - val_char_acc: 0.9107 - val_lev_distance: 0.0710 - lr: 2.0000e-04
# Epoch 9/100
# 2538/2538 [==============================] - 394s 155ms/step - loss: 0.1444 - seq_acc: 0.7753 - char_acc: 0.9625 - lev_distance: 0.0366 - val_loss: 0.1828 - val_seq_acc: 0.6477 - val_char_acc: 0.9461 - val_lev_distance: 0.0465 - lr: 2.0000e-04
# Epoch 10/100
# 2538/2538 [==============================] - 384s 151ms/step - loss: 0.1291 - seq_acc: 0.8014 - char_acc: 0.9644 - lev_distance: 0.0342 - val_loss: 0.1195 - val_seq_acc: 0.7430 - val_char_acc: 0.9685 - val_lev_distance: 0.0302 - lr: 2.0000e-04
# Epoch 11/100
# 2538/2538 [==============================] - 385s 152ms/step - loss: 0.1462 - seq_acc: 0.7790 - char_acc: 0.9575 - lev_distance: 0.0405 - val_loss: 0.1137 - val_seq_acc: 0.7087 - val_char_acc: 0.9601 - val_lev_distance: 0.0358 - lr: 2.0000e-04
# Epoch 12/100
# 2538/2538 [==============================] - 387s 153ms/step - loss: 0.2349 - seq_acc: 0.7262 - char_acc: 0.9314 - lev_distance: 0.0636 - val_loss: 0.1189 - val_seq_acc: 0.6555 - val_char_acc: 0.9476 - val_lev_distance: 0.0451 - lr: 2.0000e-04
# Epoch 13/100
# 2538/2538 [==============================] - 378s 149ms/step - loss: 0.0731 - seq_acc: 0.8913 - char_acc: 0.9838 - lev_distance: 0.0155 - val_loss: 0.0983 - val_seq_acc: 0.7539 - val_char_acc: 0.9691 - val_lev_distance: 0.0292 - lr: 2.0000e-04
# Epoch 14/100
# 2538/2538 [==============================] - 378s 149ms/step - loss: 0.0952 - seq_acc: 0.8585 - char_acc: 0.9727 - lev_distance: 0.0254 - val_loss: 0.1204 - val_seq_acc: 0.7123 - val_char_acc: 0.9599 - val_lev_distance: 0.0352 - lr: 2.0000e-04
# Epoch 15/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.1161 - seq_acc: 0.8647 - char_acc: 0.9720 - lev_distance: 0.0257
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 2538/2538 [==============================] - 379s 149ms/step - loss: 0.1161 - seq_acc: 0.8647 - char_acc: 0.9720 - lev_distance: 0.0257 - val_loss: 0.1008 - val_seq_acc: 0.7092 - val_char_acc: 0.9603 - val_lev_distance: 0.0351 - lr: 2.0000e-04
# Epoch 16/100
# 2538/2538 [==============================] - 379s 149ms/step - loss: 0.0325 - seq_acc: 0.9630 - char_acc: 0.9950 - lev_distance: 0.0048 - val_loss: 0.0890 - val_seq_acc: 0.7631 - val_char_acc: 0.9689 - val_lev_distance: 0.0280 - lr: 1.0000e-04
# Epoch 17/100
# 2538/2538 [==============================] - 379s 149ms/step - loss: 0.0200 - seq_acc: 0.9807 - char_acc: 0.9974 - lev_distance: 0.0024 - val_loss: 0.0859 - val_seq_acc: 0.7586 - val_char_acc: 0.9616 - val_lev_distance: 0.0290 - lr: 1.0000e-04
# Epoch 18/100
# 2538/2538 [==============================] - 379s 149ms/step - loss: 0.0152 - seq_acc: 0.9884 - char_acc: 0.9984 - lev_distance: 0.0014 - val_loss: 0.0744 - val_seq_acc: 0.8036 - val_char_acc: 0.9769 - val_lev_distance: 0.0221 - lr: 1.0000e-04
# Epoch 19/100
# 2538/2538 [==============================] - 380s 150ms/step - loss: 0.0129 - seq_acc: 0.9929 - char_acc: 0.9988 - lev_distance: 9.8905e-04 - val_loss: 0.5675 - val_seq_acc: 0.3012 - val_char_acc: 0.8333 - val_lev_distance: 0.1263 - lr: 1.0000e-04
# Epoch 20/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0237 - seq_acc: 0.9698 - char_acc: 0.9951 - lev_distance: 0.0045
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2538/2538 [==============================] - 383s 151ms/step - loss: 0.0237 - seq_acc: 0.9698 - char_acc: 0.9951 - lev_distance: 0.0045 - val_loss: 0.0866 - val_seq_acc: 0.7158 - val_char_acc: 0.9534 - val_lev_distance: 0.0358 - lr: 1.0000e-04
# Epoch 21/100
# 2538/2538 [==============================] - 383s 151ms/step - loss: 0.0198 - seq_acc: 0.9891 - char_acc: 0.9983 - lev_distance: 0.0014 - val_loss: 0.0841 - val_seq_acc: 0.7529 - val_char_acc: 0.9648 - val_lev_distance: 0.0296 - lr: 5.0000e-05
# Epoch 22/100
# 2538/2538 [==============================] - 380s 150ms/step - loss: 0.0096 - seq_acc: 0.9968 - char_acc: 0.9995 - lev_distance: 3.9981e-04 - val_loss: 0.0688 - val_seq_acc: 0.7960 - val_char_acc: 0.9745 - val_lev_distance: 0.0231 - lr: 5.0000e-05
# Epoch 23/100
# 2538/2538 [==============================] - 380s 150ms/step - loss: 0.0062 - seq_acc: 0.9982 - char_acc: 0.9997 - lev_distance: 2.2684e-04 - val_loss: 0.0654 - val_seq_acc: 0.8116 - val_char_acc: 0.9772 - val_lev_distance: 0.0210 - lr: 5.0000e-05
# Epoch 24/100
# 2538/2538 [==============================] - 381s 150ms/step - loss: 0.0089 - seq_acc: 0.9936 - char_acc: 0.9990 - lev_distance: 8.7571e-04 - val_loss: 0.0765 - val_seq_acc: 0.7818 - val_char_acc: 0.9713 - val_lev_distance: 0.0254 - lr: 5.0000e-05
# Epoch 25/100
# 2538/2538 [==============================] - 383s 151ms/step - loss: 0.0053 - seq_acc: 0.9984 - char_acc: 0.9997 - lev_distance: 1.9583e-04 - val_loss: 0.0634 - val_seq_acc: 0.8160 - val_char_acc: 0.9782 - val_lev_distance: 0.0206 - lr: 5.0000e-05
# Epoch 26/100
# 2538/2538 [==============================] - 384s 151ms/step - loss: 0.0053 - seq_acc: 0.9974 - char_acc: 0.9996 - lev_distance: 3.1152e-04 - val_loss: 0.0626 - val_seq_acc: 0.8175 - val_char_acc: 0.9786 - val_lev_distance: 0.0203 - lr: 5.0000e-05
# Epoch 27/100
# 2538/2538 [==============================] - 389s 153ms/step - loss: 0.0060 - seq_acc: 0.9963 - char_acc: 0.9994 - lev_distance: 4.6543e-04 - val_loss: 0.0620 - val_seq_acc: 0.8175 - val_char_acc: 0.9784 - val_lev_distance: 0.0203 - lr: 5.0000e-05
# Epoch 28/100
# 2538/2538 [==============================] - 390s 154ms/step - loss: 0.0031 - seq_acc: 0.9993 - char_acc: 0.9999 - lev_distance: 8.1585e-05 - val_loss: 0.0577 - val_seq_acc: 0.8207 - val_char_acc: 0.9777 - val_lev_distance: 0.0200 - lr: 5.0000e-05
# Epoch 29/100
# 2538/2538 [==============================] - 390s 154ms/step - loss: 0.0019 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 5.5853e-05 - val_loss: 0.0559 - val_seq_acc: 0.8342 - val_char_acc: 0.9812 - val_lev_distance: 0.0182 - lr: 5.0000e-05
# Epoch 30/100
# 2538/2538 [==============================] - 386s 152ms/step - loss: 0.0014 - seq_acc: 0.9997 - char_acc: 0.9999 - lev_distance: 3.6983e-05 - val_loss: 0.0563 - val_seq_acc: 0.8402 - val_char_acc: 0.9820 - val_lev_distance: 0.0175 - lr: 5.0000e-05
# Epoch 31/100
# 2538/2538 [==============================] - 383s 151ms/step - loss: 9.7514e-04 - seq_acc: 0.9999 - char_acc: 1.0000 - lev_distance: 1.4839e-05 - val_loss: 0.0548 - val_seq_acc: 0.8466 - val_char_acc: 0.9828 - val_lev_distance: 0.0167 - lr: 5.0000e-05
# Epoch 32/100
# 2538/2538 [==============================] - 380s 150ms/step - loss: 7.1098e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 5.6776e-06 - val_loss: 0.0543 - val_seq_acc: 0.8493 - val_char_acc: 0.9832 - val_lev_distance: 0.0163 - lr: 5.0000e-05
# Epoch 33/100
# 2538/2538 [==============================] - 384s 151ms/step - loss: 6.3018e-04 - seq_acc: 0.9997 - char_acc: 1.0000 - lev_distance: 3.0640e-05 - val_loss: 0.0520 - val_seq_acc: 0.8469 - val_char_acc: 0.9823 - val_lev_distance: 0.0166 - lr: 5.0000e-05
# Epoch 34/100
# 2538/2538 [==============================] - 385s 152ms/step - loss: 0.0046 - seq_acc: 0.9960 - char_acc: 0.9993 - lev_distance: 5.3662e-04 - val_loss: 0.0662 - val_seq_acc: 0.7802 - val_char_acc: 0.9624 - val_lev_distance: 0.0254 - lr: 5.0000e-05
# Epoch 35/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0014 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 6.2128e-05
# Epoch 35: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2538/2538 [==============================] - 382s 150ms/step - loss: 0.0014 - seq_acc: 0.9995 - char_acc: 0.9999 - lev_distance: 6.2128e-05 - val_loss: 0.0525 - val_seq_acc: 0.8377 - val_char_acc: 0.9815 - val_lev_distance: 0.0178 - lr: 5.0000e-05
# Epoch 36/100
# 2538/2538 [==============================] - 381s 150ms/step - loss: 5.5013e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0509 - val_seq_acc: 0.8450 - val_char_acc: 0.9826 - val_lev_distance: 0.0169 - lr: 2.5000e-05
# Epoch 37/100
# 2538/2538 [==============================] - 382s 151ms/step - loss: 4.0557e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0512 - val_seq_acc: 0.8493 - val_char_acc: 0.9832 - val_lev_distance: 0.0163 - lr: 2.5000e-05
# Epoch 38/100
# 2538/2538 [==============================] - ETA: 0s - loss: 3.1090e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 2538/2538 [==============================] - 389s 153ms/step - loss: 3.1090e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0515 - val_seq_acc: 0.8521 - val_char_acc: 0.9835 - val_lev_distance: 0.0160 - lr: 2.5000e-05
# Epoch 39/100
# 2538/2538 [==============================] - 382s 150ms/step - loss: 2.4923e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0522 - val_seq_acc: 0.8539 - val_char_acc: 0.9837 - val_lev_distance: 0.0158 - lr: 1.2500e-05
# Epoch 40/100
# 2538/2538 [==============================] - ETA: 0s - loss: 2.1984e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00
# Epoch 40: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 2538/2538 [==============================] - 381s 150ms/step - loss: 2.1985e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0515 - val_seq_acc: 0.8553 - val_char_acc: 0.9840 - val_lev_distance: 0.0155 - lr: 1.2500e-05
# Epoch 41/100
# 2538/2538 [==============================] - ETA: 0s - loss: 1.9223e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00Restoring model weights from the end of the best epoch: 36.
# 2538/2538 [==============================] - 383s 151ms/step - loss: 1.9224e-04 - seq_acc: 1.0000 - char_acc: 1.0000 - lev_distance: 0.0000e+00 - val_loss: 0.0525 - val_seq_acc: 0.8553 - val_char_acc: 0.9838 - val_lev_distance: 0.0155 - lr: 6.2500e-06
# Epoch 41: early stopping
# CPU times: total: 6h 16min 21s
# Wall time: 4h 21min 50s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_lev_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 0.050926804542541504
# - Sequence accuracy	: 0.8449822664260864
# - Character accuracy	: 0.9825629591941833
# - Levenshtein distance	: 0.01686241291463375

# %%
from visualizer import plot_training_results
plot_training_results(history, f'{APPROACH_NAME}.png')
model.encoder.save_weights(f'{APPROACH_NAME}_enc.h5')
model.decoder.save_weights(f'{APPROACH_NAME}_dec.h5')

# %% [markdown]
# # Inference

# %%
encoder = Encoder(imagenet_model, imagenet_output_layer)
decoder = Decoder(encoder.outputs[0].shape[1:])
encoder.load_weights(f'{APPROACH_NAME}_enc.h5')
decoder.load_weights(f'{APPROACH_NAME}_dec.h5')

# %%
reset_model = EncoderDecoderModel(encoder, decoder, data_handler)
reset_model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)
reset_model.evaluate(valid_tf_dataset)
# Out:
# 634/634 [==============================] - 54s 71ms/step - loss: 0.1088 - seq_acc: 0.8450 - char_acc: 0.9826 - lev_distance: 0.0169
# [0.8449822664260864,
#  0.9825629591941833,
#  0.01686241291463375,
#  0.050926804542541504]

# %% [markdown]
# ## On test dataset

# %%
batch_results = []
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(2)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens, attentions = reset_model.predict(batch_images, return_attention=True)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    batch_results.append({'true': labels, 'pred': pred_labels, 'attentions': attentions})
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        figsize = (14, 20),
        subplot_size = (4, 8),
        legend_loc = (3.8, 4.28),
        annotate_loc = (4, 1.8),
        font_path = FONT_PATH, 
        text_x = WIDTH + 5 # Position of actual label to plot
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '㙋𡉖\U000f0b1f', 2: '噙𠿒', 3: '犝犠', 4: '鉸𨦀', 5: '爲䧺禮公而不委之以兵', 6: '爲䧺禮公而不委之以兵', 7: '是以聖帝明王之治天下', 8: '十一月戊子朔日有食之', 9: '以致敗人事者自古有之', 10: '不名以激年老之固位者', 11: '璉以是不平使人陰殺之', 12: '武郡公令人以象載之及', 13: '武郡公令人以象載之及', 14: '大而三綱五常之道以至', 15: '世人以不常見而異之殊', 16: '如先求皇子而立之以安', 17: '如先求皇子而立之以安', 18: '冬十一月帝得陳暠立之', 19: '中國之人不耐其水土也', 20: '首惡之名為人臣而不知', 21: '爲悅而不知其過之大也', 22: '帝位以副天下臣民之望', 23: '食之是月會試天下士人', 24: '十二月以誕日為建天節', 25: '春正月初二日上以大軍', 26: '取士之科不一而定三年', 27: '取之以賴其後故有是命', 28: '人守之百官進朝不得入', 29: '牧之民不足以煩中國也', 30: '罄家所有以奉事之冀其', 31: '土人以為灵異立祠事之', 32: '土人以為灵異立祠事之'}
# - Pred: {1: '堪店玳', 2: '𡂓𨅄', 3: '㙴𢮿', 4: '鈘𥻻', 5: '爲䧺禮公而不委之以兵', 6: '爲䧺禮公而不委之以兵', 7: '是以聖帝明王治治天下', 8: '十一月戊子朔日有食之', 9: '以致敗人事者自古有之', 10: '不名以激年老之固位者', 11: '璉以是不平使人陰殺之', 12: '武郡公令人以象載之及', 13: '武郡公令人以象載之及', 14: '大而三綱五常之道以至', 15: '世人以不常見而異之殊', 16: '如先求皇子而立乂以安', 17: '如先求皇子而立以安', 18: '冬十一月帝得陳暠立之', 19: '中國之人不耐其水土也', 20: '首惡之名為人臣而不知', 21: '爲悅而不知其過之大也', 22: '帝位以副天下臣民之望', 23: '食之是月會試天下士人', 24: '十二月以誕日為建天節', 25: '春正月初二日上以大軍', 26: '取士之科不三而定三年', 27: '取之以賴其後故有是命', 28: '人守之百官進朝不得入', 29: '牧之民不足以煩中國也', 30: '慤家所有以奉事之𧡟其', 31: '土人以為灵異立祠事之', 32: '土人以為灵異立祠事之'}
#
# Batch 02:
# - True: {1: '武有等人才國家之元氣', 2: '詩曰共武之復以定王國', 3: '一節以全軍臣父子之義', 4: '年冬十二月以明字陳世', 5: '明帝以為近臣遇之甚厚', 6: '陳而不已也明帝納之五', 7: '以弱制強或攻人之不僃', 8: '之明其爲帝胄承大統也', 9: '献祥瑞以揜之而無一人', 10: '以岑州人民及土地㱕之', 11: '古今粗亦明聖人之道以', 12: '月以前楊日禮大定二年', 13: '冬十月丙戌望日有食之', 14: '鑄金為之有國十八葉也', 15: '以於八月十五日祗告天', 16: '三綱五常人之大倫太宗', 17: '杜欣等以學業不進之罪', 18: '迹其所為皆非人臣之法', 19: '冬十二月初八日以禮部', 20: '帝潜伏兵於甕隘以待之', 21: '𨿽用兵乃聖人之不得已', 22: '二十餘年之乱一旦削平', 23: '大夫仍以昭聖公主㱕之', 24: '一年之後六科給事中公', 25: '冬十月以誕日為壽天節', 26: '銘以昭先帝之業於來世', 27: '王数以亂臣賊子之罪乃', 28: '人以瓦礫投船而罵之者', 29: '有寃抑不達者撞之以聞', 30: '戊寅十一年三月以後少', 31: '大赦天下季税十分之一', 32: '冬十月以誕日為\U000f0191天節'}
# - Pred: {1: '武有等人才國家之元氣', 2: '詩曰共武之復以定王國', 3: '一節以全軍臣父子之義', 4: '年冬十二月以明字陳低', 5: '明帝以為近臣遇之甚厚', 6: '陳而不已也明帝納之五', 7: '以弱制強或攻人之不僃', 8: '之明其爲帝胄承大統也', 9: '献祥瑞以揜之而無一人', 10: '以岑州人民及土地㱕之', 11: '古今粗亦明聖人之道以', 12: '月以前楊日禮大定二年', 13: '冬十月丙戌望日有食之', 14: '鑄金為之有國十八葉也', 15: '以於八月十五日祗告天', 16: '三綱五常人之大倫太宗', 17: '杜欣等以學業不進之罪', 18: '迹其所為皆非人臣之法', 19: '冬十二月初八日以禮部', 20: '帝潜伏兵於甕隘以待之', 21: '𨿽用兵乃聖人之不得已', 22: '二十餘年之乱一旦削平', 23: '大夫仍以昭聖公主㱕之', 24: '一年之後六科給事中公', 25: '冬十月以誕日為壽天節', 26: '鎔以昭先帝之業於來世', 27: '王数以亂臣賊子梁罪乃', 28: '人以瓦藤投船而罵之者', 29: '有寃抑不達者撞之以聞', 30: '戊寅十一年三月以後少', 31: '大赦天下季税十分之一', 32: '冬十月以誕日為\U000f0191天節'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
    text_x = WIDTH # Position to plot actual label
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 囷𦝄苔惮󰞺𣈜𦬑囊
