# %%
# https://arxiv.org/pdf/1703.09137.pdf
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'Init-inject'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../Datasets/IHR-NomDB'
LABELS_PATH = r'../Datasets/IHR-NomDB/labels.txt'
FONT_PATH = r'../../NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, LABELS_PATH, min_length=1).remove_rare_chars(1)
print(dataset)
# Out:
# Samples count (not include Latin letters, numbers, punctuations):
# - Number of images found: 101533
# - Number of labels found: 101533
# - Number of unique characters: 13168
# - Characters present: {'之': 8193, '以': 4931, '月': 4007, '人': 3927, '十': 3611, '年': 3381, '不': 3263, '帝': 2955, '二': 2722, '大': 2641, '有': 2634, '日': 2561, '為': 2548, '其': 2537, '公': 2476, '兵': 2469, '等': 2404, '固': 2381, '於': 2311, '如': 2252, '國': 2194, '時': 2171, '官': 2160, '太': 2153, '爲': 2142, '子': 2140, '一': 2136, '天': 2077, '王': 2061, '軍': 2052, '而': 2019, '三': 1981, '事': 1955, '吏': 1942, '明': 1910, '朱': 1880, '使': 1825, '阮': 1818, '至': 1808, '曰': 1791, '及': 1646, '者': 1638, '文': 1631, '㐌': 1617, '安': 1612, '臣': 1601, '所': 1600, '行': 1569, '埃': 1563, '黎': 1511, '麻': 1494, '上': 1485, '皇': 1469, '也': 1469, '士': 1462, '命': 1444, '民': 1424, '是': 1418, '中': 1409, '自': 1407, '𢚸': 1387, '四': 1354, '五': 1346, '生': 1333, '道': 1331, '爫': 1319, '下': 1293, '郡': 1249, '元': 1243, '山': 1214, '渃': 1201, '𠊛': 1192, '宗': 1174, '莫': 1173, '武': 1169, '南': 1167, '于': 1165, '将': 1153, '春': 1144, '外': 1138, '城': 1136, '都': 1131, '書': 1131, '名': 1127, '花': 1122, '各': 1116, '朝': 1115, '六': 1113, '拱': 1107, '進': 1096, '得': 1091, '群': 1073, '州': 1062, '尼': 1057, '拯': 1055, '制': 1038, '意': 1036, '無': 1032, '正': 1030, '世': 1027, '令': 1026, '特': 1016, '鄭': 1013, '平': 1012, '仍': 1012, '買': 1004, '𡗶': 1001, '諸': 995, '\U000f047c': 972, '入': 966, '分': 955, '部': 955, '侯': 953, '辰': 950, '出': 945, '浪': 940, '知': 936, '乃': 932, '同': 928, '清': 924, '頭': 920, '内': 920, '陳': 919, '共': 913, '後': 904, '師': 896, '遣': 892, '空': 887, '史': 885, '昆': 885, '八': 882, '情': 880, '身': 879, '七': 874, '可': 872, '德': 869, '府': 866, '本': 843, '方': 839, '功': 835, '東': 829, '定': 824, '欺': 824, '些': 819, '江': 813, '初': 807, '𡥵': 802, '羅': 795, '賊': 794, '蒸': 794, '𥙩': 792, '女': 791, '㗂': 787, '立': 782, '在': 781, '長': 781, '𠫾': 780, '家': 772, '先': 766, '茹': 757, '秋': 757, '\U000f0179': 754, '百': 752, '故': 751, '庄': 749, '蔑': 747, '咹': 745, '守': 741, '主': 739, '西': 736, '丐': 736, '御': 735, '司': 733, '渚': 733, '用': 732, '又': 732, '九': 729, '節': 725, '水': 721, '門': 716, '縣': 715, '𠄩': 712, '典': 712, '禮': 712, '英': 709, '則': 707, '相': 706, '饒': 703, '𧗱': 699, '來': 693, '沛': 690, '從': 690, '𣈜': 685, '娘': 685, '衛': 676, '咍': 675, '未': 674, '𢧚': 669, '政': 667, '興': 663, '地': 657, '底': 653, '前': 652, '聖': 652, '見': 649, '路': 645, '京': 645, '船': 644, '與': 643, '多': 643, '保': 639, '卒': 637, '今': 632, '北': 632, '光': 632, '左': 631, '海': 630, '化': 627, '重': 627, '詔': 627, '萬': 625, '連': 620, '丕': 619, '餘': 619, '仁': 619, '罪': 617, '此': 616, '領': 611, '督': 610, '碎': 605, '皆': 604, '言': 603, '宋': 602, '復': 602, '林': 602, '鐄': 602, '𫽄': 601, '几': 599, '賜': 596, '香': 596, '金': 595, '處': 594, '封': 594, '心': 592, '奏': 592, '牢': 586, '𦋦': 584, '黄': 579, '冬': 579, '當': 578, '我': 577, '𢬣': 576, '殿': 575, '㝵': 574, '別': 574, '郎': 572, '皮': 571, '\U000f070b': 571, '神': 570, '然': 567, '侍': 567, '玉': 560, '位': 559, '塘': 559, '永': 558, '義': 558, '差': 556, '箕': 549, '𧡊': 547, '呐': 543, '占': 543, '𦝄': 543, '隊': 542, '親': 541, '法': 541, '治': 540, '君': 539, '營': 538, '死': 533, '強': 532, '常': 530, '翁': 528, '奉': 525, '𠬠': 519, '馬': 519, '還': 519, '夫': 512, '除': 503, '𨕭': 503, '陽': 503, '少': 502, '通': 502, '成': 498, '坤': 498, '會': 496, '每': 496, '敬': 496, '后': 492, '𠳒': 492, '和': 489, '吳': 489, '夏': 489, '福': 489, '回': 487, '油': 486, '才': 486, '即': 485, '没': 485, '𠓨': 483, '奴': 483, '杜': 482, '𫥨': 479, '調': 475, '順': 475, '鎮': 473, '作': 472, '襖': 467, '𦖑': 467, '何': 466, '矣': 463, '經': 463, '包': 463, '𠊚': 462, '風': 462, '右': 461, '宜': 461, '停': 460, '將': 458, '監': 454, '𠀧': 454, '試': 453, '戈': 447, '因': 445, '宫': 443, '台': 443, '旦': 442, '户': 442, '率': 441, '默': 441, '払': 441, '𡽫': 441, '李': 440, '奇': 439, '丁': 438, '院': 436, '廷': 434, '亦': 433, '祖': 433, '居': 433, '計': 432, '柴': 432, '范': 431, '漢': 430, '体': 430, '能': 429, '庒': 428, '眾': 428, '改': 427, '土': 426, '傳': 425, '信': 424, '排': 424, '職': 423, '或': 423, '忠': 421, '古': 420, '龍': 419, '坦': 419, '氏': 418, '唐': 416, '高': 415, '象': 414, '廣': 413, '傷': 412, '殺': 411, '小': 409, '滝': 408, '撑': 407, '景': 404, '朋': 404, '並': 404, '吝': 404, '過': 399, '尋': 399, '恩' ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT, WIDTH = 432, 48
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
MAX_LENGTH = data_handler.max_length
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 32

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(
    dataset.img_paths, 
    dataset.labels, 
    figsize = (15, 8),
    subplot_size = (2, 8),
    font_path = FONT_PATH
)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import Input, Embedding, Dense, GRU, Flatten
from layers import custom_cnn
EMBEDDING_DIM = 512
UNITS = 512

# %% [markdown]
# ## The CNN block

# %%
def FeaturesExtractor(imagenet_model=None, imagenet_output_layer=None, name='FeaturesExtractor'):
    # CNN block
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 3), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (2, 2)}, 

            # Last Conv blocks with 2x2 kernel but without no padding and pooling layer
            'block5': {'num_conv': 2, 'filters': 512, 'pool_size': None}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)
        
    # Reshape accordingly before adding output to RNN
    cnn_output = Dense(UNITS, name='cnn_output')(Flatten()(x))
    return tf.keras.Model(inputs=image_input, outputs=cnn_output, name=name)

# %% [markdown]
# ## The RNN block

# %%
def TextProcessor(features_shape, name='TextProcessor'):
    partial_seq_input = Input(shape=(MAX_LENGTH - 1,), dtype='int64', name='partial_caption')
    features_input = Input(shape=features_shape, name='image_features')
    rnn_output = GRU(UNITS, name='rnn_output')(
        Embedding(VOCAB_SIZE, EMBEDDING_DIM)(partial_seq_input), 
        initial_state = features_input
    )
    y_pred = Dense(VOCAB_SIZE, name='prediction')(rnn_output)
    return tf.keras.Model(inputs=[partial_seq_input, features_input], outputs=y_pred, name=name)

# %% [markdown]
# # Build the model

# %%
from models import get_imagenet_model, EarlyBindingCaptioner
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 3))
# imagenet_output_layer = 'block5_pool'
# imagenet_model.summary(line_length=100)

# %%
cnn_block = FeaturesExtractor(imagenet_model, imagenet_output_layer)
rnn_block = TextProcessor(cnn_block.output.shape[1:])
model = EarlyBindingCaptioner(cnn_block, rnn_block, data_handler)

# %%
cnn_block.summary(line_length=100)
print()
rnn_block.summary(line_length=100)
# Out:
# Model: "FeaturesExtractor"
# ____________________________________________________________________________________________________
#  Layer (type)                                Output Shape                            Param #
# ====================================================================================================
#  image (InputLayer)                          [(None, 432, 48, 3)]                    0
#
#  block1_conv1 (Conv2D)                       (None, 432, 48, 64)                     1792
#
#  block1_bn1 (BatchNormalization)             (None, 432, 48, 64)                     256
#
#  block1_relu1 (Activation)                   (None, 432, 48, 64)                     0
#
#  block1_pool (MaxPooling2D)                  (None, 216, 24, 64)                     0
#
#  block2_conv1 (Conv2D)                       (None, 216, 24, 128)                    73856
#
#  block2_bn1 (BatchNormalization)             (None, 216, 24, 128)                    512
#
#  block2_relu1 (Activation)                   (None, 216, 24, 128)                    0
#
#  block2_pool (MaxPooling2D)                  (None, 108, 12, 128)                    0
#
#  block3_conv1 (Conv2D)                       (None, 108, 12, 256)                    295168
#
#  block3_bn1 (BatchNormalization)             (None, 108, 12, 256)                    1024
#
#  block3_relu1 (Activation)                   (None, 108, 12, 256)                    0
#
#  block3_conv2 (Conv2D)                       (None, 108, 12, 256)                    590080
#
#  block3_bn2 (BatchNormalization)             (None, 108, 12, 256)                    1024
#
#  block3_relu2 (Activation)                   (None, 108, 12, 256)                    0
#
#  block3_pool (MaxPooling2D)                  (None, 54, 6, 256)                      0
#
#  block4_conv1 (Conv2D)                       (None, 54, 6, 512)                      1180160
#
#  block4_bn1 (BatchNormalization)             (None, 54, 6, 512)                      2048
#
#  block4_relu1 (Activation)                   (None, 54, 6, 512)                      0
#
#  block4_conv2 (Conv2D)                       (None, 54, 6, 512)                      2359808
#
#  block4_bn2 (BatchNormalization)             (None, 54, 6, 512)                      2048
#
#  block4_relu2 (Activation)                   (None, 54, 6, 512)                      0
#
#  block4_pool (MaxPooling2D)                  (None, 27, 3, 512)                      0
#
#  block5_conv1 (Conv2D)                       (None, 26, 2, 512)                      1049088
#
#  block5_bn1 (BatchNormalization)             (None, 26, 2, 512)                      2048
#
#  block5_relu1 (Activation)                   (None, 26, 2, 512)                      0
#
#  block5_conv2 (Conv2D)                       (None, 25, 1, 512)                      1049088
#
#  block5_bn2 (BatchNormalization)             (None, 25, 1, 512)                      2048
#
#  block5_relu2 (Activation)                   (None, 25, 1, 512)                      0
#
#  flatten (Flatten)                           (None, 12800)                           0
#
#  cnn_output (Dense)                          (None, 512)                             6554112
#
# ====================================================================================================
# Total params: 13,164,160
# Trainable params: 13,158,656
# Non-trainable params: 5,504
# ____________________________________________________________________________________________________
#
# Model: "TextProcessor"
# ____________________________________________________________________________________________________
#  Layer (type)                    Output Shape          Param #     Connected to
# ====================================================================================================
#  partial_caption (InputLayer)    [(None, 11)]          0           []
#
#  embedding (Embedding)           (None, 11, 512)       6744064     ['partial_caption[0][0]']
#
#  image_features (InputLayer)     [(None, 512)]         0           []
#
#  rnn_output (GRU)                (None, 512)           1575936     ['embedding[0][0]',
#                                                                     'image_features[0][0]']
#
#  prediction (Dense)              (None, 13172)         6757236     ['rnn_output[0][0]']
#
# ====================================================================================================
# Total params: 15,077,236
# Trainable params: 15,077,236
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
train_idxs = list(range(int(dataset.size * 0.8)))
valid_idxs = list(range(train_idxs[-1] + 1, dataset.size))
print('Number of training samples:', len(train_idxs))
print('Number of validate samples:', len(valid_idxs))
# Out:
# Number of training samples: 81226
# Number of validate samples: 20307

# %%
import random
random.seed(2022)
random.shuffle(train_idxs)

# When run on a small RAM machine, you can set use_cache=False to 
# not run out of memory but it will slow down the training speed
train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, drop_remainder=True)
valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, drop_remainder=True)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping_callback = EarlyStopping(
    monitor = 'val_loss', 
    min_delta = 1e-3, # Change that less than 1e-3, will count as no improvement
    patience = 5, # Stop if no improvement after 5 epochs
    restore_best_weights = True, # Restore weights from the epoch with the best value
    verbose = 1
)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Train the IHR-NomDB dataset

# %%
from losses import MaskedLoss
from metrics import SequenceAccuracy, CharacterAccuracy, LevenshteinDistance
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [ 
        SequenceAccuracy(), 
        CharacterAccuracy(),  
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)

# %%
# %%time
history = model.fit(
    train_tf_dataset,
    validation_data = valid_tf_dataset,
    epochs = EPOCHS,
    callbacks = [reduce_lr_callback, early_stopping_callback],
    verbose = 1
).history
# Out:
# Epoch 1/100
# 2538/2538 [==============================] - 387s 147ms/step - loss: 4.1320 - seq_acc: 2.7088e-04 - char_acc: 0.2319 - lev_distance: 0.7327 - val_loss: 4.1569 - val_seq_acc: 0.0000e+00 - val_char_acc: 0.2357 - val_lev_distance: 0.7501 - lr: 2.0000e-04
# Epoch 2/100
# 2538/2538 [==============================] - 363s 143ms/step - loss: 2.6687 - seq_acc: 0.0041 - char_acc: 0.3860 - lev_distance: 0.6045 - val_loss: 2.8283 - val_seq_acc: 2.9574e-04 - val_char_acc: 0.3695 - val_lev_distance: 0.6202 - lr: 2.0000e-04
# Epoch 3/100
# 2538/2538 [==============================] - 364s 143ms/step - loss: 1.5839 - seq_acc: 0.0318 - char_acc: 0.5766 - lev_distance: 0.4158 - val_loss: 2.0556 - val_seq_acc: 0.0022 - val_char_acc: 0.4839 - val_lev_distance: 0.5062 - lr: 2.0000e-04
# Epoch 4/100
# 2538/2538 [==============================] - 362s 143ms/step - loss: 0.9625 - seq_acc: 0.1110 - char_acc: 0.7170 - lev_distance: 0.2776 - val_loss: 1.6916 - val_seq_acc: 0.0108 - val_char_acc: 0.5394 - val_lev_distance: 0.4475 - lr: 2.0000e-04
# Epoch 5/100
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.6364 - seq_acc: 0.2105 - char_acc: 0.7957 - lev_distance: 0.2008 - val_loss: 1.5676 - val_seq_acc: 0.0197 - val_char_acc: 0.5760 - val_lev_distance: 0.4107 - lr: 2.0000e-04
# Epoch 6/100
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.4485 - seq_acc: 0.3100 - char_acc: 0.8448 - lev_distance: 0.1526 - val_loss: 1.6484 - val_seq_acc: 0.0182 - val_char_acc: 0.5684 - val_lev_distance: 0.4147 - lr: 2.0000e-04
# Epoch 7/100
# 2538/2538 [==============================] - 362s 143ms/step - loss: 0.3270 - seq_acc: 0.3991 - char_acc: 0.8791 - lev_distance: 0.1190 - val_loss: 1.4991 - val_seq_acc: 0.0365 - val_char_acc: 0.6021 - val_lev_distance: 0.3803 - lr: 2.0000e-04
# Epoch 8/100
# 2538/2538 [==============================] - 362s 143ms/step - loss: 0.2521 - seq_acc: 0.4755 - char_acc: 0.9031 - lev_distance: 0.0953 - val_loss: 1.4074 - val_seq_acc: 0.0578 - val_char_acc: 0.6302 - val_lev_distance: 0.3572 - lr: 2.0000e-04
# Epoch 9/100
# 2538/2538 [==============================] - 362s 143ms/step - loss: 0.1931 - seq_acc: 0.5551 - char_acc: 0.9231 - lev_distance: 0.0754 - val_loss: 1.2920 - val_seq_acc: 0.0590 - val_char_acc: 0.6396 - val_lev_distance: 0.3474 - lr: 2.0000e-04
# Epoch 10/100
# 2538/2538 [==============================] - 362s 142ms/step - loss: 0.1509 - seq_acc: 0.6185 - char_acc: 0.9376 - lev_distance: 0.0613 - val_loss: 1.3571 - val_seq_acc: 0.0606 - val_char_acc: 0.6419 - val_lev_distance: 0.3440 - lr: 2.0000e-04
# Epoch 11/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.1216 - seq_acc: 0.6745 - char_acc: 0.9496 - lev_distance: 0.0493
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 2538/2538 [==============================] - 362s 142ms/step - loss: 0.1215 - seq_acc: 0.6745 - char_acc: 0.9496 - lev_distance: 0.0493 - val_loss: 1.3298 - val_seq_acc: 0.0688 - val_char_acc: 0.6563 - val_lev_distance: 0.3319 - lr: 2.0000e-04
# Epoch 12/100
# 2538/2538 [==============================] - 362s 143ms/step - loss: 0.0504 - seq_acc: 0.8856 - char_acc: 0.9847 - lev_distance: 0.0149 - val_loss: 1.1977 - val_seq_acc: 0.1073 - val_char_acc: 0.6854 - val_lev_distance: 0.2968 - lr: 1.0000e-04
# Epoch 13/100
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.0255 - seq_acc: 0.9539 - char_acc: 0.9942 - lev_distance: 0.0056 - val_loss: 1.2486 - val_seq_acc: 0.1033 - val_char_acc: 0.6884 - val_lev_distance: 0.2938 - lr: 1.0000e-04
# Epoch 14/100
# 2538/2538 [==============================] - 365s 144ms/step - loss: 0.0249 - seq_acc: 0.9464 - char_acc: 0.9933 - lev_distance: 0.0065 - val_loss: 1.1369 - val_seq_acc: 0.1022 - val_char_acc: 0.6928 - val_lev_distance: 0.2909 - lr: 1.0000e-04
# Epoch 15/100
# 2538/2538 [==============================] - 364s 144ms/step - loss: 0.0211 - seq_acc: 0.9534 - char_acc: 0.9941 - lev_distance: 0.0057 - val_loss: 1.1405 - val_seq_acc: 0.1136 - val_char_acc: 0.6976 - val_lev_distance: 0.2876 - lr: 1.0000e-04
# Epoch 16/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0203 - seq_acc: 0.9533 - char_acc: 0.9941 - lev_distance: 0.0057
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2538/2538 [==============================] - 364s 143ms/step - loss: 0.0203 - seq_acc: 0.9533 - char_acc: 0.9941 - lev_distance: 0.0057 - val_loss: 1.2378 - val_seq_acc: 0.1146 - val_char_acc: 0.6979 - val_lev_distance: 0.2872 - lr: 1.0000e-04
# Epoch 17/100
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.0120 - seq_acc: 0.9824 - char_acc: 0.9978 - lev_distance: 0.0021 - val_loss: 1.2047 - val_seq_acc: 0.1174 - val_char_acc: 0.7031 - val_lev_distance: 0.2821 - lr: 5.0000e-05
# Epoch 18/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0073 - seq_acc: 0.9931 - char_acc: 0.9991 - lev_distance: 8.5785e-04
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.0073 - seq_acc: 0.9931 - char_acc: 0.9991 - lev_distance: 8.5785e-04 - val_loss: 1.1479 - val_seq_acc: 0.1352 - val_char_acc: 0.7149 - val_lev_distance: 0.2654 - lr: 5.0000e-05
# Epoch 19/100
# 2538/2538 [==============================] - ETA: 0s - loss: 0.0041 - seq_acc: 0.9991 - char_acc: 0.9999 - lev_distance: 1.2296e-04Restoring model weights from the end of the best epoch: 14.
# 2538/2538 [==============================] - 363s 143ms/step - loss: 0.0041 - seq_acc: 0.9991 - char_acc: 0.9999 - lev_distance: 1.2296e-04 - val_loss: 1.1826 - val_seq_acc: 0.1388 - val_char_acc: 0.7215 - val_lev_distance: 0.2632 - lr: 2.5000e-05
# Epoch 19: early stopping
# CPU times: total: 2h 27min 15s
# Wall time: 1h 55min 18s

# %% [markdown]
# ## Save the training results

# %%
best_epoch = early_stopping_callback.best_epoch
print(f'- Loss on validation\t: {history["val_loss"][best_epoch]}')
print(f'- Sequence accuracy\t: {history["val_seq_acc"][best_epoch]}')
print(f'- Character accuracy\t: {history["val_char_acc"][best_epoch]}')
print(f'- Levenshtein distance\t: {history["val_lev_distance"][best_epoch]}')
# Out:
# - Loss on validation	: 1.1368741989135742
# - Sequence accuracy	: 0.10217862576246262
# - Character accuracy	: 0.6927744150161743
# - Levenshtein distance	: 0.2908543646335602

# %%
from visualizer import plot_training_results
plot_training_results(history, f'{APPROACH_NAME}.png')
model.cnn_block.save_weights(f'{APPROACH_NAME}_cnn.h5')
model.rnn_block.save_weights(f'{APPROACH_NAME}_rnn.h5')

# %% [markdown]
# # Inference

# %%
cnn_block = FeaturesExtractor(imagenet_model, imagenet_output_layer)
rnn_block = TextProcessor(cnn_block.output.shape[1:])
cnn_block.load_weights(f'{APPROACH_NAME}_cnn.h5')
rnn_block.load_weights(f'{APPROACH_NAME}_rnn.h5')

# %%
reset_model = EarlyBindingCaptioner(cnn_block, rnn_block, data_handler)
reset_model.compile(
    optimizer = Adam(LEARNING_RATE), 
    loss = MaskedLoss(), 
    metrics = [
        SequenceAccuracy(),
        CharacterAccuracy(),
        LevenshteinDistance(normalize=True, name='lev_distance')
    ]
)
reset_model.evaluate(valid_tf_dataset)
# Out:
# 634/634 [==============================] - 52s 73ms/step - loss: 2.3252 - seq_acc: 0.1022 - char_acc: 0.6928 - lev_distance: 0.2909
# [0.10217862576246262,
#  0.6927744150161743,
#  0.2908543646335602,
#  1.1368741989135742]

# %% [markdown]
# ## On test dataset

# %%
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(2)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels = data_handler.tokens2texts(batch_tokens)
    pred_tokens = reset_model.predict(batch_images)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    
    visualize_images_labels(
        img_paths = dataset.img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        figsize = (14, 20),
        subplot_size = (4, 8),
        legend_loc = (3.8, 4.28),
        annotate_loc = (4, 1.8),
        font_path = FONT_PATH, 
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '㙋𡉖\U000f0b1f', 2: '噙𠿒', 3: '犝犠', 4: '鉸𨦀', 5: '爲䧺禮公而不委之以兵', 6: '爲䧺禮公而不委之以兵', 7: '是以聖帝明王之治天下', 8: '十一月戊子朔日有食之', 9: '以致敗人事者自古有之', 10: '不名以激年老之固位者', 11: '璉以是不平使人陰殺之', 12: '武郡公令人以象載之及', 13: '武郡公令人以象載之及', 14: '大而三綱五常之道以至', 15: '世人以不常見而異之殊', 16: '如先求皇子而立之以安', 17: '如先求皇子而立之以安', 18: '冬十一月帝得陳暠立之', 19: '中國之人不耐其水土也', 20: '首惡之名為人臣而不知', 21: '爲悅而不知其過之大也', 22: '帝位以副天下臣民之望', 23: '食之是月會試天下士人', 24: '十二月以誕日為建天節', 25: '春正月初二日上以大軍', 26: '取士之科不一而定三年', 27: '取之以賴其後故有是命', 28: '人守之百官進朝不得入', 29: '牧之民不足以煩中國也', 30: '罄家所有以奉事之冀其', 31: '土人以為灵異立祠事之', 32: '土人以為灵異立祠事之'}
# - Pred: {1: '括扑玠', 2: '哺𧋍', 3: '播播', 4: '敷𣌺', 5: '爲䧺禮公而不未之之公', 6: '爲䧺禮公而不念之之公', 7: '是以聖帝明王之正至類', 8: '十一月戊子納日有有有', 9: '以致則人居者昌有有有', 10: '不名以避山文之命命公', 11: '璉以是不平郡有有之公', 12: '武郡公小人以其愛其武', 13: '武郡公有有以及之其武', 14: '大而三臨五後之道之照', 15: '世人以不與見而以其其', 16: '如先求皇子而立立立民', 17: '如兄求皇子而立之又民', 18: '冬十一月帝得有之之有', 19: '中國之人不𦤶其天之也', 20: '首惡之不為人之有治尺', 21: '爲悅而不知其心不之之', 22: '常位以副天下立以去民', 23: '食之是月會試天一之為', 24: '十二月以謁四為一無為', 25: '春正月初二四上六六尺', 26: '取士之科不二而宅至', 27: '取之以略其後而有大為', 28: '人也之有官進則有有有', 29: '取之民不民以心而下有', 30: '讐家所有以或則僊豪有', 31: '土人以為甚異立而而公', 32: '土人以為甚異立下而公'}
#
# Batch 02:
# - True: {1: '武有等人才國家之元氣', 2: '詩曰共武之復以定王國', 3: '一節以全軍臣父子之義', 4: '年冬十二月以明字陳世', 5: '明帝以為近臣遇之甚厚', 6: '陳而不已也明帝納之五', 7: '以弱制強或攻人之不僃', 8: '之明其爲帝胄承大統也', 9: '献祥瑞以揜之而無一人', 10: '以岑州人民及土地㱕之', 11: '古今粗亦明聖人之道以', 12: '月以前楊日禮大定二年', 13: '冬十月丙戌望日有食之', 14: '鑄金為之有國十八葉也', 15: '以於八月十五日祗告天', 16: '三綱五常人之大倫太宗', 17: '杜欣等以學業不進之罪', 18: '迹其所為皆非人臣之法', 19: '冬十二月初八日以禮部', 20: '帝潜伏兵於甕隘以待之', 21: '𨿽用兵乃聖人之不得已', 22: '二十餘年之乱一旦削平', 23: '大夫仍以昭聖公主㱕之', 24: '一年之後六科給事中公', 25: '冬十月以誕日為壽天節', 26: '銘以昭先帝之業於來世', 27: '王数以亂臣賊子之罪乃', 28: '人以瓦礫投船而罵之者', 29: '有寃抑不達者撞之以聞', 30: '戊寅十一年三月以後少', 31: '大赦天下季税十分之一', 32: '冬十月以誕日為\U000f0191天節'}
# - Pred: {1: '武有至人才國家之之', 2: '詩曰共武之復以之之萌', 3: '一節以去軍臣之之之又', 4: '年未十二月以四二㱕遣', 5: '明帝以為犯臣避愛愛萌', 6: '陳而不已也此或滅已綱', 7: '以輕制強或攻人之之嗣', 8: '之明其爲帝胄或之輕㓂', 9: '献祥脆以𪮙之則被一為', 10: '以老以人民及之下措之', 11: '有今耶亦明聖有之之類', 12: '月以前楊日禮天天之', 13: '冬十月自戌二日九其入', 14: '鐵金為之有國天天之尺', 15: '以於八月十五九七在尺', 16: '三綱五肃人王去有又又', 17: '杜欣等以學業不之之', 18: '迹其則為皆也有天之照', 19: '冬十二月初八四以險服', 20: '帝潜伏兵於愛而而而公', 21: '懷用兵乃並人之之有附', 22: '二十餘年之長心四億尺', 23: '大之仍以相聖名下𡗶', 24: '一年之𭛁六冊一之晋尺', 25: '冬十月以謁四為為又為', 26: '戰以明先軍去黎於延也', 27: '王数以亂臣賊足之之尺', 28: '人以五極䏻遊而則之驕', 29: '有柬物不達者濫權無有', 30: '代寅十一年三八大之之', 31: '大赦天下季税于十之', 32: '冬十月以誕四為上又鎮'}

# %% [markdown]
# ## On random image

# %%
random_path = '../囷𦝄苔惮󰞺𧍋𦬑囊.jpg'
random_label = '囷𦝄苔惮󰞺𧍋𦬑囊'
random_image = data_handler.process_image(random_path)
pred_tokens = reset_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    font_path = FONT_PATH, 
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 囷𦝄苔筋闷𨑗󱁲𡗶羅
