# %%
# https://www.tensorflow.org/tutorials/text/image_captioning
# https://www.kaggle.com/code/dschettler8845/bms-image-captioning-w-attention-train
# https://github.com/tensorflow/models/tree/master/research/attention_ocr
# https://github.com/vuducnghia/attention-ocr
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')
APPROACH_NAME = 'ImageCaptioning'

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Data input pipeline

# %%
DATASET_DIR = r'../../Dataset/trdg'
LABELS_PATH = r'../../Dataset/trdg/labels.txt'
FONT_PATH = r'../../Dataset/NomNaTong-Regular.ttf'

# %% [markdown]
# ## Load and remove records with rare characters

# %%
from loader import DataImporter
dataset = DataImporter(DATASET_DIR, LABELS_PATH, min_length=6).remove_rare_chars(2)
print(dataset)
# Out:
# Number of images found: 4069
# Number of labels found: 4069
# Number of unique characters: 2033
# Characters present: {'浪': 308, '㐌': 304, '\U000f070b': 236, '朱': 234, '𠊛': 232, '\U000f047c': 215, '尼': 215, '娘': 206, '𢚸': 202, '固': 201, '吏': 201, '𦋦': 191, '拱': 180, '之': 163, '埃': 159, '群': 153, '𠳒': 150, '情': 147, '芇': 147, '買': 147, '別': 134, '欺': 125, '麻': 125, '𠓨': 124, '𠬠': 124, '仙': 120, '𡗶': 116, '爫': 116, '𧗱': 114, '花': 106, '𦖑': 105, '浽': 104, '𠄩': 102, '呐': 102, '命': 102, '渚': 101, '塘': 99, '饒': 98, '𠫾': 97, '些': 97, '渃': 97, '如': 96, '時': 95, '強': 94, '分': 93, '低': 92, '𡢐': 91, '傷': 91, '払': 91, '牢': 88, '𫽄': 85, '仍': 83, '咍': 82, '冲': 81, '昆': 81, '鐄': 81, '於': 80, '身': 79, '庒': 79, '生': 77, '𧡊': 77, '月': 76, '𢬣': 75, '𣈜': 75, '沛': 74, '調': 74, '茹': 74, '﨤': 72, '皮': 72, '油': 71, '\U000f061a': 71, '細': 71, '催': 70, '公': 70, '典': 70, '緣': 69, '畧': 68, '戈': 68, '碎': 67, '排': 67, '爲': 66, '𠁀': 64, '娥': 64, '\U000f02c7': 62, '包': 61, '共': 61, '貝': 59, '𢧚': 58, '㗂': 57, '恩': 57, '賒': 57, '𢪀': 56, '雲': 55, '迻': 55, '紅': 54, '特': 54, '世': 54, '𠳨': 54, '倍': 52, '耒': 52, '𥙩': 52, '空': 51, '頭': 50, '𫢩': 49, '唉': 49, '𦝄': 49, '女': 49, '\U000f0832': 49, '事': 48, '高': 48, '春': 48, '\U000f0833': 48, '柴': 47, '蹺': 47, '小': 47, '台': 47, '𠊚': 47, '自': 46, '茄': 46, '絲': 46, '𩄲': 46, '尋': 46, '車': 45, '才': 45, '䜹': 45, '翁': 45, '料': 45, '𧵆': 44, '𬂙': 44, '𨑮': 44, '童': 44, '初': 44, '𥪞': 44, '底': 43, '\U000f0803': 43, '香': 43, '吝': 43, '𠀧': 42, '外': 42, '𣇞': 42, '信': 41, '衝': 41, '明': 40, '𠇮': 40, '𡽫': 40, '姅': 40, '𡥵': 40, '𨀈': 39, '𠸜': 38, '𤾓': 38, '户': 38, '嗔': 38, '\U000f0761': 37, '嘆': 37, '連': 37, '𨕭': 37, '枚': 37, '師': 36, '匕': 36, '湄': 36, '徐': 36, '边': 36, '役': 36, '王': 36, '朝': 36, '𠓀': 36, '䀡': 35, '𨉓': 35, '功': 35, '它': 35, '㤕': 35, '坦': 35, '䏾': 35, '𢆥': 35, '𠸗': 35, '状': 35, '𥹰': 34, '泊': 34, '𠦳': 34, '云': 34, '𢖵': 34, '子': 33, '妬': 33, '几': 33, '\U000f0284': 33, '唭': 32, '敢': 32, '箕': 32, '悶': 32, '𢜠': 32, '𨔍': 32, '愁': 32, '歇': 32, '停': 32, '名': 31, '呂': 31, '蹎': 31, '矯': 31, '𦊚': 31, '𦰟': 31, '同': 31, '桃': 31, '撑': 31, '㝵': 30, '閉': 30, '風': 30, '意': 30, '易': 30, '\U000f07ba': 30, '\U000f0482': 30, '直': 30, '\U000f0993': 30, '旦': 30, '\U000f000e': 30, '体': 30, '元': 30, '没': 30, '𣃣': 29, '准': 29, '淡': 29, '安': 29, '添': 29, '苔': 29, '仕': 29, '坤': 29, '寔': 29, '\U000f0152': 29, '𡎢': 29, '吒': 29, '軍': 29, '𠰺': 29, '𤴬': 29, '隊': 29, '扵': 28, '謝': 28, '堂': 28, '家': 28, '𨅸': 28, '仃': 28, '逴': 28, '𠁑': 28, '𫳘': 28, '人': 27, '埋': 27, '吀': 27, '𤑟': 27, '𨱽': 27, '散': 27, '行': 26, '賖': 26, '補': 26, '哭': 26, '悲': 26, '𠲖': 26, '圭': 26, '𣅶': 26, '産': 26, '制': 26, '默': 26, '滝': 26, '𧘇': 26, '論': 25, '𠖈': 25, '玉': 25, '幅': 25, '𦀊': 25, '從': 25, '用': 25, '寃': 25, '𥢆': 25, '刼': 25, '辰': 24, '卢': 24, '法': 24, '差': 24, '天': 24, '本': 24, '扒': 24, '弹': 24, '梗': 24, '堆': 24, '𣦍': 24, '船': 24, '𥒥': 24, '\U000f03d9': 24, '湥': 24, '𡦂': 23, '東': 23, '詩': 23, '吹': 23, '哙': 23, '𠄼': 23, '計': 23, '𢭂': 23, '塊': 23, '知': 23, '併': 23, '𮎦': 23, '畨': 23, '歆': 23, '六': 23, '𣎀': 23, '𭛣': 22, '苦': 22, '𣳔': 22, '金': 22, '𥛉': 22, '𧵑': 22, '終': 22, '重': 22, '㛪': 22, '想': 22, '牟': 22, '楼': 22, '\U000f01fe': 22, '半': 22, '昂': 22, '更': 22, '聀': 22, '\U000f0607': 22, '盘': 21, '𣈙': 21, '魚': 21, '庄': 21, '潙': 21, '礼': 21, '阻': 21, '不': 21, '平': 21, '妾': 21, '清': 21, '𠹾': 21, '傕': 21, '𬌓': 21, '𫅷': 21, '移': 21, '親': 21, '容': 21, '舘': 21, '𬑉': 21, '珠': 21, '咹': 21, '媒': 21, '淶': 21, '𦓡': 21, '西': 20, '刀': 20, '及': 20, '𪟽': 20, '馭': 20, '丿': 20, '呌': 20, '沙': 20, '𤽗': 20, '干': 20, '奇': 20, '相': 20, '官': 20, '像': 20, '漢': 20, '客': 20, '待': 20, '塵': 20, '𫯳': 20, '𣷭': 20, '貞': 20, '𦹵': 20, '𠳐': 20, '𢴑': 20, '\U000f07ef': 20, '傳': 19, '神': 19, '\U000f0778': 19, '前': 19, '合': 19, '姐': 19, '𥆾': 19, '和': 19, '胣': 19, '武': 19, '柳': 19, '𨖲': 19, '病': 19, '招': 19, '\U000f0810': 19, '秩': 19, '𬖉': 19, '𡭧': 19, '陀': 19, '酉': 19, '𡛔': 18, '科': 18, '除': 18, '陣': 18, '芒': 18, '盃': 18, '老': 18, '迡': 18, '心': 18, '掣': 18, '落': 18, '妑': 18, '𠳚': 18, '脱': 18, '翹': 18, '𠖤': 18, '膓': 18, '𢝙': 18, '束': 18, '城': 17, '達': 17, '道': 17, '期': 17, '景': 17, '𢈱': 17, '𢜝': 17, '呵': 17, '君': 17, ' ...

# %% [markdown]
# ## Data constants and input pipeline

# %%
HEIGHT = 148
WIDTH = 32
PADDING_CHAR = '[PAD]' 
START_CHAR = '[START]'
END_CHAR = '[END]'

# %%
from loader import DataHandler
data_handler = DataHandler(
    dataset, 
    img_size = (HEIGHT, WIDTH), 
    padding_char = PADDING_CHAR,
    start_char = START_CHAR,
    end_char = END_CHAR
)

# %%
MAX_LENGTH = data_handler.max_length
PADDING_TOKEN = data_handler.padding_token
START_TOKEN = data_handler.start_token
END_TOKEN = data_handler.end_token
VOCAB_SIZE = data_handler.char2num.vocab_size()
BATCH_SIZE = 16

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
img_paths, labels = dataset.img_paths, dataset.labels 
visualize_images_labels(img_paths, labels, font_path=FONT_PATH, text_x=WIDTH + 3)

# %% [markdown]
# # Define model components

# %%
from tensorflow.keras.layers import (
    Input, Embedding, Dropout, Dense, GRU, 
    Concatenate, GlobalAveragePooling1D, 
)
from cnn import custom_cnn, get_imagenet_model, reshape_for_rnn
EMBEDDING_DIM = 512
UNITS = 1024

# %%
imagenet_model, imagenet_output_layer = None, None
# # Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 1))
# imagenet_output_layer = 'block4_pool'
# imagenet_model.summary(line_length=100)

# %% [markdown]
# ## The encoder

# %%
def CNN_Encoder(imagenet_model=None, imagenet_output_layer=None, name='CNN_encoder'):
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        features = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 1), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (1, 2)}, 
        }
        features = custom_cnn(conv_blocks_config, image_input)

    # Adding pixel coordinates to image features
    batch_size, h, w, _ = tf.shape(features)
    x, y = tf.meshgrid(tf.range(w), tf.range(h))
    w_loc = tf.one_hot(x, depth=w)
    h_loc = tf.one_hot(y, depth=h)
    loc = tf.concat([h_loc, w_loc], axis=2)
    loc = tf.tile(tf.expand_dims(loc, 0), multiples=[batch_size, 1, 1, 1])
    
    # (batch_size, height, width, num_features + coord)
    features = tf.concat([features, loc], axis=3) 
    features = reshape_for_rnn(features, dim_to_keep=1)
    return tf.keras.Model(inputs=image_input, outputs=features, name=name)

# %% [markdown]
# ## The attention head

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units, name='BahdanauAttention', **kwargs):
        super(BahdanauAttention, self).__init__(name=name)
        self.W1 = Dense(units)
        self.W2 = Dense(units)
        self.V = Dense(1)

    def call(self, features, hidden):
        # features(CNN_encoder output) shape == (batch_size, 17, encoder_channels)
        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # attention_hidden_layer shape == (batch_size, 17, units)
        attention_hidden_layer = self.W1(features) + self.W2(hidden_with_time_axis)
        attention_hidden_layer = tf.nn.tanh(attention_hidden_layer)

        # score shape == (batch_size, 17, 1)
        # This gives you an unnormalized score for each image feature.
        score = self.V(attention_hidden_layer)

        # attention_weights shape == (batch_size, 17, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, encoder_channels)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

# %% [markdown]
# ## The decoder

# %%
def RNN_Decoder(enc_output_shape, vocab_size, name='RNN_Decoder'):
    token_input = Input(shape=(1,), name='new_token')
    features_input = Input(shape=enc_output_shape, name='encoder_output')
    pre_hidden_input = Input(shape=(UNITS,), name='previous_state')
    
    # Defining attention as a separate model
    attention = BahdanauAttention(UNITS)
    context_vector, attention_weights = attention(features_input, pre_hidden_input)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = Concatenate(axis=-1, name='context_and_embedding')([
        tf.expand_dims(context_vector, 1), 
        Embedding(vocab_size, EMBEDDING_DIM)(token_input)
    ])
    
    # Passing the concatenated vector to the GRU
    rnn_output, state = GRU(
        units = UNITS, 
        return_state = True, 
        return_sequences = True, 
    )(x, initial_state=pre_hidden_input)

    x = Dropout(0.4)(rnn_output)
    x = Dense(UNITS, name='dense')(x)
    x = GlobalAveragePooling1D(name='average_pool')(x)
    y_pred = Dense(vocab_size, name='prediction')(x)

    return tf.keras.Model(
        inputs = [token_input, features_input, pre_hidden_input], 
        outputs = [y_pred, state, attention_weights],
        name = name
    )

# %% [markdown]
# # Customize `Model.fit `

# %%
class AttentionCRNN(tf.keras.Model):
    def __init__(self, encoder, decoder, name='AttentionCRNN'):
        super(AttentionCRNN, self).__init__(name=name)
        self.encoder = encoder
        self.decoder = decoder
    
    def get_config(self):
        return {
            'encoder': CNN_Encoder(imagenet_model, imagenet_output_layer), 
            'decoder': RNN_Decoder(self.encoder.output_shape[1:], VOCAB_SIZE)
        }
    
    @classmethod
    def from_config(cls, config):
        return cls(**config)

# %% [markdown]
# ## Custom training loop

# %%
@tf.function
def _compute_loss(self, batch):
    dec_input = tf.expand_dims([START_TOKEN] * BATCH_SIZE, 1) 
    hidden = tf.zeros((BATCH_SIZE, UNITS), tf.float32)

    batch_images, batch_tokens = batch
    features = self.encoder(batch_images)
    loss = tf.constant(0.0)

    for i in range(1, MAX_LENGTH):
        # Passing the features through the decoder
        preds, hidden, _ = self.decoder([dec_input, features, hidden])
        loss += self.loss(batch_tokens[:, i], preds) 
        
        # Use teacher forcing
        dec_input = tf.expand_dims(batch_tokens[:, i], 1) 
    
    # Update metrics
    predictions = self.predict(batch_images) 
    self.compiled_metrics.update_state(batch_tokens, predictions)
    
    display_result = {'loss': loss / MAX_LENGTH}
    display_result.update({m.name: m.result() for m in self.metrics})
    return loss, display_result

# %%
@tf.function
def train_step(self, batch):
    with tf.GradientTape() as tape:
        loss, display_result = self._compute_loss(batch)

    # Apply an optimization step
    gradients = tape.gradient(loss, self.trainable_variables)
    self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
    return display_result

@tf.function
def test_step(self, batch):
    _, display_result = self._compute_loss(batch)
    return display_result

# %% [markdown]
# ## Custom prediction

# %%
@tf.function
def predict(self, batch_images, return_attention=False):
    batch_size = batch_images.shape[0]
    new_tokens = tf.fill([batch_size, 1], START_TOKEN)
    result_tokens, attentions = [new_tokens], []

    hidden = tf.zeros((batch_size, UNITS), tf.float32)
    features = self.encoder(batch_images)
    done = tf.zeros([batch_size, 1], dtype=tf.bool)

    for _ in range(1, MAX_LENGTH):
        last_tokens = new_tokens
        preds, hidden, attention_weights = self.decoder([last_tokens, features, hidden])
        new_tokens = tf.expand_dims(tf.argmax(preds, axis=-1), 1) 

        # If a sequence produces an `END_TOKEN`, set it `done` after that
        done = done | (last_tokens == END_TOKEN)

        # Once a sequence is done it only produces PADDING_TOKEN
        new_tokens = tf.where(done, PADDING_TOKEN, new_tokens)
        result_tokens.append(new_tokens)

        attentions.append(attention_weights)
        if tf.executing_eagerly() and tf.reduce_all(done): break

    result_tokens = tf.concat(result_tokens, axis=-1)
    if return_attention: return result_tokens, tf.concat(attentions, axis=-1)
    return result_tokens

# %% [markdown]
# ## Summary

# %%
AttentionCRNN._compute_loss = _compute_loss
AttentionCRNN.train_step = train_step
AttentionCRNN.test_step = test_step
AttentionCRNN.predict = predict

# %%
encoder = CNN_Encoder(imagenet_model, imagenet_output_layer)
decoder = RNN_Decoder(encoder.output_shape[1:], VOCAB_SIZE)
model = AttentionCRNN(encoder, decoder)

# %%
encoder.summary(line_length=120)
print()
decoder.summary(line_length=125)
# Out:
# Model: "CNN_encoder"
# ________________________________________________________________________________________________________________________
#  Layer (type)                          Output Shape               Param #       Connected to
# ========================================================================================================================
#  image (InputLayer)                    [(None, 148, 32, 1)]       0             []
#
#  block1_conv1 (Conv2D)                 (None, 148, 32, 64)        640           ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)       (None, 148, 32, 64)        256           ['block1_conv1[0][0]']
#
#  block1_activation1 (LeakyReLU)        (None, 148, 32, 64)        0             ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)            (None, 74, 16, 64)         0             ['block1_activation1[0][0]']
#
#  block2_conv1 (Conv2D)                 (None, 74, 16, 128)        73856         ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)       (None, 74, 16, 128)        512           ['block2_conv1[0][0]']
#
#  block2_activation1 (LeakyReLU)        (None, 74, 16, 128)        0             ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)            (None, 37, 8, 128)         0             ['block2_activation1[0][0]']
#
#  block3_conv1 (Conv2D)                 (None, 37, 8, 256)         295168        ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)       (None, 37, 8, 256)         1024          ['block3_conv1[0][0]']
#
#  block3_activation1 (LeakyReLU)        (None, 37, 8, 256)         0             ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)                 (None, 37, 8, 256)         590080        ['block3_activation1[0][0]']
#
#  block3_bn2 (BatchNormalization)       (None, 37, 8, 256)         1024          ['block3_conv2[0][0]']
#
#  block3_activation2 (LeakyReLU)        (None, 37, 8, 256)         0             ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)            (None, 18, 4, 256)         0             ['block3_activation2[0][0]']
#
#  block4_conv1 (Conv2D)                 (None, 18, 4, 512)         1180160       ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)       (None, 18, 4, 512)         2048          ['block4_conv1[0][0]']
#
#  block4_activation1 (LeakyReLU)        (None, 18, 4, 512)         0             ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)                 (None, 18, 4, 512)         2359808       ['block4_activation1[0][0]']
#
#  block4_bn2 (BatchNormalization)       (None, 18, 4, 512)         2048          ['block4_conv2[0][0]']
#
#  block4_activation2 (LeakyReLU)        (None, 18, 4, 512)         0             ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)            (None, 18, 2, 512)         0             ['block4_activation2[0][0]']
#
#  final_conv (Conv2D)                   (None, 17, 1, 512)         1049088       ['block4_pool[0][0]']
#
#  final_bn (BatchNormalization)         (None, 17, 1, 512)         2048          ['final_conv[0][0]']
#
#  final_activation (LeakyReLU)          (None, 17, 1, 512)         0             ['final_bn[0][0]']
#
#  tf.compat.v1.shape (TFOpLambda)       (4,)                       0             ['final_activation[0][0]']
#
#  tf.__operators__.getitem_2 (SlicingOp  ()                        0             ['tf.compat.v1.shape[0][0]']
#  Lambda)
#
#  tf.__operators__.getitem_1 (SlicingOp  ()                        0             ['tf.compat.v1.shape[0][0]']
#  Lambda)
#
#  tf.range (TFOpLambda)                 (1,)                       0             ['tf.__operators__.getitem_2[0][0]']
#
#  tf.range_1 (TFOpLambda)               (17,)                      0             ['tf.__operators__.getitem_1[0][0]']
#
#  tf.meshgrid (TFOpLambda)              [(17, 1),                  0             ['tf.range[0][0]',
#                                         (17, 1)]                                 'tf.range_1[0][0]']
#
#  tf.one_hot_1 (TFOpLambda)             (17, 1, 17)                0             ['tf.meshgrid[0][1]',
#                                                                                  'tf.__operators__.getitem_1[0][0]']
#
#  tf.one_hot (TFOpLambda)               (17, 1, 1)                 0             ['tf.meshgrid[0][0]',
#                                                                                  'tf.__operators__.getitem_2[0][0]']
#
#  tf.concat (TFOpLambda)                (17, 1, 18)                0             ['tf.one_hot_1[0][0]',
#                                                                                  'tf.one_hot[0][0]']
#
#  tf.expand_dims (TFOpLambda)           (1, 17, 1, 18)             0             ['tf.concat[0][0]']
#
#  tf.__operators__.getitem (SlicingOpLa  ()                        0             ['tf.compat.v1.shape[0][0]']
#  mbda)
#
#  tf.tile (TFOpLambda)                  (None, 17, 1, 18)          0             ['tf.expand_dims[0][0]',
#                                                                                  'tf.__operators__.getitem[0][0]']
#
#  tf.concat_1 (TFOpLambda)              (None, 17, 1, 530)         0             ['final_activation[0][0]',
#                                                                                  'tf.tile[0][0]']
#
#  rnn_input (Reshape)                   (None, 17, 530)            0             ['tf.concat_1[0][0]']
#
# ========================================================================================================================
# Total params: 5,557,760
# Trainable params: 5,553,280
# Non-trainable params: 4,480
# ________________________________________________________________________________________________________________________
#
# Model: "RNN_Decoder"
# _____________________________________________________________________________________________________________________________
#  Layer (type)                            Output Shape               Param #        Connected to
# =============================================================================================================================
#  encoder_output (InputLayer)             [(None, 17, 530)]          0              []
#
#  previous_state (InputLayer)             [(None, 1024)]             0              []
#
#  BahdanauAttention (BahdanauAttention)   ((None, 530),              1594369        ['encoder_output[0][0]',
#                                           (None, 17, 1))                            'previous_state[0][0]']
#
#  new_token (InputLayer)                  [(None, 1)]                0              []
#
#  tf.expand_dims_1 (TFOpLambda)           (None, 1, 530)             0              ['BahdanauAttention[0][0]']
#
#  embedding (Embedding)                   (None, 1, 512)             1042944        ['new_token[0][0]']
#
#  context_and_embedding (Concatenate)     (None, 1, 1042)            0              ['tf.expand_dims_1[0][0]',
#                                                                                     'embedding[0][0]']
#
#  gru (GRU)                               [(None, 1, 1024),          6352896        ['context_and_embedding[0][0]',
#                                           (None, 1024)]                             'previous_state[0][0]']
#
#  dropout (Dropout)                       (None, 1, 1024)            0              ['gru[0][0]']
#
#  dense (Dense)                           (None, 1, 1024)            1049600        ['dropout[0][0]']
#
#  average_pool (GlobalAveragePooling1D)   (None, 1024)               0              ['dense[0][0]']
#
#  prediction (Dense)                      (None, 2037)               2087925        ['average_pool[0][0]']
#
# =============================================================================================================================
# Total params: 12,127,734
# Trainable params: 12,127,734
# Non-trainable params: 0
# _____________________________________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
from tensorflow.keras.optimizers import Adam
from kfold import kfold_decorator
from metrics import MeanEditDistance
from losses import MaskedLoss

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from callbacks import EarlyStoppingWithStuck
LEARNING_RATE = 2e-4
EPOCHS = 100

# %% [markdown]
# ## Callbacks

# %%
stuck_str = 'epoch > 15 and val_loss > 4'
early_stopping_callback = EarlyStoppingWithStuck(patience=5, stuck_str=stuck_str)

def scheduler(epoch, lr):
    if epoch < 1 or (epoch % 5) > 0: return lr # Keeps lr for each 5 epochs
    return lr * tf.math.exp(-0.2) # Decreases it exponentially after that
schedule_lr_callback = LearningRateScheduler(scheduler, verbose=1)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 3, # Reduce if no improvement after 3 epochs
    min_lr = 1e-6, # Lower bound on the learning rate 
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Cross validation with K-Fold

# %%
@kfold_decorator(n_splits=10, random_state=2022, is_subclassed_model=True)
def train(model, img_paths, labels, train_idxs=None, valid_idxs=None):
    train_tf_dataset = data_handler.prepare_tf_dataset(train_idxs, BATCH_SIZE, True)
    valid_tf_dataset = data_handler.prepare_tf_dataset(valid_idxs, BATCH_SIZE, True)
    
    model.compile(
        optimizer = Adam(learning_rate=LEARNING_RATE), 
        loss = MaskedLoss(PADDING_TOKEN), 
        metrics = [MeanEditDistance(PADDING_TOKEN)]
    )
    history = model.fit(
        train_tf_dataset,
        validation_data = valid_tf_dataset,
        epochs = EPOCHS,
        callbacks = [
            early_stopping_callback,
            reduce_lr_callback, 
#             schedule_lr_callback, 
        ],
        verbose = 1
    ).history
    return valid_tf_dataset, early_stopping_callback.best_epoch, history, model

# %%
# %%time
valid_datasets, best_epochs, histories, models = train(model, img_paths, labels)
# Out:
# ============== Fold 01 training ==============
# Epoch 1/100
# 228/228 [==============================] - 25s 61ms/step - loss: 5.4166 - edist: 8.0692 - val_loss: 5.0122 - val_edist: 7.8528 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 11s 50ms/step - loss: 5.0526 - edist: 7.3132 - val_loss: 4.8168 - val_edist: 7.1118 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.8391 - edist: 7.4181 - val_loss: 4.6961 - val_edist: 7.4685 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.6269 - edist: 7.1402 - val_loss: 4.6344 - val_edist: 6.8854 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.4510 - edist: 6.9942 - val_loss: 4.6353 - val_edist: 7.0936 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.2712 - edist: 6.8289 - val_loss: 4.7386 - val_edist: 6.8430 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.0842 - edist: 6.8100 - val_loss: 4.6323 - val_edist: 6.7545 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.8408 - edist: 6.6730 - val_loss: 4.5168 - val_edist: 6.5708 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.5405 - edist: 6.5867 - val_loss: 4.3499 - val_edist: 6.6207 - lr: 2.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.1419 - edist: 6.0359 - val_loss: 4.0970 - val_edist: 6.1543 - lr: 2.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 51ms/step - loss: 2.5635 - edist: 5.3806 - val_loss: 3.5315 - val_edist: 5.3930 - lr: 2.0000e-04
# Epoch 12/100
# 228/228 [==============================] - 12s 51ms/step - loss: 1.8317 - edist: 3.3132 - val_loss: 2.6488 - val_edist: 4.3144 - lr: 2.0000e-04
# Epoch 13/100
# 228/228 [==============================] - 12s 51ms/step - loss: 1.0102 - edist: 1.7120 - val_loss: 1.8082 - val_edist: 3.2065 - lr: 2.0000e-04
# Epoch 14/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.4729 - edist: 0.5636 - val_loss: 1.4131 - val_edist: 2.5437 - lr: 2.0000e-04
# Epoch 15/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.2048 - edist: 0.2420 - val_loss: 1.1297 - val_edist: 2.1532 - lr: 2.0000e-04
# Epoch 16/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.1101 - edist: 0.0987 - val_loss: 1.0744 - val_edist: 2.0661 - lr: 2.0000e-04
# Epoch 17/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0959 - edist: 0.1500 - val_loss: 1.3577 - val_edist: 2.4738 - lr: 2.0000e-04
# Epoch 18/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0719 - edist: 0.5300 - val_loss: 2.6916 - val_edist: 3.9857 - lr: 2.0000e-04
# Epoch 19/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.1189 - edist: 0.1506 - val_loss: 1.0129 - val_edist: 2.0284 - lr: 2.0000e-04
# Epoch 20/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0425 - edist: 0.0171 - val_loss: 0.8791 - val_edist: 1.6983 - lr: 2.0000e-04
# Epoch 21/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0244 - edist: 4.6253e-05 - val_loss: 1.0620 - val_edist: 1.6739 - lr: 2.0000e-04
# Epoch 22/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0183 - edist: 0.0156 - val_loss: 0.8694 - val_edist: 1.6986 - lr: 2.0000e-04
# Epoch 23/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0181 - edist: 0.0625 - val_loss: 0.7813 - val_edist: 1.5169 - lr: 2.0000e-04
# Epoch 24/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0086 - edist: 1.9083e-06 - val_loss: 0.8159 - val_edist: 1.6071 - lr: 2.0000e-04
# Epoch 25/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0650 - edist: 0.0547 - val_loss: 1.0617 - val_edist: 1.9291 - lr: 2.0000e-04
# Epoch 26/100
# 227/228 [============================>.] - ETA: 0s - loss: 0.0918 - edist: 0.3141
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0917 - edist: 0.2196 - val_loss: 0.9827 - val_edist: 1.8696 - lr: 2.0000e-04
# Epoch 27/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0274 - edist: 2.0123e-04 - val_loss: 0.6464 - val_edist: 1.3455 - lr: 1.0000e-04
# Epoch 28/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0085 - edist: 2.3842e-07 - val_loss: 0.6388 - val_edist: 1.2444 - lr: 1.0000e-04
# Epoch 29/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0050 - edist: 2.1684e-19 - val_loss: 0.6274 - val_edist: 1.2322 - lr: 1.0000e-04
# Epoch 30/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0035 - edist: 0.0000e+00 - val_loss: 0.5893 - val_edist: 1.2011 - lr: 1.0000e-04
# Epoch 31/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0024 - edist: 0.0000e+00 - val_loss: 0.5787 - val_edist: 1.1753 - lr: 1.0000e-04
# Epoch 32/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0020 - edist: 0.0000e+00 - val_loss: 0.5727 - val_edist: 1.1308 - lr: 1.0000e-04
# Epoch 33/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0017 - edist: 0.0000e+00 - val_loss: 0.5710 - val_edist: 1.1164 - lr: 1.0000e-04
# Epoch 34/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0015 - edist: 0.0000e+00 - val_loss: 0.5713 - val_edist: 1.1146 - lr: 1.0000e-04
# Epoch 35/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0013 - edist: 0.0000e+00 - val_loss: 0.5708 - val_edist: 1.0849 - lr: 1.0000e-04
# Epoch 36/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0011 - edist: 0.0000e+00 - val_loss: 0.5706 - val_edist: 1.0876 - lr: 1.0000e-04
# Epoch 37/100
# 228/228 [==============================] - 12s 51ms/step - loss: 9.3934e-04 - edist: 0.0000e+00 - val_loss: 0.5697 - val_edist: 1.0847 - lr: 1.0000e-04
# Epoch 38/100
# 228/228 [==============================] - 12s 51ms/step - loss: 8.1493e-04 - edist: 0.0000e+00 - val_loss: 0.5685 - val_edist: 1.0840 - lr: 1.0000e-04
# Epoch 39/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.1029e-04 - edist: 0.0000e+00 - val_loss: 0.5659 - val_edist: 1.0800 - lr: 1.0000e-04
# Epoch 40/100
# 228/228 [==============================] - 12s 52ms/step - loss: 6.2244e-04 - edist: 0.0000e+00 - val_loss: 0.5629 - val_edist: 1.0765 - lr: 1.0000e-04
# Epoch 41/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.4820e-04 - edist: 0.0000e+00 - val_loss: 0.5593 - val_edist: 1.0612 - lr: 1.0000e-04
# Epoch 42/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.8479e-04 - edist: 0.0000e+00 - val_loss: 0.5554 - val_edist: 1.0609 - lr: 1.0000e-04
# Epoch 43/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.3002e-04 - edist: 0.0000e+00 - val_loss: 0.5509 - val_edist: 1.0609 - lr: 1.0000e-04
# Epoch 44/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.8252e-04 - edist: 0.0000e+00 - val_loss: 0.5462 - val_edist: 1.0608 - lr: 1.0000e-04
# Epoch 45/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.4107e-04 - edist: 0.0000e+00 - val_loss: 0.5415 - val_edist: 1.0528 - lr: 1.0000e-04
# Epoch 46/100
# 228/228 [==============================] - 12s 51ms/step - loss: 3.0472e-04 - edist: 0.0000e+00 - val_loss: 0.5373 - val_edist: 1.0449 - lr: 1.0000e-04
# Epoch 47/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.7253e-04 - edist: 0.0000e+00 - val_loss: 0.5332 - val_edist: 1.0448 - lr: 1.0000e-04
# Epoch 48/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.4392e-04 - edist: 0.0000e+00 - val_loss: 0.5294 - val_edist: 1.0448 - lr: 1.0000e-04
# Epoch 49/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.1849e-04 - edist: 0.0000e+00 - val_loss: 0.5255 - val_edist: 1.0082 - lr: 1.0000e-04
# Epoch 50/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.9573e-04 - edist: 0.0000e+00 - val_loss: 0.5221 - val_edist: 1.0080 - lr: 1.0000e-04
# Epoch 51/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.7530e-04 - edist: 0.0000e+00 - val_loss: 0.5189 - val_edist: 1.0002 - lr: 1.0000e-04
# Epoch 52/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.5703e-04 - edist: 0.0000e+00 - val_loss: 0.5164 - val_edist: 1.0000 - lr: 1.0000e-04
# Epoch 53/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.4057e-04 - edist: 0.0000e+00 - val_loss: 0.5141 - val_edist: 1.0000 - lr: 1.0000e-04
# Epoch 54/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.2574e-04 - edist: 0.0000e+00 - val_loss: 0.5123 - val_edist: 0.9684 - lr: 1.0000e-04
# Epoch 55/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.1237e-04 - edist: 0.0000e+00 - val_loss: 0.5107 - val_edist: 0.9683 - lr: 1.0000e-04
# Epoch 56/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.0036e-04 - edist: 0.0000e+00 - val_loss: 0.5097 - val_edist: 0.9653 - lr: 1.0000e-04
# Epoch 57/100
# 228/228 [==============================] - 12s 52ms/step - loss: 8.9546e-05 - edist: 0.0000e+00 - val_loss: 0.5086 - val_edist: 0.9653 - lr: 1.0000e-04
# Epoch 58/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.9815e-05 - edist: 0.0000e+00 - val_loss: 0.5078 - val_edist: 0.9575 - lr: 1.0000e-04
# Epoch 59/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.1082e-05 - edist: 0.0000e+00 - val_loss: 0.5068 - val_edist: 0.9428 - lr: 1.0000e-04
# Epoch 60/100
# 228/228 [==============================] - 12s 52ms/step - loss: 6.3249e-05 - edist: 0.0000e+00 - val_loss: 0.5061 - val_edist: 0.9428 - lr: 1.0000e-04
# Epoch 61/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.6235e-05 - edist: 0.0000e+00 - val_loss: 0.5055 - val_edist: 0.9425 - lr: 1.0000e-04
# Epoch 62/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.9961e-05 - edist: 0.0000e+00 - val_loss: 0.5051 - val_edist: 0.9346 - lr: 1.0000e-04
# Epoch 63/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4352e-05 - edist: 0.0000e+00 - val_loss: 0.5046 - val_edist: 0.9346 - lr: 1.0000e-04
# Epoch 64/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.9353e-05 - edist: 0.0000e+00 - val_loss: 0.5039 - val_edist: 0.9033 - lr: 1.0000e-04
# Epoch 65/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.4908e-05 - edist: 0.0000e+00 - val_loss: 0.5032 - val_edist: 0.8722 - lr: 1.0000e-04
# Epoch 66/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.0955e-05 - edist: 0.0000e+00 - val_loss: 0.5025 - val_edist: 0.8639 - lr: 1.0000e-04
# Epoch 67/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.7444e-05 - edist: 0.0000e+00 - val_loss: 0.5015 - val_edist: 0.8615 - lr: 1.0000e-04
# Epoch 68/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.4329e-05 - edist: 0.0000e+00 - val_loss: 0.5002 - val_edist: 0.8292 - lr: 1.0000e-04
# Epoch 69/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.1571e-05 - edist: 0.0000e+00 - val_loss: 0.4989 - val_edist: 0.8287 - lr: 1.0000e-04
# Epoch 70/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.9128e-05 - edist: 0.0000e+00 - val_loss: 0.4975 - val_edist: 0.8282 - lr: 1.0000e-04
# Epoch 71/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.6963e-05 - edist: 0.0000e+00 - val_loss: 0.4959 - val_edist: 0.8126 - lr: 1.0000e-04
# Epoch 72/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.5050e-05 - edist: 0.0000e+00 - val_loss: 0.4942 - val_edist: 0.8126 - lr: 1.0000e-04
# Epoch 73/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.3354e-05 - edist: 0.0000e+00 - val_loss: 0.4924 - val_edist: 0.7735 - lr: 1.0000e-04
# Epoch 74/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.1853e-05 - edist: 0.0000e+00 - val_loss: 0.4905 - val_edist: 0.7423 - lr: 1.0000e-04
# Epoch 75/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.0523e-05 - edist: 0.0000e+00 - val_loss: 0.4885 - val_edist: 0.7423 - lr: 1.0000e-04
# Epoch 76/100
# 228/228 [==============================] - 12s 52ms/step - loss: 9.3463e-06 - edist: 0.0000e+00 - val_loss: 0.4866 - val_edist: 0.7428 - lr: 1.0000e-04
# Epoch 77/100
# 228/228 [==============================] - 12s 53ms/step - loss: 8.3024e-06 - edist: 0.0000e+00 - val_loss: 0.4846 - val_edist: 0.7428 - lr: 1.0000e-04
# Epoch 78/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.3758e-06 - edist: 0.0000e+00 - val_loss: 0.4824 - val_edist: 0.7427 - lr: 1.0000e-04
# Epoch 79/100
# 228/228 [==============================] - 12s 53ms/step - loss: 6.5546e-06 - edist: 0.0000e+00 - val_loss: 0.4800 - val_edist: 0.7730 - lr: 1.0000e-04
# Epoch 80/100
# 228/228 [==============================] - 12s 53ms/step - loss: 5.8253e-06 - edist: 0.0000e+00 - val_loss: 0.4777 - val_edist: 0.7730 - lr: 1.0000e-04
# Epoch 81/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.1788e-06 - edist: 0.0000e+00 - val_loss: 0.4754 - val_edist: 0.7730 - lr: 1.0000e-04
# Epoch 82/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.6046e-06 - edist: 0.0000e+00 - val_loss: 0.4729 - val_edist: 0.7730 - lr: 1.0000e-04
# Epoch 83/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0943e-06 - edist: 0.0000e+00 - val_loss: 0.4707 - val_edist: 0.8043 - lr: 1.0000e-04
# Epoch 84/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.6415e-06 - edist: 0.0000e+00 - val_loss: 0.4679 - val_edist: 0.8043 - lr: 1.0000e-04
# Epoch 85/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.2387e-06 - edist: 0.0000e+00 - val_loss: 0.4655 - val_edist: 0.7964 - lr: 1.0000e-04
# Epoch 86/100
# 228/228 [==============================] - 12s 54ms/step - loss: 2.8820e-06 - edist: 0.0000e+00 - val_loss: 0.4630 - val_edist: 0.7972 - lr: 1.0000e-04
# Epoch 87/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.5636e-06 - edist: 0.0000e+00 - val_loss: 0.4607 - val_edist: 0.7972 - lr: 1.0000e-04
# Epoch 88/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.2812e-06 - edist: 0.0000e+00 - val_loss: 0.4583 - val_edist: 0.7815 - lr: 1.0000e-04
# Epoch 89/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.0301e-06 - edist: 0.0000e+00 - val_loss: 0.4559 - val_edist: 0.7805 - lr: 1.0000e-04
# Epoch 90/100
# 228/228 [==============================] - 12s 51ms/step - loss: 1.8072e-06 - edist: 0.0000e+00 - val_loss: 0.4534 - val_edist: 0.7802 - lr: 1.0000e-04
# Epoch 91/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.6085e-06 - edist: 0.0000e+00 - val_loss: 0.4513 - val_edist: 0.7484 - lr: 1.0000e-04
# Epoch 92/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.4324e-06 - edist: 0.0000e+00 - val_loss: 0.4493 - val_edist: 0.7484 - lr: 1.0000e-04
# Epoch 93/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.2759e-06 - edist: 0.0000e+00 - val_loss: 0.4471 - val_edist: 0.7496 - lr: 1.0000e-04
# Epoch 94/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.1369e-06 - edist: 0.0000e+00 - val_loss: 0.4454 - val_edist: 0.7496 - lr: 1.0000e-04
# Epoch 95/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.0134e-06 - edist: 0.0000e+00 - val_loss: 0.4438 - val_edist: 0.7496 - lr: 1.0000e-04
# Epoch 96/100
# 228/228 [==============================] - 12s 52ms/step - loss: 9.0321e-07 - edist: 0.0000e+00 - val_loss: 0.4422 - val_edist: 0.7496 - lr: 1.0000e-04
# Epoch 97/100
# 228/228 [==============================] - 12s 52ms/step - loss: 8.0583e-07 - edist: 0.0000e+00 - val_loss: 0.4408 - val_edist: 0.7486 - lr: 1.0000e-04
# Epoch 98/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.1894e-07 - edist: 0.0000e+00 - val_loss: 0.4389 - val_edist: 0.7486 - lr: 1.0000e-04
# Epoch 99/100
# 228/228 [==============================] - 12s 52ms/step - loss: 6.4164e-07 - edist: 0.0000e+00 - val_loss: 0.4373 - val_edist: 0.7330 - lr: 1.0000e-04
# Epoch 100/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.7365e-07 - edist: 0.0000e+00 - val_loss: 0.4357 - val_edist: 0.7321 - lr: 1.0000e-04
# ============== Fold 02 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 63ms/step - loss: 5.4144 - edist: 8.0347 - val_loss: 5.0268 - val_edist: 7.9761 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.0786 - edist: 7.6094 - val_loss: 4.9448 - val_edist: 7.8329 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.9257 - edist: 7.0959 - val_loss: 4.8129 - val_edist: 7.4115 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.7267 - edist: 7.0013 - val_loss: 4.6827 - val_edist: 7.0289 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.5372 - edist: 7.1557 - val_loss: 4.6547 - val_edist: 7.1243 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.3918 - edist: 7.0199 - val_loss: 4.6497 - val_edist: 7.1824 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.2658 - edist: 6.8874 - val_loss: 4.6246 - val_edist: 7.0936 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.1422 - edist: 7.0038 - val_loss: 4.6700 - val_edist: 7.1948 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.9775 - edist: 7.1883 - val_loss: 4.6688 - val_edist: 7.4294 - lr: 2.0000e-04
# Epoch 10/100
# 228/228 [==============================] - ETA: 0s - loss: 3.8247 - edist: 6.9884
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 53ms/step - loss: 3.8254 - edist: 6.9884 - val_loss: 4.6653 - val_edist: 7.1401 - lr: 2.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.6025 - edist: 6.9887 - val_loss: 4.6467 - val_edist: 7.0026 - lr: 1.0000e-04
# Epoch 12/100
# 228/228 [==============================] - 12s 54ms/step - loss: 3.4735 - edist: 6.7847 - val_loss: 4.8258 - val_edist: 7.0239 - lr: 1.0000e-04
# Early stopping and restored the model weights from the end of epoch 7 - val_loss: 4.624600887298584
#
# ============== Fold 03 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 64ms/step - loss: 5.3962 - edist: 8.0240 - val_loss: 4.7523 - val_edist: 7.5920 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.9448 - edist: 7.2935 - val_loss: 4.5339 - val_edist: 6.8317 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.7588 - edist: 6.9012 - val_loss: 4.4147 - val_edist: 6.6488 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.5712 - edist: 7.0672 - val_loss: 4.3427 - val_edist: 6.9205 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.4242 - edist: 7.1458 - val_loss: 4.3360 - val_edist: 6.9093 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.2962 - edist: 6.9752 - val_loss: 4.3520 - val_edist: 6.9690 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.1610 - edist: 6.9477 - val_loss: 4.3927 - val_edist: 6.6358 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - ETA: 0s - loss: 3.9960 - edist: 6.8894
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 53ms/step - loss: 3.9962 - edist: 6.8894 - val_loss: 4.5337 - val_edist: 6.5990 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.7570 - edist: 6.9349 - val_loss: 4.5476 - val_edist: 6.5511 - lr: 1.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.6102 - edist: 6.7675 - val_loss: 4.6187 - val_edist: 6.6437 - lr: 1.0000e-04
# Early stopping and restored the model weights from the end of epoch 5 - val_loss: 4.336042881011963
#
# ============== Fold 04 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 62ms/step - loss: 5.4239 - edist: 8.0525 - val_loss: 5.3363 - val_edist: 8.0853 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.9979 - edist: 7.5337 - val_loss: 5.0993 - val_edist: 7.6970 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.7871 - edist: 6.9228 - val_loss: 4.9748 - val_edist: 7.2293 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.5973 - edist: 6.8949 - val_loss: 4.9107 - val_edist: 7.0803 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4506 - edist: 7.0786 - val_loss: 4.8871 - val_edist: 7.2520 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.3048 - edist: 6.8840 - val_loss: 4.9228 - val_edist: 7.0344 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.1535 - edist: 6.9738 - val_loss: 5.1123 - val_edist: 7.1010 - lr: 2.0000e-04
# Epoch 8/100
# 227/228 [============================>.] - ETA: 0s - loss: 3.9906 - edist: 6.9776
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 3.9898 - edist: 6.9263 - val_loss: 5.1015 - val_edist: 7.0450 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.7607 - edist: 6.9513 - val_loss: 5.1613 - val_edist: 7.1530 - lr: 1.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.6363 - edist: 6.9837 - val_loss: 5.0830 - val_edist: 7.0547 - lr: 1.0000e-04
# Early stopping and restored the model weights from the end of epoch 5 - val_loss: 4.8871169090271
#
# ============== Fold 05 training ==============
# Epoch 1/100
# 228/228 [==============================] - 22s 61ms/step - loss: 5.3794 - edist: 7.9723 - val_loss: 5.2550 - val_edist: 7.1884 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.9826 - edist: 7.5819 - val_loss: 5.1147 - val_edist: 7.1118 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.7741 - edist: 7.0187 - val_loss: 5.0486 - val_edist: 7.0630 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.5777 - edist: 7.1930 - val_loss: 4.9921 - val_edist: 7.3475 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.4183 - edist: 7.1734 - val_loss: 5.0738 - val_edist: 7.2054 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.2595 - edist: 7.0629 - val_loss: 5.0393 - val_edist: 7.2553 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - ETA: 0s - loss: 4.0602 - edist: 6.9106
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0603 - edist: 6.9106 - val_loss: 5.0910 - val_edist: 7.2992 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.7853 - edist: 6.7860 - val_loss: 4.8210 - val_edist: 6.9689 - lr: 1.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.5880 - edist: 6.7523 - val_loss: 4.8817 - val_edist: 7.0175 - lr: 1.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.3759 - edist: 6.6986 - val_loss: 4.6878 - val_edist: 6.8254 - lr: 1.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.1403 - edist: 6.3358 - val_loss: 4.6931 - val_edist: 6.8909 - lr: 1.0000e-04
# Epoch 12/100
# 228/228 [==============================] - 12s 51ms/step - loss: 2.8605 - edist: 6.2010 - val_loss: 4.3103 - val_edist: 6.3338 - lr: 1.0000e-04
# Epoch 13/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.5107 - edist: 5.4372 - val_loss: 4.0653 - val_edist: 6.1556 - lr: 1.0000e-04
# Epoch 14/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.1060 - edist: 4.7975 - val_loss: 3.7136 - val_edist: 5.6392 - lr: 1.0000e-04
# Epoch 15/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.6168 - edist: 3.4732 - val_loss: 3.0808 - val_edist: 5.1745 - lr: 1.0000e-04
# Epoch 16/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.0773 - edist: 2.2683 - val_loss: 2.4348 - val_edist: 4.0138 - lr: 1.0000e-04
# Epoch 17/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.7130 - edist: 1.8065 - val_loss: 2.0750 - val_edist: 3.3305 - lr: 1.0000e-04
# Epoch 18/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.4545 - edist: 1.1651 - val_loss: 1.7402 - val_edist: 2.7758 - lr: 1.0000e-04
# Epoch 19/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.2785 - edist: 0.4662 - val_loss: 1.5979 - val_edist: 2.5019 - lr: 1.0000e-04
# Epoch 20/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.2026 - edist: 0.1400 - val_loss: 1.4328 - val_edist: 2.2925 - lr: 1.0000e-04
# Epoch 21/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1515 - edist: 0.0683 - val_loss: 1.2734 - val_edist: 2.1106 - lr: 1.0000e-04
# Epoch 22/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1004 - edist: 0.0044 - val_loss: 1.2525 - val_edist: 2.0629 - lr: 1.0000e-04
# Epoch 23/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0712 - edist: 0.0158 - val_loss: 1.1313 - val_edist: 1.8789 - lr: 1.0000e-04
# Epoch 24/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0517 - edist: 1.7174e-05 - val_loss: 1.1308 - val_edist: 1.7261 - lr: 1.0000e-04
# Epoch 25/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0382 - edist: 2.4605e-04 - val_loss: 1.0867 - val_edist: 1.7039 - lr: 1.0000e-04
# Epoch 26/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0386 - edist: 0.3535 - val_loss: 1.3873 - val_edist: 2.1509 - lr: 1.0000e-04
# Epoch 27/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0611 - edist: 0.1280 - val_loss: 1.1642 - val_edist: 1.6668 - lr: 1.0000e-04
# Epoch 28/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0398 - edist: 0.0098 - val_loss: 1.0728 - val_edist: 1.6365 - lr: 1.0000e-04
# Epoch 29/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0258 - edist: 1.4901e-08 - val_loss: 1.0133 - val_edist: 1.4888 - lr: 1.0000e-04
# Epoch 30/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0180 - edist: 9.7656e-04 - val_loss: 1.0601 - val_edist: 1.3845 - lr: 1.0000e-04
# Epoch 31/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0125 - edist: 3.9443e-31 - val_loss: 1.0089 - val_edist: 1.3980 - lr: 1.0000e-04
# Epoch 32/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0096 - edist: 2.2737e-13 - val_loss: 0.9937 - val_edist: 1.3246 - lr: 1.0000e-04
# Epoch 33/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0173 - edist: 0.1163 - val_loss: 1.2748 - val_edist: 1.8154 - lr: 1.0000e-04
# Epoch 34/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0665 - edist: 0.0106 - val_loss: 1.1505 - val_edist: 1.5809 - lr: 1.0000e-04
# Epoch 35/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0248 - edist: 0.0117
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0248 - edist: 0.0117 - val_loss: 1.0886 - val_edist: 1.5621 - lr: 1.0000e-04
# Epoch 36/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0122 - edist: 0.0078 - val_loss: 1.0096 - val_edist: 1.3533 - lr: 5.0000e-05
# Epoch 37/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0063 - edist: 3.1554e-30 - val_loss: 0.9636 - val_edist: 1.2316 - lr: 5.0000e-05
# Epoch 38/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0047 - edist: 0.0000e+00 - val_loss: 0.9697 - val_edist: 1.2198 - lr: 5.0000e-05
# Epoch 39/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0040 - edist: 0.0000e+00 - val_loss: 0.9736 - val_edist: 1.2134 - lr: 5.0000e-05
# Epoch 40/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0034 - edist: 0.0000e+00
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0034 - edist: 0.0000e+00 - val_loss: 0.9751 - val_edist: 1.1527 - lr: 5.0000e-05
# Epoch 41/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0038 - edist: 0.0000e+00 - val_loss: 0.9572 - val_edist: 1.1109 - lr: 2.5000e-05
# Epoch 42/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0034 - edist: 0.0000e+00 - val_loss: 0.9510 - val_edist: 1.1106 - lr: 2.5000e-05
# Epoch 43/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0031 - edist: 0.0000e+00 - val_loss: 0.9507 - val_edist: 1.0754 - lr: 2.5000e-05
# Epoch 44/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0028 - edist: 0.0000e+00 - val_loss: 0.9513 - val_edist: 1.0747 - lr: 2.5000e-05
# Epoch 45/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0026 - edist: 0.0000e+00 - val_loss: 0.9525 - val_edist: 1.0426 - lr: 2.5000e-05
# Epoch 46/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0023 - edist: 0.0000e+00
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0023 - edist: 0.0000e+00 - val_loss: 0.9536 - val_edist: 1.0231 - lr: 2.5000e-05
# Epoch 47/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0025 - edist: 0.0000e+00 - val_loss: 0.9542 - val_edist: 1.0181 - lr: 1.2500e-05
# Epoch 48/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0022 - edist: 0.0000e+00 - val_loss: 0.9549 - val_edist: 1.0532 - lr: 1.2500e-05
# Early stopping and restored the model weights from the end of epoch 43 - val_loss: 0.950661838054657
#
# ============== Fold 06 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 62ms/step - loss: 5.4222 - edist: 7.9762 - val_loss: 5.0430 - val_edist: 7.5937 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.0574 - edist: 7.5361 - val_loss: 4.9498 - val_edist: 7.0997 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.8611 - edist: 7.1770 - val_loss: 4.9023 - val_edist: 6.8022 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.6341 - edist: 7.0969 - val_loss: 4.9547 - val_edist: 7.0436 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4668 - edist: 7.0959 - val_loss: 5.0007 - val_edist: 7.1419 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - ETA: 0s - loss: 4.3291 - edist: 7.1471
# Epoch 6: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 4.3287 - edist: 7.1471 - val_loss: 5.0607 - val_edist: 7.3080 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.1415 - edist: 6.8727 - val_loss: 4.9860 - val_edist: 6.5411 - lr: 1.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0405 - edist: 6.7565 - val_loss: 5.1430 - val_edist: 6.7068 - lr: 1.0000e-04
# Early stopping and restored the model weights from the end of epoch 3 - val_loss: 4.902332305908203
#
# ============== Fold 07 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 61ms/step - loss: 5.4191 - edist: 7.5097 - val_loss: 5.1429 - val_edist: 7.9076 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 51ms/step - loss: 5.0075 - edist: 7.0762 - val_loss: 4.9433 - val_edist: 7.4774 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.7860 - edist: 7.6740 - val_loss: 4.8570 - val_edist: 7.8310 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.6144 - edist: 7.1050 - val_loss: 4.8066 - val_edist: 7.2555 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.4575 - edist: 7.0127 - val_loss: 4.8287 - val_edist: 7.2460 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 51ms/step - loss: 4.3078 - edist: 6.8657 - val_loss: 4.8764 - val_edist: 6.9952 - lr: 2.0000e-04
# Epoch 7/100
# 227/228 [============================>.] - ETA: 0s - loss: 4.1526 - edist: 6.8229
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 51ms/step - loss: 4.1533 - edist: 6.9115 - val_loss: 4.8712 - val_edist: 6.9633 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.9198 - edist: 6.9941 - val_loss: 4.9602 - val_edist: 6.9422 - lr: 1.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.7943 - edist: 6.9179 - val_loss: 4.8189 - val_edist: 6.9904 - lr: 1.0000e-04
# Early stopping and restored the model weights from the end of epoch 4 - val_loss: 4.806619644165039
#
# ============== Fold 08 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 63ms/step - loss: 5.3805 - edist: 7.9205 - val_loss: 4.9180 - val_edist: 7.7765 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.9693 - edist: 7.6666 - val_loss: 5.5091 - val_edist: 7.9139 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.7836 - edist: 6.9602 - val_loss: 4.6779 - val_edist: 7.0247 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.5964 - edist: 6.9909 - val_loss: 4.5908 - val_edist: 7.1105 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4591 - edist: 6.9844 - val_loss: 4.5588 - val_edist: 7.0467 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.3115 - edist: 6.9557 - val_loss: 4.6654 - val_edist: 7.1055 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.1612 - edist: 6.8793 - val_loss: 4.5826 - val_edist: 6.9373 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - ETA: 0s - loss: 4.0050 - edist: 7.0223
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0054 - edist: 7.0223 - val_loss: 4.6665 - val_edist: 7.0226 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.7812 - edist: 6.9016 - val_loss: 4.5585 - val_edist: 7.0165 - lr: 1.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.6617 - edist: 6.9000 - val_loss: 4.5949 - val_edist: 7.0081 - lr: 1.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.5356 - edist: 6.9298 - val_loss: 4.5864 - val_edist: 7.0000 - lr: 1.0000e-04
# Epoch 12/100
# 227/228 [============================>.] - ETA: 0s - loss: 3.4030 - edist: 6.9457
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 3.4050 - edist: 6.9728 - val_loss: 4.6404 - val_edist: 6.9222 - lr: 1.0000e-04
# Epoch 13/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.2666 - edist: 6.9686 - val_loss: 4.6384 - val_edist: 6.9477 - lr: 5.0000e-05
# Epoch 14/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.1903 - edist: 6.9373 - val_loss: 4.6713 - val_edist: 6.9381 - lr: 5.0000e-05
# Early stopping and restored the model weights from the end of epoch 9 - val_loss: 4.558500289916992
#
# ============== Fold 09 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 62ms/step - loss: 5.3882 - edist: 8.0327 - val_loss: 4.9991 - val_edist: 8.0093 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 53ms/step - loss: 5.0338 - edist: 7.3765 - val_loss: 4.8639 - val_edist: 7.1104 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.8372 - edist: 7.3748 - val_loss: 4.7726 - val_edist: 7.3921 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.6386 - edist: 6.9271 - val_loss: 4.6874 - val_edist: 6.9087 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4782 - edist: 6.9833 - val_loss: 4.7235 - val_edist: 7.1504 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.3431 - edist: 6.9238 - val_loss: 4.7462 - val_edist: 7.0488 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - ETA: 0s - loss: 4.2163 - edist: 7.1850
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 53ms/step - loss: 4.2169 - edist: 7.1850 - val_loss: 4.7271 - val_edist: 7.0881 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.0212 - edist: 7.0251 - val_loss: 4.7404 - val_edist: 7.2938 - lr: 1.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.9026 - edist: 7.1737 - val_loss: 4.6199 - val_edist: 7.2288 - lr: 1.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.7849 - edist: 6.8350 - val_loss: 4.6864 - val_edist: 6.9940 - lr: 1.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 54ms/step - loss: 3.6445 - edist: 6.9023 - val_loss: 4.5792 - val_edist: 6.8530 - lr: 1.0000e-04
# Epoch 12/100
# 228/228 [==============================] - 12s 54ms/step - loss: 3.5076 - edist: 6.7963 - val_loss: 4.5493 - val_edist: 6.7508 - lr: 1.0000e-04
# Epoch 13/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.3643 - edist: 6.7917 - val_loss: 4.3996 - val_edist: 6.8015 - lr: 1.0000e-04
# Epoch 14/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.1844 - edist: 6.7368 - val_loss: 4.4204 - val_edist: 6.6733 - lr: 1.0000e-04
# Epoch 15/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.9770 - edist: 6.7678 - val_loss: 4.1905 - val_edist: 6.5800 - lr: 1.0000e-04
# Epoch 16/100
# 228/228 [==============================] - 12s 53ms/step - loss: 2.7008 - edist: 6.3813 - val_loss: 3.9854 - val_edist: 6.2399 - lr: 1.0000e-04
# Epoch 17/100
# 228/228 [==============================] - 12s 53ms/step - loss: 2.3394 - edist: 5.9954 - val_loss: 3.5548 - val_edist: 6.0701 - lr: 1.0000e-04
# Epoch 18/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.8101 - edist: 4.9381 - val_loss: 2.8797 - val_edist: 5.3866 - lr: 1.0000e-04
# Epoch 19/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.2405 - edist: 3.5907 - val_loss: 2.2009 - val_edist: 4.4952 - lr: 1.0000e-04
# Epoch 20/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.8236 - edist: 2.1648 - val_loss: 1.7821 - val_edist: 3.8787 - lr: 1.0000e-04
# Epoch 21/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.5539 - edist: 1.4847 - val_loss: 1.5622 - val_edist: 3.5291 - lr: 1.0000e-04
# Epoch 22/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.3732 - edist: 0.9643 - val_loss: 1.5079 - val_edist: 3.1370 - lr: 1.0000e-04
# Epoch 23/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.2486 - edist: 0.5228 - val_loss: 1.3769 - val_edist: 2.8570 - lr: 1.0000e-04
# Epoch 24/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.2292 - edist: 0.2735 - val_loss: 1.2180 - val_edist: 2.5500 - lr: 1.0000e-04
# Epoch 25/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.1434 - edist: 0.1130 - val_loss: 1.1838 - val_edist: 2.4032 - lr: 1.0000e-04
# Epoch 26/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0984 - edist: 0.0219 - val_loss: 1.0702 - val_edist: 2.3530 - lr: 1.0000e-04
# Epoch 27/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0626 - edist: 7.4009e-04 - val_loss: 0.9399 - val_edist: 2.1068 - lr: 1.0000e-04
# Epoch 28/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0455 - edist: 3.1501e-05 - val_loss: 0.9834 - val_edist: 2.0763 - lr: 1.0000e-04
# Epoch 29/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0336 - edist: 1.1924e-07 - val_loss: 0.8731 - val_edist: 1.9002 - lr: 1.0000e-04
# Epoch 30/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0547 - edist: 3.7770e-04 - val_loss: 0.9157 - val_edist: 1.9793 - lr: 1.0000e-04
# Epoch 31/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0449 - edist: 0.0502 - val_loss: 0.9868 - val_edist: 2.1885 - lr: 1.0000e-04
# Epoch 32/100
# 227/228 [============================>.] - ETA: 0s - loss: 0.0443 - edist: 0.0648
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0446 - edist: 0.1574 - val_loss: 0.9851 - val_edist: 2.1707 - lr: 1.0000e-04
# Epoch 33/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0297 - edist: 5.2649e-04 - val_loss: 0.7971 - val_edist: 1.8894 - lr: 5.0000e-05
# Epoch 34/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0188 - edist: 0.0000e+00 - val_loss: 0.7694 - val_edist: 1.6953 - lr: 5.0000e-05
# Epoch 35/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0153 - edist: 0.0000e+00 - val_loss: 0.7349 - val_edist: 1.6774 - lr: 5.0000e-05
# Epoch 36/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0140 - edist: 0.0000e+00 - val_loss: 0.7143 - val_edist: 1.5912 - lr: 5.0000e-05
# Epoch 37/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0121 - edist: 3.6380e-12 - val_loss: 0.7151 - val_edist: 1.5123 - lr: 5.0000e-05
# Epoch 38/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0106 - edist: 0.0000e+00 - val_loss: 0.7121 - val_edist: 1.5529 - lr: 5.0000e-05
# Epoch 39/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0102 - edist: 6.0185e-36 - val_loss: 0.6918 - val_edist: 1.5168 - lr: 5.0000e-05
# Epoch 40/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0100 - edist: 4.6532e-25 - val_loss: 0.6954 - val_edist: 1.4211 - lr: 5.0000e-05
# Epoch 41/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.0084 - edist: 5.2103e-26 - val_loss: 0.6869 - val_edist: 1.4232 - lr: 5.0000e-05
# Epoch 42/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0068 - edist: 6.1035e-05 - val_loss: 0.6914 - val_edist: 1.3642 - lr: 5.0000e-05
# Epoch 43/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.0056 - edist: 6.1035e-05 - val_loss: 0.6914 - val_edist: 1.4611 - lr: 5.0000e-05
# Epoch 44/100
# 228/228 [==============================] - 12s 54ms/step - loss: 0.0045 - edist: 0.0000e+00 - val_loss: 0.6772 - val_edist: 1.4185 - lr: 5.0000e-05
# Epoch 45/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0038 - edist: 0.0000e+00 - val_loss: 0.6711 - val_edist: 1.4583 - lr: 5.0000e-05
# Epoch 46/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0033 - edist: 0.0000e+00 - val_loss: 0.6704 - val_edist: 1.4419 - lr: 5.0000e-05
# Epoch 47/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0029 - edist: 0.0000e+00 - val_loss: 0.6679 - val_edist: 1.4275 - lr: 5.0000e-05
# Epoch 48/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0025 - edist: 0.0000e+00 - val_loss: 0.6606 - val_edist: 1.3884 - lr: 5.0000e-05
# Epoch 49/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0022 - edist: 0.0000e+00 - val_loss: 0.6445 - val_edist: 1.3861 - lr: 5.0000e-05
# Epoch 50/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0019 - edist: 0.0000e+00 - val_loss: 0.6287 - val_edist: 1.3616 - lr: 5.0000e-05
# Epoch 51/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0016 - edist: 0.0000e+00 - val_loss: 0.6159 - val_edist: 1.3684 - lr: 5.0000e-05
# Epoch 52/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0014 - edist: 0.0000e+00 - val_loss: 0.6038 - val_edist: 1.2809 - lr: 5.0000e-05
# Epoch 53/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0013 - edist: 0.0000e+00 - val_loss: 0.5914 - val_edist: 1.2818 - lr: 5.0000e-05
# Epoch 54/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0011 - edist: 0.0000e+00 - val_loss: 0.5820 - val_edist: 1.2539 - lr: 5.0000e-05
# Epoch 55/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0010 - edist: 0.0000e+00 - val_loss: 0.5783 - val_edist: 1.2390 - lr: 5.0000e-05
# Epoch 56/100
# 228/228 [==============================] - 12s 53ms/step - loss: 8.8444e-04 - edist: 0.0000e+00 - val_loss: 0.5801 - val_edist: 1.2272 - lr: 5.0000e-05
# Epoch 57/100
# 228/228 [==============================] - 12s 53ms/step - loss: 7.7615e-04 - edist: 0.0000e+00 - val_loss: 0.5863 - val_edist: 1.2301 - lr: 5.0000e-05
# Epoch 58/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0492 - edist: 0.1724
# Epoch 58: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0494 - edist: 0.1724 - val_loss: 1.0311 - val_edist: 2.2828 - lr: 5.0000e-05
# Epoch 59/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0242 - edist: 0.0156 - val_loss: 0.7793 - val_edist: 1.6653 - lr: 2.5000e-05
# Epoch 60/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0071 - edist: 0.0000e+00 - val_loss: 0.6835 - val_edist: 1.5641 - lr: 2.5000e-05
# Early stopping and restored the model weights from the end of epoch 55 - val_loss: 0.5783023238182068
#
# ============== Fold 10 training ==============
# Epoch 1/100
# 228/228 [==============================] - 23s 61ms/step - loss: 5.3993 - edist: 7.7267 - val_loss: 5.1077 - val_edist: 7.8227 - lr: 2.0000e-04
# Epoch 2/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.9893 - edist: 7.3079 - val_loss: 4.9521 - val_edist: 6.7271 - lr: 2.0000e-04
# Epoch 3/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.7716 - edist: 7.0406 - val_loss: 4.8768 - val_edist: 7.1670 - lr: 2.0000e-04
# Epoch 4/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.5822 - edist: 6.9240 - val_loss: 4.7992 - val_edist: 6.9915 - lr: 2.0000e-04
# Epoch 5/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.4049 - edist: 6.9645 - val_loss: 4.8074 - val_edist: 6.7238 - lr: 2.0000e-04
# Epoch 6/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.2306 - edist: 6.8763 - val_loss: 4.8309 - val_edist: 6.6761 - lr: 2.0000e-04
# Epoch 7/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0034 - edist: 6.8279 - val_loss: 4.6882 - val_edist: 6.6619 - lr: 2.0000e-04
# Epoch 8/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.7410 - edist: 6.6474 - val_loss: 4.5721 - val_edist: 6.6762 - lr: 2.0000e-04
# Epoch 9/100
# 228/228 [==============================] - 12s 54ms/step - loss: 3.4136 - edist: 6.3385 - val_loss: 4.4978 - val_edist: 6.5407 - lr: 2.0000e-04
# Epoch 10/100
# 228/228 [==============================] - 11s 47ms/step - loss: 3.0254 - edist: 6.0020 - val_loss: 4.1807 - val_edist: 6.2522 - lr: 2.0000e-04
# Epoch 11/100
# 228/228 [==============================] - 12s 53ms/step - loss: 2.4949 - edist: 5.2131 - val_loss: 3.6875 - val_edist: 5.8607 - lr: 2.0000e-04
# Epoch 12/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.8271 - edist: 3.9575 - val_loss: 3.1398 - val_edist: 5.0410 - lr: 2.0000e-04
# Epoch 13/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.1589 - edist: 2.8771 - val_loss: 2.5297 - val_edist: 4.4831 - lr: 2.0000e-04
# Epoch 14/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.6190 - edist: 1.3188 - val_loss: 1.9406 - val_edist: 3.5946 - lr: 2.0000e-04
# Epoch 15/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.3053 - edist: 0.4079 - val_loss: 1.7146 - val_edist: 2.9782 - lr: 2.0000e-04
# Epoch 16/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1723 - edist: 0.3568 - val_loss: 1.4924 - val_edist: 2.7519 - lr: 2.0000e-04
# Epoch 17/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1226 - edist: 0.0969 - val_loss: 1.3144 - val_edist: 2.5191 - lr: 2.0000e-04
# Epoch 18/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0804 - edist: 0.0493 - val_loss: 1.2573 - val_edist: 2.2853 - lr: 2.0000e-04
# Epoch 19/100
# 228/228 [==============================] - 12s 51ms/step - loss: 0.0589 - edist: 0.0400 - val_loss: 1.3534 - val_edist: 2.3877 - lr: 2.0000e-04
# Epoch 20/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0505 - edist: 0.0093 - val_loss: 1.3162 - val_edist: 2.3215 - lr: 2.0000e-04
# Epoch 21/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0302 - edist: 0.0191
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0303 - edist: 0.0191 - val_loss: 1.3482 - val_edist: 2.4655 - lr: 2.0000e-04
# Epoch 22/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0207 - edist: 0.0044 - val_loss: 1.1063 - val_edist: 2.2419 - lr: 1.0000e-04
# Epoch 23/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0111 - edist: 7.6252e-09 - val_loss: 1.0328 - val_edist: 2.0740 - lr: 1.0000e-04
# Epoch 24/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0070 - edist: 6.9389e-18 - val_loss: 0.9577 - val_edist: 1.8280 - lr: 1.0000e-04
# Epoch 25/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0055 - edist: 6.9389e-18 - val_loss: 0.9246 - val_edist: 1.8752 - lr: 1.0000e-04
# Epoch 26/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0043 - edist: 0.0000e+00 - val_loss: 0.9136 - val_edist: 1.8415 - lr: 1.0000e-04
# Epoch 27/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0036 - edist: 0.0000e+00 - val_loss: 0.8981 - val_edist: 1.7757 - lr: 1.0000e-04
# Epoch 28/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0030 - edist: 0.0000e+00 - val_loss: 0.8837 - val_edist: 1.7511 - lr: 1.0000e-04
# Epoch 29/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0026 - edist: 0.0000e+00 - val_loss: 0.8723 - val_edist: 1.7489 - lr: 1.0000e-04
# Epoch 30/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0022 - edist: 0.0000e+00 - val_loss: 0.8625 - val_edist: 1.7714 - lr: 1.0000e-04
# Epoch 31/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0019 - edist: 0.0000e+00 - val_loss: 0.8543 - val_edist: 1.7746 - lr: 1.0000e-04
# Epoch 32/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0017 - edist: 0.0000e+00 - val_loss: 0.8475 - val_edist: 1.7666 - lr: 1.0000e-04
# Epoch 33/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0015 - edist: 0.0000e+00 - val_loss: 0.8408 - val_edist: 1.7586 - lr: 1.0000e-04
# Epoch 34/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.0013 - edist: 0.0000e+00 - val_loss: 0.8352 - val_edist: 1.7112 - lr: 1.0000e-04
# Epoch 35/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0011 - edist: 0.0000e+00 - val_loss: 0.8304 - val_edist: 1.7053 - lr: 1.0000e-04
# Epoch 36/100
# 228/228 [==============================] - 12s 53ms/step - loss: 9.8982e-04 - edist: 0.0000e+00 - val_loss: 0.8252 - val_edist: 1.7131 - lr: 1.0000e-04
# Epoch 37/100
# 228/228 [==============================] - 12s 53ms/step - loss: 8.6946e-04 - edist: 0.0000e+00 - val_loss: 0.8205 - val_edist: 1.6959 - lr: 1.0000e-04
# Epoch 38/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.6375e-04 - edist: 0.0000e+00 - val_loss: 0.8154 - val_edist: 1.6568 - lr: 1.0000e-04
# Epoch 39/100
# 228/228 [==============================] - 12s 52ms/step - loss: 6.7181e-04 - edist: 0.0000e+00 - val_loss: 0.8107 - val_edist: 1.6398 - lr: 1.0000e-04
# Epoch 40/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.9171e-04 - edist: 0.0000e+00 - val_loss: 0.8059 - val_edist: 1.6392 - lr: 1.0000e-04
# Epoch 41/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.2196e-04 - edist: 0.0000e+00 - val_loss: 0.8014 - val_edist: 1.6460 - lr: 1.0000e-04
# Epoch 42/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.6108e-04 - edist: 0.0000e+00 - val_loss: 0.7971 - val_edist: 1.6439 - lr: 1.0000e-04
# Epoch 43/100
# 228/228 [==============================] - 12s 52ms/step - loss: 4.0783e-04 - edist: 0.0000e+00 - val_loss: 0.7929 - val_edist: 1.6400 - lr: 1.0000e-04
# Epoch 44/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.6113e-04 - edist: 0.0000e+00 - val_loss: 0.7889 - val_edist: 1.6400 - lr: 1.0000e-04
# Epoch 45/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.1998e-04 - edist: 0.0000e+00 - val_loss: 0.7853 - val_edist: 1.6360 - lr: 1.0000e-04
# Epoch 46/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.8364e-04 - edist: 0.0000e+00 - val_loss: 0.7819 - val_edist: 1.6048 - lr: 1.0000e-04
# Epoch 47/100
# 228/228 [==============================] - 12s 53ms/step - loss: 2.5144e-04 - edist: 0.0000e+00 - val_loss: 0.7788 - val_edist: 1.6048 - lr: 1.0000e-04
# Epoch 48/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.2286e-04 - edist: 0.0000e+00 - val_loss: 0.7758 - val_edist: 1.5462 - lr: 1.0000e-04
# Epoch 49/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.9752e-04 - edist: 0.0000e+00 - val_loss: 0.7728 - val_edist: 1.5462 - lr: 1.0000e-04
# Epoch 50/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.7498e-04 - edist: 0.0000e+00 - val_loss: 0.7701 - val_edist: 1.4837 - lr: 1.0000e-04
# Epoch 51/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.5497e-04 - edist: 0.0000e+00 - val_loss: 0.7673 - val_edist: 1.4829 - lr: 1.0000e-04
# Epoch 52/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.3720e-04 - edist: 0.0000e+00 - val_loss: 0.7640 - val_edist: 1.4826 - lr: 1.0000e-04
# Epoch 53/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.2141e-04 - edist: 0.0000e+00 - val_loss: 0.7612 - val_edist: 1.4826 - lr: 1.0000e-04
# Epoch 54/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.0741e-04 - edist: 0.0000e+00 - val_loss: 0.7583 - val_edist: 1.4276 - lr: 1.0000e-04
# Epoch 55/100
# 228/228 [==============================] - 12s 52ms/step - loss: 9.4977e-05 - edist: 0.0000e+00 - val_loss: 0.7553 - val_edist: 1.3649 - lr: 1.0000e-04
# Epoch 56/100
# 228/228 [==============================] - 12s 52ms/step - loss: 8.3978e-05 - edist: 0.0000e+00 - val_loss: 0.7523 - val_edist: 1.3610 - lr: 1.0000e-04
# Epoch 57/100
# 228/228 [==============================] - 12s 53ms/step - loss: 7.4232e-05 - edist: 0.0000e+00 - val_loss: 0.7499 - val_edist: 1.3912 - lr: 1.0000e-04
# Epoch 58/100
# 228/228 [==============================] - 12s 53ms/step - loss: 6.5601e-05 - edist: 0.0000e+00 - val_loss: 0.7475 - val_edist: 1.3931 - lr: 1.0000e-04
# Epoch 59/100
# 228/228 [==============================] - 12s 53ms/step - loss: 5.7967e-05 - edist: 0.0000e+00 - val_loss: 0.7450 - val_edist: 1.3933 - lr: 1.0000e-04
# Epoch 60/100
# 228/228 [==============================] - 12s 52ms/step - loss: 5.1224e-05 - edist: 0.0000e+00 - val_loss: 0.7424 - val_edist: 1.3928 - lr: 1.0000e-04
# Epoch 61/100
# 228/228 [==============================] - 12s 53ms/step - loss: 4.5259e-05 - edist: 0.0000e+00 - val_loss: 0.7399 - val_edist: 1.3283 - lr: 1.0000e-04
# Epoch 62/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.9989e-05 - edist: 0.0000e+00 - val_loss: 0.7373 - val_edist: 1.3283 - lr: 1.0000e-04
# Epoch 63/100
# 228/228 [==============================] - 12s 52ms/step - loss: 3.5339e-05 - edist: 0.0000e+00 - val_loss: 0.7347 - val_edist: 1.3127 - lr: 1.0000e-04
# Epoch 64/100
# 228/228 [==============================] - 12s 53ms/step - loss: 3.1232e-05 - edist: 0.0000e+00 - val_loss: 0.7325 - val_edist: 1.3119 - lr: 1.0000e-04
# Epoch 65/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.7605e-05 - edist: 0.0000e+00 - val_loss: 0.7304 - val_edist: 1.3097 - lr: 1.0000e-04
# Epoch 66/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.4406e-05 - edist: 0.0000e+00 - val_loss: 0.7285 - val_edist: 1.3136 - lr: 1.0000e-04
# Epoch 67/100
# 228/228 [==============================] - 12s 52ms/step - loss: 2.1579e-05 - edist: 0.0000e+00 - val_loss: 0.7268 - val_edist: 1.3292 - lr: 1.0000e-04
# Epoch 68/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.9081e-05 - edist: 0.0000e+00 - val_loss: 0.7253 - val_edist: 1.3292 - lr: 1.0000e-04
# Epoch 69/100
# 228/228 [==============================] - 12s 52ms/step - loss: 1.6878e-05 - edist: 0.0000e+00 - val_loss: 0.7241 - val_edist: 1.3292 - lr: 1.0000e-04
# Epoch 70/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.4930e-05 - edist: 0.0000e+00 - val_loss: 0.7228 - val_edist: 1.3292 - lr: 1.0000e-04
# Epoch 71/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.3209e-05 - edist: 0.0000e+00 - val_loss: 0.7217 - val_edist: 1.3231 - lr: 1.0000e-04
# Epoch 72/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.1689e-05 - edist: 0.0000e+00 - val_loss: 0.7208 - val_edist: 1.3231 - lr: 1.0000e-04
# Epoch 73/100
# 228/228 [==============================] - 12s 53ms/step - loss: 1.0344e-05 - edist: 0.0000e+00 - val_loss: 0.7196 - val_edist: 1.3151 - lr: 1.0000e-04
# Epoch 74/100
# 228/228 [==============================] - 12s 53ms/step - loss: 9.1543e-06 - edist: 0.0000e+00 - val_loss: 0.7193 - val_edist: 1.3137 - lr: 1.0000e-04
# Epoch 75/100
# 228/228 [==============================] - 12s 53ms/step - loss: 8.1022e-06 - edist: 0.0000e+00 - val_loss: 0.7185 - val_edist: 1.3137 - lr: 1.0000e-04
# Epoch 76/100
# 228/228 [==============================] - 12s 52ms/step - loss: 7.1731e-06 - edist: 0.0000e+00 - val_loss: 0.7185 - val_edist: 1.3010 - lr: 1.0000e-04
# Epoch 77/100
# 228/228 [==============================] - 12s 52ms/step - loss: 6.3507e-06 - edist: 0.0000e+00 - val_loss: 0.7163 - val_edist: 1.3030 - lr: 1.0000e-04
# Epoch 78/100
# 228/228 [==============================] - 12s 52ms/step - loss: 0.1301 - edist: 0.2860 - val_loss: 1.1984 - val_edist: 2.1750 - lr: 1.0000e-04
# Epoch 79/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0484 - edist: 0.0599 - val_loss: 1.0387 - val_edist: 2.0649 - lr: 1.0000e-04
# Epoch 80/100
# 228/228 [==============================] - ETA: 0s - loss: 0.0203 - edist: 1.2262e-04
# Epoch 80: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0203 - edist: 1.2262e-04 - val_loss: 0.8776 - val_edist: 1.8269 - lr: 1.0000e-04
# Epoch 81/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0050 - edist: 9.7658e-04 - val_loss: 0.8486 - val_edist: 1.7166 - lr: 5.0000e-05
# Epoch 82/100
# 228/228 [==============================] - 12s 53ms/step - loss: 0.0014 - edist: 0.0000e+00 - val_loss: 0.8367 - val_edist: 1.6204 - lr: 5.0000e-05
# Early stopping and restored the model weights from the end of epoch 77 - val_loss: 0.7162771224975586
#
# Wall time: 1h 12min 5s

# %% [markdown]
# ## Get the best CRNN model and its results

# %%
from kfold import get_best_fold
from visualizer import plot_training_results
(
    best_valid_dataset,
    best_fold_epoch,
    best_history,
    best_model,
    best_fold_idx, 
    best_loss,
) = get_best_fold(valid_datasets, best_epochs, histories, models, verbose=2)
# Out:
# 25/25 - 1s - loss: 0.4357 - edist: 0.7321 - 706ms/epoch - 28ms/step
# 25/25 - 1s - loss: 4.6246 - edist: 7.0936 - 706ms/epoch - 28ms/step
# 25/25 - 1s - loss: 4.3360 - edist: 6.9093 - 721ms/epoch - 29ms/step
# 25/25 - 1s - loss: 4.8871 - edist: 7.2520 - 710ms/epoch - 28ms/step
# 25/25 - 1s - loss: 0.9507 - edist: 1.0754 - 705ms/epoch - 28ms/step
# 25/25 - 1s - loss: 4.9023 - edist: 6.8022 - 713ms/epoch - 29ms/step
# 25/25 - 1s - loss: 4.8066 - edist: 7.2555 - 709ms/epoch - 28ms/step
# 25/25 - 1s - loss: 4.5585 - edist: 7.0165 - 681ms/epoch - 27ms/step
# 25/25 - 1s - loss: 0.5783 - edist: 1.2390 - 711ms/epoch - 28ms/step
# 25/25 - 1s - loss: 0.7163 - edist: 1.3030 - 700ms/epoch - 28ms/step

# %%
print(f'Fold {best_fold_idx + 1:02d} has the best result at epoch {best_fold_epoch + 1}:')
print(f'- Loss on validation: {best_loss}')
print(f'- Mean edit distance: {best_history["val_edist"][best_fold_epoch]}')

plot_training_results(best_history, f'{APPROACH_NAME}.png')
best_model.encoder.save_weights(f'{APPROACH_NAME}_encoder.h5')
best_model.decoder.save_weights(f'{APPROACH_NAME}_decoder.h5')
# Out:
# Fold 01 has the best result at epoch 100:
# - Loss on validation: 0.43573495745658875
# - Mean edit distance: 0.7320601344108582

# %% [markdown]
# # Inference

# %%
encoder = CNN_Encoder(imagenet_model, imagenet_output_layer)
decoder = RNN_Decoder(encoder.output_shape[1:], VOCAB_SIZE)
encoder.load_weights(f'{APPROACH_NAME}_encoder.h5')
decoder.load_weights(f'{APPROACH_NAME}_decoder.h5')

# %%
reloaded_model = AttentionCRNN(encoder, decoder)
reloaded_model.compile(
    optimizer = Adam(learning_rate=LEARNING_RATE), 
    loss = MaskedLoss(PADDING_TOKEN), 
    metrics = [MeanEditDistance(PADDING_TOKEN)]
)

# %% [markdown]
# ## On test dataset

# %%
batch_results = []
valid_tf_dataset, valid_idxs = best_valid_dataset
for idx, (batch_images, batch_tokens) in enumerate(valid_tf_dataset.take(3)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    pred_tokens, attentions = reloaded_model.predict(batch_images, return_attention=True) 
    
    labels = data_handler.tokens2texts(batch_tokens)
    pred_labels = data_handler.tokens2texts(pred_tokens)
    batch_results.append({'true': labels, 'pred': pred_labels, 'attentions': attentions})

    visualize_images_labels(
        img_paths = img_paths[idxs_in_batch], 
        labels = labels, 
        pred_labels = pred_labels,
        font_path = FONT_PATH, 
        text_x = WIDTH + 3 # Position of actual label to plot
    )
    print(
        f'Batch {idx + 1:02d}:\n'
        f'- True: {dict(enumerate(labels, start=1))}\n'
        f'- Pred: {dict(enumerate(pred_labels, start=1))}\n'
    )
# Out:
# Batch 01:
# - True: {1: '𤳆辰忠孝\U000f094e頭', 2: '𣎃㝵包𬋩功程劳刀', 3: '吹柴傷伵㤕車𥪝𢚸', 4: '咍\U000f047c昆唉胡𪟽', 5: '𡢐油鄧𡦂顕荣', 6: '雲仙倍且謝恩', 7: '咍\U000f047c𠬠屡山\U000f025f蹺些', 8: '民𦖑㗂呐請台', 9: '䜹浪固党娄\U000f047c', 10: '碎吀𦋦飭英豪', 11: '民浪屡奴群低', 12: '戈䀡\U000f061a倍踈兮㐌仃', 13: '嗔蹺拱妾𡊰恩朱払', 14: '𧵑尼\U000f047c𧵑沕爲', 15: '本渚別氏固欺覔𢚸', 16: '妾嗔爫𠬠排书謝辞'}
# - Pred: {1: '𤳆辰差孝\U000f094e頭', 2: '𣎃㝵包改功程劳刀', 3: '吹柴傷伵㤕車𥪝𢚸', 4: '咍\U000f047c昆唉胡𪟽', 5: '𡢐油鄧𡦂顕荣', 6: '雲仙倍且謝恩', 7: '咍\U000f047c𠬠茦泊\U000f025f蹺些', 8: '民𦖑㗂呐請台', 9: '䜹浪固党雲\U000f047c', 10: '碎吀𦋦飭英豪', 11: '民浪堆奴群低', 12: '戈䀡\U000f061a倍淶身㐌仃', 13: '嗔蹺拱妾畑恩朱払', 14: '𧵑尼\U000f047c𧵑𣳔爲', 15: '本渚別色固欺盃𢚸', 16: '妾嗔爫𠬠排书謝詩'}
#
# Batch 02:
# - True: {1: '\U000f0778畨宋玉拱\U000f07f4西詩', 2: '汝句愈出愈奇', 3: '埃咍才𡛔劍夷才𤳆', 4: '𢪀𠇮麻喭朱𠇮', 5: '浽恩渚呂浽情吏芒', 6: '𤾓𠄼朱論𡦂從貝安', 7: '𬌓𢚸娥女爲払麻迎', 8: '哙浪芇𥘷过兒', 9: '𣅶芇吒領役官', 10: '吒願呂特\U000f0482尼辰傕', 11: '䀡𦝄耒吏想情故人', 12: '嘆浪𠦳淡山川', 13: '漢明姓字水支圭茄', 14: '𡦂浪朋友之交', 15: '𨑗棱𧯶易𠬠核', 16: '朱𠫾𠬠妸小童'}
# - Pred: {1: '\U000f0778畨宋玉拱紅西詩', 2: '汝句恩㐌慈奇', 3: '埃咍才𡛔制夷才𤳆', 4: '𢪀𠇮麻喭朱𠇮', 5: '浽恩渚呂浽情吏芒', 6: '𤾓𠄼朱論𡦂從貝安', 7: '𬌓𢚸離女爲払麻迎', 8: '哙浪芇𥘷宫兒', 9: '𣅶芇吒用役官', 10: '吒願呂特\U000f0482尼辰傕', 11: '䀡𦝄耒吏想情故人', 12: '嘆浪𠦳淡山川', 13: '漢明𢭮子本𨖲圭茄', 14: '𡦂浪胡北之安', 15: '𨑗棱顔易𠬠核', 16: '朱𠫾𠬠妸小童'}
#
# Batch 03:
# - True: {1: '大科嗔及小科卢夷', 2: '𠸜\U000f047c子直文章捽𠁀', 3: '湿高買別所才', 4: '𥙩句泙水有縁爲題', 5: '防𡢐朱塊不平𢚸饒', 6: '踈浪君子赴京', 7: '𤾓𢆥𢚸庄差𢚸', 8: '\U000f0778咍翁舘唭之', 9: '撫𢬣摺昭𠬠欺唭𨱽', 10: '直浪𢈱呐有縁', 11: '\U000f086b冲經史固全\U000f0803庒', 12: '被𡗶欧𠲝𧗱茄𠰺民', 13: '姅分吏咭姅分吏傷', 14: '傷民牢庒立身', 15: '\U000f0272埋𣳔渭墨油盃制', 16: '陳平㐌𠇍卢欧'}
# - Pred: {1: '犬科嗔及小科卢夷', 2: '𠸜\U000f047c子直文兒𢭂𠁀', 3: '湿高買別所才', 4: '𥙩句泙永負縁爲題', 5: '防𡢐朱塊不平饒饒', 6: '踈浪君子𪿒京', 7: '𤾓𢆥𢚸庄差𢚸', 8: '\U000f0778咍翁舘唭之', 9: '撫𢬣招𣇜𠬠欺唭𨱽', 10: '直浪𢈱呐有縁', 11: '\U000f086b冲經史固全\U000f0803庒', 12: '襘𡗶詫罕𧗱茄𠰺民', 13: '姅分吏哙姅分吏傷', 14: '傷民牢庒立身', 15: '底埋𣳔劄𦊚油盃制', 16: '陳平㐌\U000f02c7卢欧'}

# %% [markdown]
# ## On random image

# %%
random_path = '../大越史記全書.jpg'
random_label = '大越史記全書'
random_image = data_handler.process_image(random_path)
pred_tokens = reloaded_model.predict(tf.expand_dims(random_image, axis=0))
pred_labels = data_handler.tokens2texts(pred_tokens)

# %%
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    show_legend = False,
    font_path = FONT_PATH, 
    text_x = WIDTH + 3 # Position of actual label to plot
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 大桃吏記全書
