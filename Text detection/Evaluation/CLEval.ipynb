# %%
# !unzip -q 'validate/validate.zip' -d '/tmp'
# !unzip -q 'validate/validate_all.zip' -d '/tmp'
# !unzip -q 'validate/validate_poem.zip' -d '/tmp'
# !unzip -q 'validate/validate_prose.zip' -d '/tmp'

# %%
# !git clone https://github.com/clovaai/CLEval.git
# %cd CLEval
# !pip3 install -r requirements.txt

# %% [markdown]
# # General evaluations

# %%
# All DBNet
# !python3 CLEval/script.py -g=/tmp/validate_all/truth/truth.zip -s=/tmp/validate_all/db/db.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 594/594 [00:14<00:00, 39.61it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9964935653987486,
#                'precision': 0.9991045991045991,
#                'recall': 0.9938961433343456},
#  'Detection_Metadata': {'char_false_pos': 51,
#                         'char_miss': 566,
#                         'char_overlap': 5,
#                         'num_false_pos': 51,
#                         'num_merge': 16,
#                         'num_split': 35},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 51,
#                        'num_merge': 16,
#                        'num_split': 35}}

# %%
# All EAST
# !python3 CLEval/script.py -g=/tmp/validate_all/truth/truth.zip -s=/tmp/validate_all/east/east.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 594/594 [00:13<00:00, 45.02it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9876559566358306,
#                'precision': 0.9909630249869806,
#                'recall': 0.9843708877416742},
#  'Detection_Metadata': {'char_false_pos': 77,
#                         'char_miss': 1315,
#                         'char_overlap': 379,
#                         'num_false_pos': 70,
#                         'num_merge': 223,
#                         'num_split': 184},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 70,
#                        'num_merge': 223,
#                        'num_split': 184}}

# %% [markdown]
# # Evaluate by document types

# %%
# For DBNet on Poem
# !python3 CLEval/script.py -g=/tmp/validate_poem/truth/truth.zip -s=/tmp/validate_poem/db/db.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 102/102 [00:05<00:00, 17.86it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9998879489047006,
#                'precision': 1.0,
#                'recall': 0.9997759229174836},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 2,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 2},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 2}}

# %%
# For EAST on Poem
# !python3 CLEval/script.py -g=/tmp/validate_poem/truth/truth.zip -s=/tmp/validate_poem/east/east.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 102/102 [00:05<00:00, 17.51it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9976149723617386,
#                'precision': 0.9993816055767933,
#                'recall': 0.9958545739734469},
#  'Detection_Metadata': {'char_false_pos': 11,
#                         'char_miss': 74,
#                         'char_overlap': 0,
#                         'num_false_pos': 11,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 11,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For DBNet on Prose
# !python3 CLEval/script.py -g=/tmp/validate_prose/truth/truth.zip -s=/tmp/validate_prose/db/db.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 492/492 [00:07<00:00, 62.63it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9957426442328503,
#                'precision': 0.9989058944934167,
#                'recall': 0.9925993649538541},
#  'Detection_Metadata': {'char_false_pos': 51,
#                         'char_miss': 564,
#                         'char_overlap': 5,
#                         'num_false_pos': 51,
#                         'num_merge': 16,
#                         'num_split': 33},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 51,
#                        'num_merge': 16,
#                        'num_split': 33}}

# %%
# For EAST on Prose
# !python3 CLEval/script.py -g=/tmp/validate_prose/truth/truth.zip -s=/tmp/validate_prose/east/east.zip --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 492/492 [00:07<00:00, 68.41it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9854529763321928,
#                'precision': 0.9890944935927031,
#                'recall': 0.9818381744276554},
#  'Detection_Metadata': {'char_false_pos': 66,
#                         'char_miss': 1241,
#                         'char_overlap': 379,
#                         'num_false_pos': 59,
#                         'num_merge': 223,
#                         'num_split': 184},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 59,
#                        'num_merge': 223,
#                        'num_split': 184}}

# %% [markdown]
# # Evaluate on each document

# %%
# For DBNet on Luc Van Tien
# !python3 CLEval/script.py -g='/tmp/validate/Luc Van Tien/truth/truth.zip' -s='/tmp/validate/Luc Van Tien/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 21/21 [00:00<00:00, 23.00it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.999552706127926,
#                'precision': 1.0,
#                'recall': 0.9991058122205663},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 2,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 1},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 1}}

# %%
# For DBNet on Tale of Kieu 1866
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1866/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1866/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 20/20 [00:01<00:00, 14.08it/s]
# 'Calculated!'
# {'Detection': {'hmean': 1.0, 'precision': 1.0, 'recall': 1.0},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 0,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For DBNet on Tale of Kieu 1871
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1871/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1871/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 28/28 [00:01<00:00, 14.19it/s]
# 'Calculated!'
# {'Detection': {'hmean': 1.0, 'precision': 1.0, 'recall': 1.0},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 0,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For DBNet on Tale of Kieu 1872
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1872/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1872/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 33/33 [00:01<00:00, 23.07it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9999052940619376,
#                'precision': 1.0,
#                'recall': 0.999810606060606},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 0,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 1},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 1}}

# %%
# For DBNet on DVSKTT-1 Quyen thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-1 Quyen thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-1 Quyen thu/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 21/21 [00:00<00:00, 38.42it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9897719975721964,
#                'precision': 0.9974271012006861,
#                'recall': 0.9822335025380711},
#  'Detection_Metadata': {'char_false_pos': 5,
#                         'char_miss': 37,
#                         'char_overlap': 0,
#                         'num_false_pos': 5,
#                         'num_merge': 1,
#                         'num_split': 5},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 5,
#                        'num_merge': 1,
#                        'num_split': 5}}

# %%
# For DBNet on DVSKTT-2 Ngoai ky toan thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-2 Ngoai ky toan thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-2 Ngoai ky toan thu/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 36/36 [00:01<00:00, 27.26it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.995568766145568,
#                'precision': 0.9996705649810574,
#                'recall': 0.9915004903563256},
#  'Detection_Metadata': {'char_false_pos': 1,
#                         'char_miss': 48,
#                         'char_overlap': 0,
#                         'num_false_pos': 1,
#                         'num_merge': 1,
#                         'num_split': 4},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 1,
#                        'num_merge': 1,
#                        'num_split': 4}}

# %%
# For DBNet on DVSKTT-3 Ban ky toan thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-3 Ban ky toan thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-3 Ban ky toan thu/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 187/187 [00:02<00:00, 76.95it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9968261634463529,
#                'precision': 0.9991770849818009,
#                'recall': 0.9944862787107345},
#  'Detection_Metadata': {'char_false_pos': 20,
#                         'char_miss': 166,
#                         'char_overlap': 2,
#                         'num_false_pos': 20,
#                         'num_merge': 2,
#                         'num_split': 8},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 20,
#                        'num_merge': 2,
#                        'num_split': 8}}

# %%
# For DBNet on DVSKTT-4 Ban ky thuc luc
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-4 Ban ky thuc luc/truth/truth.zip' -s='/tmp/validate/DVSKTT-4 Ban ky thuc luc/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 158/158 [00:02<00:00, 72.31it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.99629384313373,
#                'precision': 0.9986139986139986,
#                'recall': 0.9939844438484233},
#  'Detection_Metadata': {'char_false_pos': 18,
#                         'char_miss': 145,
#                         'char_overlap': 2,
#                         'num_false_pos': 18,
#                         'num_merge': 7,
#                         'num_split': 11},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 18,
#                        'num_merge': 7,
#                        'num_split': 11}}

# %%
# For DBNet on DVSKTT-5 Ban ky tuc bien
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-5 Ban ky tuc bien/truth/truth.zip' -s='/tmp/validate/DVSKTT-5 Ban ky tuc bien/db/db.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 90/90 [00:01<00:00, 63.25it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9934323766006162,
#                'precision': 0.9987551006293658,
#                'recall': 0.988166085231548},
#  'Detection_Metadata': {'char_false_pos': 7,
#                         'char_miss': 168,
#                         'char_overlap': 1,
#                         'num_false_pos': 7,
#                         'num_merge': 5,
#                         'num_split': 5},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 7,
#                        'num_merge': 5,
#                        'num_split': 5}}

# %%
# For EAST on Luc Van Tien
# !python3 CLEval/script.py -g='/tmp/validate/Luc Van Tien/truth/truth.zip' -s='/tmp/validate/Luc Van Tien/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 21/21 [00:00<00:00, 22.78it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9992551765231641,
#                'precision': 0.9988088147706968,
#                'recall': 0.9997019374068554},
#  'Detection_Metadata': {'char_false_pos': 4,
#                         'char_miss': 1,
#                         'char_overlap': 0,
#                         'num_false_pos': 4,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 4,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For EAST on Tale of Kieu 1866
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1866/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1866/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 20/20 [00:01<00:00, 14.23it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9997395833333333,
#                'precision': 0.9997395833333333,
#                'recall': 0.9997395833333333},
#  'Detection_Metadata': {'char_false_pos': 1,
#                         'char_miss': 1,
#                         'char_overlap': 0,
#                         'num_false_pos': 1,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 1,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For EAST on Tale of Kieu 1871
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1871/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1871/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 28/28 [00:01<00:00, 14.15it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9994422755158953,
#                'precision': 0.9988851727982163,
#                'recall': 1.0},
#  'Detection_Metadata': {'char_false_pos': 6,
#                         'char_miss': 0,
#                         'char_overlap': 0,
#                         'num_false_pos': 6,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 6,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For EAST on Tale of Kieu 1872
# !python3 CLEval/script.py -g='/tmp/validate/Tale of Kieu 1872/truth/truth.zip' -s='/tmp/validate/Tale of Kieu 1872/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 33/33 [00:01<00:00, 22.97it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9931350114416476,
#                'precision': 1.0,
#                'recall': 0.9863636363636363},
#  'Detection_Metadata': {'char_false_pos': 0,
#                         'char_miss': 72,
#                         'char_overlap': 0,
#                         'num_false_pos': 0,
#                         'num_merge': 0,
#                         'num_split': 0},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 0,
#                        'num_merge': 0,
#                        'num_split': 0}}

# %%
# For EAST on DVSKTT-1 Quyen thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-1 Quyen thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-1 Quyen thu/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 21/21 [00:00<00:00, 40.80it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9644032889371723,
#                'precision': 0.9760348583877996,
#                'recall': 0.9530456852791879},
#  'Detection_Metadata': {'char_false_pos': 2,
#                         'char_miss': 92,
#                         'char_overlap': 21,
#                         'num_false_pos': 2,
#                         'num_merge': 24,
#                         'num_split': 18},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 2,
#                        'num_merge': 24,
#                        'num_split': 18}}

# %%
# For EAST on DVSKTT-2 Ngoai ky toan thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-2 Ngoai ky toan thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-2 Ngoai ky toan thu/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 36/36 [00:01<00:00, 33.09it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9672362864394438,
#                'precision': 0.9729505476269499,
#                'recall': 0.961588754494933},
#  'Detection_Metadata': {'char_false_pos': 6,
#                         'char_miss': 180,
#                         'char_overlap': 82,
#                         'num_false_pos': 6,
#                         'num_merge': 49,
#                         'num_split': 49},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 6,
#                        'num_merge': 49,
#                        'num_split': 49}}

# %%
# For EAST on DVSKTT-3 Ban ky toan thu
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-3 Ban ky toan thu/truth/truth.zip' -s='/tmp/validate/DVSKTT-3 Ban ky toan thu/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 187/187 [00:02<00:00, 82.16it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9880270539569483,
#                'precision': 0.9901150080790799,
#                'recall': 0.9859478874570717},
#  'Detection_Metadata': {'char_false_pos': 26,
#                         'char_miss': 359,
#                         'char_overlap': 157,
#                         'num_false_pos': 23,
#                         'num_merge': 64,
#                         'num_split': 57},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 23,
#                        'num_merge': 64,
#                        'num_split': 57}}

# %%
# For EAST on DVSKTT-4 Ban ky thuc luc
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-4 Ban ky thuc luc/truth/truth.zip' -s='/tmp/validate/DVSKTT-4 Ban ky thuc luc/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 158/158 [00:01<00:00, 79.01it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9898043842867295,
#                'precision': 0.992885039248289,
#                'recall': 0.9867427870799648},
#  'Detection_Metadata': {'char_false_pos': 22,
#                         'char_miss': 317,
#                         'char_overlap': 57,
#                         'num_false_pos': 18,
#                         'num_merge': 41,
#                         'num_split': 27},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 18,
#                        'num_merge': 41,
#                        'num_split': 27}}

# %%
# For EAST on DVSKTT-5 Ban ky tuc bien
# !python3 CLEval/script.py -g='/tmp/validate/DVSKTT-5 Ban ky tuc bien/truth/truth.zip' -s='/tmp/validate/DVSKTT-5 Ban ky tuc bien/east/east.zip' --BOX_TYPE=QUAD
# Out:
# Integrating results...: 100% 90/90 [00:01<00:00, 67.99it/s]
# 'Calculated!'
# {'Detection': {'hmean': 0.9830543828454296,
#                'precision': 0.9888873454646478,
#                'recall': 0.9772898283056297},
#  'Detection_Metadata': {'char_false_pos': 10,
#                         'char_miss': 293,
#                         'char_overlap': 62,
#                         'num_false_pos': 10,
#                         'num_merge': 45,
#                         'num_split': 33},
#  'EndtoEnd': {'hmean': 0,
#               'precision': 0,
#               'recall': 0.0,
#               'recognition_score': 0},
#  'EndtoEnd_Metadata': {'char_false_pos': 0,
#                        'char_miss': 0,
#                        'num_false_pos': 10,
#                        'num_merge': 45,
#                        'num_split': 33}}
