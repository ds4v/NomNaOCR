# %%
# https://keras.io/examples/vision/handwriting_recognition
# https://keras.io/examples/vision/captcha_ocr
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Import the dataset

# %%
from dataset_handler import create_dataset, remove_rare_chars
DATA_PATH = '../../Dataset/trdg'
FONT_PATH = '../../Dataset/NomNaTong-Regular.ttf'
HEIGHT = 148
WIDTH = 32

# %% [markdown]
# ## Load and remove records with rare characters

# %%
img_paths, labels, vocabs = create_dataset(DATA_PATH)
img_paths, labels, vocabs = remove_rare_chars(img_paths, labels, vocabs, threshold=3)
print('Number of images found:', len(img_paths))
print('Number of labels found:', len(labels))
print('Number of unique characters:', len(vocabs))
print('Characters present:', vocabs, sep='')
# Out:
# Number of images found: 2889
# Number of labels found: 2889
# Number of unique characters: 1697
# Characters present:{'㐌': 316, '浪': 300, '朱': 247, '\U000f047c': 214, '\U000f070b': 213, '尼': 210, '吏': 200, '𦋦': 197, '𢚸': 197, '娘': 197, '𠊛': 192, '固': 189, '拱': 172, '之': 167, '情': 161, '埃': 161, '買': 151, '芇': 146, '𠬠': 145, '仙': 139, '欺': 138, '群': 136, '𠳒': 136, '麻': 130, '𠓨': 127, '𧗱': 124, '爫': 122, '別': 118, '塘': 117, '花': 114, '𠫾': 109, '𠄩': 108, '払': 106, '渚': 106, '𡗶': 106, '浽': 104, '傷': 103, '強': 102, '呐': 101, '渃': 99, '𦖑': 99, '饒': 97, '庒': 97, '如': 96, '些': 95, '分': 94, '冲': 94, '畧': 93, '咍': 92, '鐄': 90, '時': 90, '昆': 90, '低': 90, '𢬣': 89, '𡢐': 88, '身': 87, '兜': 87, '𧡊': 86, '於': 86, '細': 84, '生': 81, '月': 79, '公': 78, '戈': 78, '皮': 78, '調': 76, '﨤': 74, '𣈜': 74, '爲': 73, '茹': 73, '沛': 73, '牢': 73, '仍': 73, '油': 73, '命': 72, '排': 70, '典': 66, '包': 66, '娥': 65, '碎': 65, '㗂': 64, '\U000f061a': 63, '雲': 62, '𠁀': 61, '\U000f02c7': 61, '恩': 61, '迻': 59, '耒': 59, '茄': 57, '共': 57, '紅': 56, '催': 56, '貝': 56, '高': 56, '𠊚': 55, '\U000f0803': 55, '翁': 54, '𫢩': 53, '𦝄': 53, '頭': 52, '唉': 52, '𨑮': 52, '柴': 52, '𠇮': 52, '𠳨': 52, '𢪀': 51, '𢧚': 51, '車': 51, '匕': 51, '𠀧': 51, '絲': 51, '倍': 51, '𥙩': 50, '空': 50, '𩄲': 50, '世': 49, '衝': 49, '台': 49, '賒': 49, '明': 49, '底': 49, '外': 48, '香': 47, '特': 47, '童': 47, '它': 47, '才': 47, '�
, '及': 22, '併': 22, '迡': 22, '珠': 22, '和': 22, '楼': 22, '移': 22, '馭': 22, '官': 22, '窖': 22, '打': 22, '郑': 22, '寃': 21, '𥒥': 21, '\U000f0607': 21, '知': 21, '客': 21, '柳': 21, '盘': 21, '悲': 21, '計': 21, '待': 21, '常': 21, '房': 21, '誓': 21, '刀': 21, '𧵑': 21, '秩': 21, '終': 21, '𥘀': 20, '奇': 20, '𨖲': 20, '𦹵': 20, '𡆫': 20, '想': 20, '𥛉': 20, '\U000f0268': 20, '掣': 20, '澄': 20, '阻': 20, '呵': 20, '恪': 20, '容': 20, '畑': 20, '𫯳': 20, '盃': 20, '山': 20, '𠄼': 20, '𡛔': 20, '𫳵': 20, '病': 20, '貞': 20, '前': 19, '心': 19, '𠃅': 19, '鄧': 19, '故': 19, '𡑝': 19, '科': 19, '𣈙': 19, '不': 19, '平': 19, '丿': 19, '郎': 19, '重': 19, '英': 19, '𩈘': 19, '眉': 19, '最': 19, '兵': 19, '𣷭': 19, '𦣰': 19, '楚': 19, '𠓀': 18, '色': 18, '刼': 18, '又': 18, '相': 18, '䋦': 18, '𥆾': 18, '陣': 18, '决': 18, '酉': 18, '民': 18, '𪟽': 18, ...

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(img_paths, labels, font_path=FONT_PATH, text_x=WIDTH + 3)

# %% [markdown]
# ## Building the character vocabulary

# %%
# Mapping characters to integers
char2num = tf.keras.layers.StringLookup(
    vocabulary = list(vocabs), 
    mask_token = None,
    encoding = 'utf-8'
)

# Mapping integers back to original characters
num2char = tf.keras.layers.StringLookup(
    vocabulary = char2num.get_vocabulary(), 
    mask_token = None, 
    invert = True,
    encoding = 'utf-8'
)

# %% [markdown]
# # Define the model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Dense, Bidirectional, GRU,
    Lambda, RepeatVector, Permute, multiply
)
from cnn import custom_cnn, get_imagenet_model, reshape_for_cnn
from ctc import CTCLayer

# %%
# https://pbcquoc.github.io/vietnamese-ocr (Vietnamese blog)
def visual_attention(feature_maps):
    _, timestep, input_dim = feature_maps.shape
    a = Permute((2, 1), name='dim_switching')(feature_maps)
    a = Dense(timestep, activation='softmax', name='attention_weights')(a)
    
    # Calculate the average of all timesteps and multiply by 100 to convert
    # the fraction obtained from the softmax calculation into a percentage
    a = Lambda(
        lambda x: tf.keras.backend.mean(x, axis=1) * 100, 
        name = 'average_weight'
    )(a)
    
    a = RepeatVector(input_dim, name='redistribute')(a)
    a = Permute((2, 1), name='attention_vector')(a) 
    return multiply([feature_maps, a], name='context_vector')

# %%
def build_crnn(imagenet_model=None, imagenet_output_layer=None, name='CRNN'):
    label_input = Input(shape=(None,), dtype='int64', name='label')
    label_length = Input(shape=[1], dtype='int64', name='label_length')
    
    # CNN layers
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 1), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (1, 2)}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)
        
    # Reshape accordingly before passing output to RNN and apply attention mechanism
    x = reshape_for_cnn(x, dim_to_keep=-1)
    x = visual_attention(x)
    
    # RNN layers
    bigru_layers = [512, 512]
    for idx in range(len(bigru_layers)):
        x = Bidirectional(GRU(
            units = bigru_layers[idx], 
            return_sequences = True, 
            dropout = 0.2,
        ), name = f'bigru{idx + 1}')(x)

    # Output layer
    y_pred = Dense(
        units = char2num.vocabulary_size() + 1, # + 1 blank character for CTC loss
        activation = 'softmax', 
        name = 'rnn_output'
    )(x)

    # Compile the model and return
    model = Model(
        inputs = [image_input, label_input, label_length], 
        outputs = CTCLayer()(label_input, y_pred, label_length), 
        name = name
    )
    return model

# %%
## Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 1))
# imagenet_model.summary(line_length=100)

# %%
# imagenet_output_layer = 'block4_pool'
# model = build_crnn(imagenet_model, imagenet_output_layer)
model = build_crnn()
model.summary(line_length=100)
# Out:
# Model: "CRNN"
# ____________________________________________________________________________________________________
#  Layer (type)                    Output Shape          Param #     Connected to
# ====================================================================================================
#  image (InputLayer)              [(None, 148, 32, 1)]  0           []
#
#  block1_conv1 (Conv2D)           (None, 148, 32, 64)   640         ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)  (None, 148, 32, 64)  256         ['block1_conv1[0][0]']
#
#  block1_activation1 (LeakyReLU)  (None, 148, 32, 64)   0           ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)      (None, 74, 16, 64)    0           ['block1_activation1[0][0]']
#
#  block2_conv1 (Conv2D)           (None, 74, 16, 128)   73856       ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)  (None, 74, 16, 128)  512         ['block2_conv1[0][0]']
#
#  block2_activation1 (LeakyReLU)  (None, 74, 16, 128)   0           ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)      (None, 37, 8, 128)    0           ['block2_activation1[0][0]']
#
#  block3_conv1 (Conv2D)           (None, 37, 8, 256)    295168      ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv1[0][0]']
#
#  block3_activation1 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)           (None, 37, 8, 256)    590080      ['block3_activation1[0][0]']
#
#  block3_bn2 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv2[0][0]']
#
#  block3_activation2 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)      (None, 18, 4, 256)    0           ['block3_activation2[0][0]']
#
#  block4_conv1 (Conv2D)           (None, 18, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv1[0][0]']
#
#  block4_activation1 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)           (None, 18, 4, 512)    2359808     ['block4_activation1[0][0]']
#
#  block4_bn2 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv2[0][0]']
#
#  block4_activation2 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)      (None, 18, 2, 512)    0           ['block4_activation2[0][0]']
#
#  final_conv (Conv2D)             (None, 17, 1, 512)    1049088     ['block4_pool[0][0]']
#
#  final_bn (BatchNormalization)   (None, 17, 1, 512)    2048        ['final_conv[0][0]']
#
#  final_activation (LeakyReLU)    (None, 17, 1, 512)    0           ['final_bn[0][0]']
#
#  rnn_input (Reshape)             (None, 17, 512)       0           ['final_activation[0][0]']
#
#  dim_switching (Permute)         (None, 512, 17)       0           ['rnn_input[0][0]']
#
#  attention_weights (Dense)       (None, 512, 17)       306         ['dim_switching[0][0]']
#
#  average_weight (Lambda)         (None, 17)            0           ['attention_weights[0][0]']
#
#  redistribute (RepeatVector)     (None, 512, 17)       0           ['average_weight[0][0]']
#
#  attention_vector (Permute)      (None, 17, 512)       0           ['redistribute[0][0]']
#
#  context_vector (Multiply)       (None, 17, 512)       0           ['rnn_input[0][0]',
#                                                                     'attention_vector[0][0]']
#
#  bigru1 (Bidirectional)          (None, 17, 1024)      3151872     ['context_vector[0][0]']
#
#  bigru2 (Bidirectional)          (None, 17, 1024)      4724736     ['bigru1[0][0]']
#
#  label (InputLayer)              [(None, None)]        0           []
#
#  rnn_output (Dense)              (None, 17, 1699)      1741475     ['bigru2[0][0]']
#
#  label_length (InputLayer)       [(None, 1)]           0           []
#
#  ctc_loss (CTCLayer)             (None, 17, 1699)      0           ['label[0][0]',
#                                                                     'rnn_output[0][0]',
#                                                                     'label_length[0][0]']
#
# ====================================================================================================
# Total params: 15,176,149
# Trainable params: 15,171,669
# Non-trainable params: 4,480
# ____________________________________________________________________________________________________

# %% [markdown]
# # Training

# %%
from dataset_handler import process_one_image
MAX_LENGTH = max([len(label) for label in labels])
PADDING_TOKEN = char2num.vocabulary_size()
AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 16

# %% [markdown]
# ## Data input pipeline

# %%
def process_images_labels(img_path, label, img_size=(HEIGHT, WIDTH)):
    image = process_one_image(img_path, img_size)
    label = char2num(tf.strings.unicode_split(label, input_encoding='UTF-8'))
    label_length = tf.shape(label, tf.int64)[0]
    label = tf.pad(
        label, 
        paddings = [[0, MAX_LENGTH - label_length]], 
        constant_values = PADDING_TOKEN
    )
    return {'image': image, 'label': label, 'label_length': label_length}

# %%
def prepare_tf_dataset(img_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((img_paths, labels)).map(
        process_images_labels, num_parallel_calls=AUTOTUNE
    )
    return dataset.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from custom_callbacks import EditDistanceCallback, EarlyStoppingWithStuck
early_stopping_callback = EarlyStoppingWithStuck(patience=5)

def scheduler(epoch, lr):
    if epoch == 0 or (epoch % 10) > 0: return lr # Keeps lr for 10 epochs
    return lr * tf.math.exp(-0.2) # Decreases it exponentially after that
schedule_lr_callback = LearningRateScheduler(scheduler, verbose=1)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_delta = 0.001, # The val_loss should at least improve 0.001
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Cross validation with K-Fold

# %%
from kfold import kfold_decorator
from tensorflow.keras.optimizers import Adam
LEARNING_RATE = 2e-4
EPOCHS = 100

# %%
@kfold_decorator(n_splits=10)
def train(model, img_paths, labels, train_idx=None, valid_idx=None):
    train_tf_dataset = prepare_tf_dataset(img_paths[train_idx], labels[train_idx])
    valid_tf_dataset = prepare_tf_dataset(img_paths[valid_idx], labels[valid_idx])
    
    model.compile(optimizer=Adam(learning_rate=LEARNING_RATE))
    edit_distance_callback = EditDistanceCallback(Model(
        inputs = model.get_layer('image').input, 
        outputs = model.get_layer('rnn_output').output
    ), valid_tf_dataset, MAX_LENGTH)
    
    history = model.fit(
        train_tf_dataset,
        validation_data = valid_tf_dataset,
        epochs = EPOCHS,
        callbacks = [
#             checkpoint_callback,
#             schedule_lr_callback, 
            reduce_lr_callback, 
            edit_distance_callback, 
            early_stopping_callback,
        ],
        verbose = 1
    )
    return (
        valid_tf_dataset, 
        early_stopping_callback.best_epoch, 
        edit_distance_callback.logs,
        history,
    )

# %%
# %%time
valid_datasets, best_epochs, edist_logs, histories, models = train(model, img_paths, labels)
# Out:
# Start training for Fold 1:
# Epoch 1/100
# 163/163 [==============================] - ETA: 0s - loss: 51.2967 - Mean edit distance: 8.0
# 163/163 [==============================] - 14s 49ms/step - loss: 51.2967 - val_loss: 49.3610 - lr: 2.0000e-04
# Epoch 2/100
# 162/163 [============================>.] - ETA: 0s - loss: 46.1067 - Mean edit distance: 7.993421
# 163/163 [==============================] - 5s 33ms/step - loss: 46.1258 - val_loss: 49.4804 - lr: 2.0000e-04
# Epoch 3/100
# 161/163 [============================>.] - ETA: 0s - loss: 41.3037 - Mean edit distance: 7.888158
# 163/163 [==============================] - 5s 32ms/step - loss: 41.2880 - val_loss: 43.0289 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 29.3789 - Mean edit distance: 5.9013157
# 163/163 [==============================] - 5s 32ms/step - loss: 29.3643 - val_loss: 26.1884 - lr: 2.0000e-04
# Epoch 5/100
# 161/163 [============================>.] - ETA: 0s - loss: 16.6841 - Mean edit distance: 3.7598684
100
# 163/163 [==============================] - ETA: 0s - loss: 0.0502 - Mean edit distance: 1.6710526
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0502 - val_loss: 2.9121 - lr: 2.0000e-04
# Epoch 24/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0445 - Mean edit distance: 1.6710526
# 163/163 [==============================] - 6s 34ms/step - loss: 0.0445 - val_loss: 2.8594 - lr: 2.0000e-04
# Epoch 25/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0400 - Mean edit distance: 1.6809211
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0400 - val_loss: 2.8758 - lr: 2.0000e-04
# Epoch 26/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0360
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#  - Mean edit distance: 1.6940789
# 163/163 [==============================] - 6s 35ms/step - loss: 0.0360 - val_loss: 2.8628 - lr: 2.0000e-04
# Epoch 27/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0329 - Mean edit distance: 1.6578947
# 163/163 [==============================] - 6s 34ms/step - loss: 0.0329 - val_loss: 2.7748 - lr: 1.0000e-04
# Epoch 28/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0309 - Mean edit distance: 1.6578947
# 163/163 [==============================] - 6s 35ms/step - loss: 0.0309 - val_loss: 2.8141 - lr: 1.0000e-04
# Epoch 29/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0293
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  - Mean edit distance: 1.6480263
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0293 - val_loss: 2.7765 - lr: 1.0000e-04
# Epoch 30/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0281 - Mean edit distance: 1.6480263
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0281 - val_loss: 2.7897 - lr: 5.0000e-05
# Epoch 31/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0271
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  - Mean edit distance: 1.6546053
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0271 - val_loss: 2.7879 - lr: 5.0000e-05
# Epoch 32/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0263 - Mean edit distance: 1.6546053
# Restored weights from the end of epoch: 27
# 163/163 [==============================] - 6s 35ms/step - loss: 0.0263 - val_loss: 2.7959 - lr: 2.5000e-05
# Epoch 32: early stopping
# Finish training for Fold 1
#
# Start training for Fold 2:
# Epoch 1/100
# 162/163 [============================>.] - ETA: 0s - loss: 51.2806 - Mean edit distance: 8.0
# 163/163 [==============================] - 12s 45ms/step - loss: 51.2998 - val_loss: 50.2197 - lr: 2.0000e-04
# Epoch 2/100
# 162/163 [============================>.] - ETA: 0s - loss: 46.7801 - Mean edit distance: 7.986842
# 163/163 [==============================] - 5s 34ms/step - loss: 46.8008 - val_loss: 48.8638 - lr: 2.0000e-04
# Epoch 3/100
# 161/163 [============================>.] - ETA: 0s - loss: 43.4479 - Mean edit distance: 7.9638157
# 163/163 [==============================] - 5s 34ms/step - loss: 43.4666 - val_loss: 44.2067 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 37.0763 - Mean edit distance: 7.4638157
# 163/163 [==============================] - 6s 35ms/step - loss: 37.0752 - val_loss: 35.5036 - lr: 2.0000e-04
# Epoch 5/100
# 161/163 [============================>.] - ETA: 0s - loss: 25.8582 - Mean edit distance: 6.3486843
# 163/163 [==============================] - 6s 34ms/step - loss: 25.8211 - val_loss: 27.3078 - lr: 2.0000e-04
# Epoch 6/100
# 162/163 [============================>.] - ETA: 0s - loss: 16.8285 - Mean edit distance: 4.700658
# 163/163 [==============================] - 5s 33ms/step - loss: 16.8153 - val_loss: 19.3161 - lr: 2.0000e-04
# Epoch 7/100
# 161/163 [============================>.] - ETA: 0s - loss: 10.6241 - Mean edit distance: 3.7697368
100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0204 - Mean edit distance: 1.8980263
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0204 - val_loss: 4.0390 - lr: 2.5000e-05
# Epoch 45/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0199 - Mean edit distance: 1.9111842
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0199 - val_loss: 4.0195 - lr: 2.5000e-05
# Epoch 46/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0194 - Mean edit distance: 1.8980263
# 163/163 [==============================] - 5s 34ms/step - loss: 0.0194 - val_loss: 3.9977 - lr: 2.5000e-05
# Epoch 47/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0188 - Mean edit distance: 1.8980263
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0188 - val_loss: 3.9894 - lr: 2.5000e-05
# Epoch 48/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0183 - Mean edit distance: 1.9046053
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0183 - val_loss: 3.9863 - lr: 2.5000e-05
# Epoch 49/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0177 - Mean edit distance: 1.8848684
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0177 - val_loss: 3.9559 - lr: 2.5000e-05
# Epoch 50/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0172 - Mean edit distance: 1.9078947
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0172 - val_loss: 3.9730 - lr: 2.5000e-05
# Epoch 51/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  - Mean edit distance: 1.8848684
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0167 - val_loss: 3.9728 - lr: 2.5000e-05
# Epoch 52/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0167 - Mean edit distance: 1.875
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0166 - val_loss: 3.9304 - lr: 1.2500e-05
# Epoch 53/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0161 - Mean edit distance: 1.8618422
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0161 - val_loss: 3.9077 - lr: 1.2500e-05
# Epoch 54/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0159 - Mean edit distance: 1.8717105
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0159 - val_loss: 3.9059 - lr: 1.2500e-05
# Epoch 55/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0156 - Mean edit distance: 1.8848684
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0156 - val_loss: 3.9323 - lr: 1.2500e-05
# Epoch 56/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0152
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#  - Mean edit distance: 1.8684211
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0152 - val_loss: 3.9452 - lr: 1.2500e-05
# Epoch 57/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0152 - Mean edit distance: 1.8782895
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0152 - val_loss: 3.8962 - lr: 6.2500e-06
# Epoch 58/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0148 - Mean edit distance: 1.875
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0148 - val_loss: 3.8905 - lr: 6.2500e-06
# Epoch 59/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0145 - Mean edit distance: 1.8651316
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0145 - val_loss: 3.8951 - lr: 6.2500e-06
# Epoch 60/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0144
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#  - Mean edit distance: 1.8717105
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0144 - val_loss: 3.9056 - lr: 6.2500e-06
# Epoch 61/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0143 - Mean edit distance: 1.8684211
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0143 - val_loss: 3.9019 - lr: 3.1250e-06
# Epoch 62/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0141 - Mean edit distance: 1.8717105
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0141 - val_loss: 3.8871 - lr: 3.1250e-06
# Epoch 63/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0140 - Mean edit distance: 1.8717105
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0140 - val_loss: 3.8994 - lr: 3.1250e-06
# Epoch 64/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0139
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#  - Mean edit distance: 1.8684211
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0139 - val_loss: 3.8873 - lr: 3.1250e-06
# Epoch 65/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0137 - Mean edit distance: 1.8585526
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0137 - val_loss: 3.8924 - lr: 1.5625e-06
# Epoch 66/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0137
# Epoch 66: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
#  - Mean edit distance: 1.8618422
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0137 - val_loss: 3.8907 - lr: 1.5625e-06
# Epoch 67/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0137 - Mean edit distance: 1.8651316
# Restored weights from the end of epoch: 62
# 163/163 [==============================] - 5s 33ms/step - loss: 0.
100
# 163/163 [==============================] - ETA: 0s - loss: 0.0274 - Mean edit distance: 1.5381944
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0274 - val_loss: 2.6288 - lr: 1.0000e-04
# Epoch 32/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0254
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  - Mean edit distance: 1.5069444
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0254 - val_loss: 2.6745 - lr: 1.0000e-04
# Epoch 33/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0243 - Mean edit distance: 1.4826388
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0243 - val_loss: 2.6286 - lr: 5.0000e-05
# Epoch 34/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0235 - Mean edit distance: 1.4895834
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0235 - val_loss: 2.6233 - lr: 5.0000e-05
# Epoch 35/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0226 - Mean edit distance: 1.4791666
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0227 - val_loss: 2.6124 - lr: 5.0000e-05
# Epoch 36/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0219 - Mean edit distance: 1.4895834
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0220 - val_loss: 2.6190 - lr: 5.0000e-05
# Epoch 37/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 37: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  - Mean edit distance: 1.5138888
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0211 - val_loss: 2.6115 - lr: 5.0000e-05
# Epoch 38/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0205 - Mean edit distance: 1.4756944
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0205 - val_loss: 2.5872 - lr: 2.5000e-05
# Epoch 39/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0200 - Mean edit distance: 1.4861112
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0200 - val_loss: 2.6001 - lr: 2.5000e-05
# Epoch 40/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  - Mean edit distance: 1.4826388
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0196 - val_loss: 2.5978 - lr: 2.5000e-05
# Epoch 41/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0192 - Mean edit distance: 1.4861112
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0192 - val_loss: 2.5904 - lr: 1.2500e-05
# Epoch 42/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0190 - Mean edit distance: 1.4861112
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0190 - val_loss: 2.5839 - lr: 1.2500e-05
# Epoch 43/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0188 - Mean edit distance: 1.4826388
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0188 - val_loss: 2.5914 - lr: 1.2500e-05
# Epoch 44/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0184
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#  - Mean edit distance: 1.4791666
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0184 - val_loss: 2.5944 - lr: 1.2500e-05
# Epoch 45/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0182 - Mean edit distance: 1.4791666
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0182 - val_loss: 2.5773 - lr: 6.2500e-06
# Epoch 46/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0181 - Mean edit distance: 1.4756944
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0181 - val_loss: 2.5812 - lr: 6.2500e-06
# Epoch 47/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0179
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#  - Mean edit distance: 1.4930556
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0179 - val_loss: 2.5882 - lr: 6.2500e-06
# Epoch 48/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0178 - Mean edit distance: 1.4791666
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0178 - val_loss: 2.5861 - lr: 3.1250e-06
# Epoch 49/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0177
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
#  - Mean edit distance: 1.4826388
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0177 - val_loss: 2.5855 - lr: 3.1250e-06
# Epoch 50/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0176 - Mean edit distance: 1.4791666
# Restored weights from the end of epoch: 45
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0176 - val_loss: 2.5871 - lr: 1.5625e-06
# Epoch 50: early stopping
# Finish training for Fold 10
#
# Wall time: 41min 13s

# %% [markdown]
# ## Get the best CRNN model and its results

# %%
from kfold import get_best_fold
from visualizer import plot_training_results
(
    best_valid_dataset, 
    best_edist_log, 
    best_history,
    best_model,
    best_fold_idx, 
    best_loss
) = get_best_fold(valid_datasets, best_epochs, edist_logs, histories, models)
# Out:
# Fold 01 - Mean edit distance: 1.6578947305679321
# 19/19 [==============================] - 0s 14ms/step - loss: 2.7748
# Fold 02 - Mean edit distance: 1.8717105388641357
# 19/19 [==============================] - 0s 14ms/step - loss: 3.8871
# Fold 03 - Mean edit distance: 1.5394736528396606
# 19/19 [==============================] - 0s 14ms/step - loss: 2.3568
# Fold 04 - Mean edit distance: 1.388157844543457
# 19/19 [==============================] - 0s 13ms/step - loss: 2.4670
# Fold 05 - Mean edit distance: 1.3914474248886108
# 19/19 [==============================] - 0s 13ms/step - loss: 2.9373
# Fold 06 - Mean edit distance: 1.2796052694320679
# 19/19 [==============================] - 0s 14ms/step - loss: 2.3693
# Fold 07 - Mean edit distance: 1.5657894611358643
# 19/19 [==============================] - 0s 14ms/step - loss: 2.6095
# Fold 08 - Mean edit distance: 1.5032894611358643
# 19/19 [==============================] - 0s 13ms/step - loss: 2.7365
# Fold 09 - Mean edit distance: 1.6644736528396606
# 19/19 [==============================] - 0s 14ms/step - loss: 2.9466
# Fold 10 - Mean edit distance: 1.4791666269302368
# 18/18 [==============================] - 0s 14ms/step - loss: 2.5773

# %%
print('Fold', best_fold_idx, 'has the best loss:', best_loss)
plot_training_results(best_history, best_edist_log, 'crnn_trdg_history.png')
best_model.save('crnn_trdg.h5')
# Out:
# Fold 2 has the best loss: 2.356799602508545

# %% [markdown]
# # Inference

# %%
from tensorflow.keras.models import Model, load_model
from ctc import CTCLayer, decode_batch_predictions
valid_dataset, valid_idxs = best_valid_dataset

# %% [markdown]
# ## Reload the model

# %%
reloaded_model = load_model('crnn_trdg.h5', custom_objects={'CTCLayer': CTCLayer})
reloaded_prediction_model = Model(
    inputs = reloaded_model.get_layer('image').input, 
    outputs = reloaded_model.get_layer('rnn_output').output
)
reloaded_model.summary(line_length=100)
# Out:
# Model: "Model_3"
# ____________________________________________________________________________________________________
#  Layer (type)                    Output Shape          Param #     Connected to
# ====================================================================================================
#  image (InputLayer)              [(None, 148, 32, 1)]  0           []
#
#  block1_conv1 (Conv2D)           (None, 148, 32, 64)   640         ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)  (None, 148, 32, 64)  256         ['block1_conv1[0][0]']
#
#  block1_activation1 (LeakyReLU)  (None, 148, 32, 64)   0           ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)      (None, 74, 16, 64)    0           ['block1_activation1[0][0]']
#
#  block2_conv1 (Conv2D)           (None, 74, 16, 128)   73856       ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)  (None, 74, 16, 128)  512         ['block2_conv1[0][0]']
#
#  block2_activation1 (LeakyReLU)  (None, 74, 16, 128)   0           ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)      (None, 37, 8, 128)    0           ['block2_activation1[0][0]']
#
#  block3_conv1 (Conv2D)           (None, 37, 8, 256)    295168      ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv1[0][0]']
#
#  block3_activation1 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)           (None, 37, 8, 256)    590080      ['block3_activation1[0][0]']
#
#  block3_bn2 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv2[0][0]']
#
#  block3_activation2 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)      (None, 18, 4, 256)    0           ['block3_activation2[0][0]']
#
#  block4_conv1 (Conv2D)           (None, 18, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv1[0][0]']
#
#  block4_activation1 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)           (None, 18, 4, 512)    2359808     ['block4_activation1[0][0]']
#
#  block4_bn2 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv2[0][0]']
#
#  block4_activation2 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)      (None, 18, 2, 512)    0           ['block4_activation2[0][0]']
#
#  final_conv (Conv2D)             (None, 17, 1, 512)    1049088     ['block4_pool[0][0]']
#
#  final_bn (BatchNormalization)   (None, 17, 1, 512)    2048        ['final_conv[0][0]']
#
#  final_activation (LeakyReLU)    (None, 17, 1, 512)    0           ['final_bn[0][0]']
#
#  rnn_input (Reshape)             (None, 17, 512)       0           ['final_activation[0][0]']
#
#  dim_switching (Permute)         (None, 512, 17)       0           ['rnn_input[0][0]']
#
#  attention_weights (Dense)       (None, 512, 17)       306         ['dim_switching[0][0]']
#
#  average_weight (Lambda)         (None, 17)            0           ['attention_weights[0][0]']
#
#  redistribute (RepeatVector)     (None, 512, 17)       0           ['average_weight[0][0]']
#
#  attention_vector (Permute)      (None, 17, 512)       0           ['redistribute[0][0]']
#
#  context_vector (Multiply)       (None, 17, 512)       0           ['rnn_input[0][0]',
#                                                                     'attention_vector[0][0]']
#
#  bigru1 (Bidirectional)          (None, 17, 1024)      3151872     ['context_vector[0][0]']
#
#  bigru2 (Bidirectional)          (None, 17, 1024)      4724736     ['bigru1[0][0]']
#
#  label (InputLayer)              [(None, None)]        0           []
#
#  label_length (InputLayer)       [(None, 1)]           0           []
#
#  rnn_output (Dense)              (None, 17, 1699)      1741475     ['bigru2[0][0]']
#
#  ctc_loss (CTCLayer)             (None, 17, 1699)      0           ['label[0][0]',
#                                                                     'label_length[0][0]',
#                                                                     'rnn_output[0][0]']
#
# ====================================================================================================
# Total params: 15,176,149
# Trainable params: 15,171,669
# Non-trainable params: 4,480
# ____________________________________________________________________________________________________

# %% [markdown]
# ## On test dataset

# %%
for idx, batch in enumerate(valid_dataset.take(3)):
    idxs_in_batch = valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    labels_in_batch = []
    
    for label in batch['label']:
        # Gather indices where label != padding_token.
        not_padding = tf.math.not_equal(label, PADDING_TOKEN)
        indices = tf.gather(label, tf.where(not_padding))
        label = tf.strings.reduce_join(num2char(indices)) # Convert to string
        labels_in_batch.append(label.numpy().decode('utf-8'))
        
    preds = reloaded_prediction_model.predict(batch['image'])
    pred_labels = decode_batch_predictions(preds, MAX_LENGTH, 20, num2char)
    visualize_images_labels(
        img_paths = img_paths[idxs_in_batch], 
        labels = labels_in_batch, 
        pred_labels = pred_labels,
        font_path = FONT_PATH, 
        text_x = WIDTH + 3 # Position of actual label to plot
    )
    print(f'Batch {idx + 1}: {labels_in_batch}\n')
# Out:
# Batch 1: ['㐌空縁畧庄麻', '㗂牟派派如𡗶覩湄', '䏾核𦝄㐌拮頭', '䏾花苔坦𨤔銀昂𡗶', '䏾𦝄𣃣格梗橷', '䜹浪停𥙩爫制', '䜹浪碎寔𠊛𬆄', '䜹茹萱歇每情', '世芇拱拯酉衝特芇', '事兜渚急堆囬', '事尼別併世芇特低', '云仙之掣浽愁', '云仙課畧於尼厨廛', '云仙𠓨准書楼𢪀安', '云仙𣃣𨀈蹎𦋦', '云仙\U000f0803妸小童移蹎']
#
# Batch 2: ['些低沛摱埃兜𦓡浪', '仍啉呂浽渃𡽫朱耒', '仍調鐄𥒥沛調呐空', '仍𠇮芇別固春\U000f047c之', '仰𬂙量𢌌皮𨕭', '伶伶昔越固𠄩𫳘題', '侈𣃣典𣅶更𠀧', '便塘拱吏尋娘𡢐初', '信茹𣈜\U000f070b永信', '停𢚸除妬𠃣𥹰', '傷柴童子高賒', '傷饒吀𢖵𠳒饒', '傷𢝙𪽝在𢚸尼', '價停𥪞月𨕭𩄲', '儈頭払仍拔\U000f0810湥霜', '儉歆群𢪀菫𠽐']
#
# Batch 3: ['公浪幅像𠊚𠸗', '公浪悶論𭛣𨉓', '公浪\U000f0586𩈘𠄩昆', '六公𢖵細俸連哭嘆', '六公𫢩㐌𡏦营於廊', '共妑武后調連細低', '共饒蹺𨃴差衙', '共𤽗骨突打連最㝵', '兵𡆫外隘㐌苔兎山', '几硯𠊛笈質塘', '分油油丕拱油', '別信自意旦𫢩', '別兜地獄天堂\U000f047c兜', '別娘拱預軍中論盘', '別𡆫催固上程爫之', '别綠命别分命世傕']

# %% [markdown]
# ## On random image

# %%
random_path = '../大越史記全書.jpg'
random_label = '大越史記全書'
random_image = process_images_labels(random_path, random_label)
batch_images = tf.expand_dims(random_image['image'], axis=0)

# %%
preds = reloaded_prediction_model.predict(batch_images)
pred_labels = decode_batch_predictions(preds, MAX_LENGTH, 20, num2char)
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    show_legend = False,
    font_path = FONT_PATH, 
    text_x = WIDTH + 3 # Position of actual label to plot
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 大越史記会書
