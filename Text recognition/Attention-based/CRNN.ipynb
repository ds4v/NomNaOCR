# %%
# https://keras.io/examples/vision/handwriting_recognition
# https://keras.io/examples/vision/captcha_ocr
import sys
import tensorflow as tf
sys.path.append('..')
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# # Check GPU working

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0': raise SystemError('GPU device not found')
print('Found GPU at:', device_name)
# !nvcc -V
# Out:
# Found GPU at: /device:GPU:0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Nov_30_19:15:10_Pacific_Standard_Time_2020
# Cuda compilation tools, release 11.2, V11.2.67
# Build cuda_11.2.r11.2/compiler.29373293_0

# %% [markdown]
# # Import the dataset

# %%
from dataset_handler import create_dataset, remove_rare_chars
DATA_PATH = '../../Dataset/trdg'
FONT_PATH = '../../Dataset/NomNaTong-Regular.ttf'
HEIGHT = 148
WIDTH = 32

# %% [markdown]
# ## Load and remove records with rare characters

# %%
img_paths, labels, vocabs = create_dataset(DATA_PATH)
img_paths, labels, vocabs = remove_rare_chars(img_paths, labels, vocabs, threshold=3)
print('Number of images found:', len(img_paths))
print('Number of labels found:', len(labels))
print('Number of unique characters:', len(vocabs))
print('Characters present:', vocabs, sep='')
# Out:
# Number of images found: 2889
# Number of labels found: 2889
# Number of unique characters: 1697
# Characters present:{'㐌': 316, '浪': 300, '朱': 247, '\U000f047c': 214, '\U000f070b': 213, '尼': 210, '吏': 200, '𦋦': 197, '𢚸': 197, '娘': 197, '𠊛': 192, '固': 189, '拱': 172, '之': 167, '情': 161, '埃': 161, '買': 151, '芇': 146, '𠬠': 145, '仙': 139, '欺': 138, '群': 136, '𠳒': 136, '麻': 130, '𠓨': 127, '𧗱': 124, '爫': 122, '別': 118, '塘': 117, '花': 114, '𠫾': 109, '𠄩': 108, '払': 106, '渚': 106, '𡗶': 106, '浽': 104, '傷': 103, '強': 102, '呐': 101, '渃': 99, '𦖑': 99, '饒': 97, '庒': 97, '如': 96, '些': 95, '分': 94, '冲': 94, '畧': 93, '咍': 92, '鐄': 90, '時': 90, '昆': 90, '低': 90, '𢬣': 89, '𡢐': 88, '身': 87, '兜': 87, '𧡊': 86, '於': 86, '細': 84, '生': 81, '月': 79, '公': 78, '戈': 78, '皮': 78, '調': 76, '﨤': 74, '𣈜': 74, '爲': 73, '茹': 73, '沛': 73, '牢': 73, '仍': 73, '油': 73, '命': 72, '排': 70, '典': 66, '包': 66, '娥': 65, '碎': 65, '㗂': 64, '\U000f061a': 63, '雲': 62, '𠁀': 61, '\U000f02c7': 61, '恩': 61, '迻': 59, '耒': 59, '茄': 57, '共': 57, '紅': 56, '催': 56, '貝': 56, '高': 56, '𠊚': 55, '\U000f0803': 55, '翁': 54, '𫢩': 53, '𦝄': 53, '頭': 52, '唉': 52, '𨑮': 52, '柴': 52, '𠇮': 52, '𠳨': 52, '𢪀': 51, '𢧚': 51, '車': 51, '匕': 51, '𠀧': 51, '絲': 51, '倍': 51, '𥙩': 50, '空': 50, '𩄲': 50, '世': 49, '衝': 49, '台': 49, '賒': 49, '明': 49, '底': 49, '外': 48, '香': 47, '特': 47, '童': 47, '它': 47, '才': 47, '
�': 22, '及': 22, '併': 22, '迡': 22, '珠': 22, '和': 22, '楼': 22, '移': 22, '馭': 22, '官': 22, '窖': 22, '打': 22, '郑': 22, '寃': 21, '𥒥': 21, '\U000f0607': 21, '知': 21, '客': 21, '柳': 21, '盘': 21, '悲': 21, '計': 21, '待': 21, '常': 21, '房': 21, '誓': 21, '刀': 21, '𧵑': 21, '秩': 21, '終': 21, '𥘀': 20, '奇': 20, '𨖲': 20, '𦹵': 20, '𡆫': 20, '想': 20, '𥛉': 20, '\U000f0268': 20, '掣': 20, '澄': 20, '阻': 20, '呵': 20, '恪': 20, '容': 20, '畑': 20, '𫯳': 20, '盃': 20, '山': 20, '𠄼': 20, '𡛔': 20, '𫳵': 20, '病': 20, '貞': 20, '前': 19, '心': 19, '𠃅': 19, '鄧': 19, '故': 19, '𡑝': 19, '科': 19, '𣈙': 19, '不': 19, '平': 19, '丿': 19, '郎': 19, '重': 19, '英': 19, '𩈘': 19, '眉': 19, '最': 19, '兵': 19, '𣷭': 19, '𦣰': 19, '楚': 19, '𠓀': 18, '色': 18, '刼': 18, '又': 18, '相': 18, '䋦': 18, '𥆾': 18, '陣': 18, '决': 18, '酉': 18, '民': 18, '𪟽': 18, ...

# %% [markdown]
# ## Visualize the data

# %%
from visualizer import visualize_images_labels
visualize_images_labels(img_paths, labels, font_path=FONT_PATH, text_x=WIDTH + 3)

# %% [markdown]
# ## Building the character vocabulary

# %%
# Mapping characters to integers
char2num = tf.keras.layers.StringLookup(
    vocabulary = list(vocabs), 
    mask_token = None,
    encoding = 'utf-8'
)

# Mapping integers back to original characters
num2char = tf.keras.layers.StringLookup(
    vocabulary = char2num.get_vocabulary(), 
    mask_token = None, 
    invert = True,
    encoding = 'utf-8'
)

# %% [markdown]
# # Define the model

# %%
from tensorflow.keras.layers import Input, Dense, Bidirectional, GRU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
from ctc import CTCLayer
from cnn import custom_cnn, get_imagenet_model, reshape_for_cnn

# Pick a model from https://keras.io/api/applications
# imagenet_model = get_imagenet_model('VGG16', (HEIGHT, WIDTH, 1))
# imagenet_model.summary()
# imagenet_output_layer = 'block3_pool'

# %%
def build_and_compile_model(name, imagenet_model=None, imagenet_output_layer=None):
    label_input = Input(shape=(None,), dtype='int64', name='label')
    label_length = Input(shape=[1], dtype='int64', name='label_length')
    
    # CNN layers
    if imagenet_model: # Use Imagenet model as CNN layers
        image_input = imagenet_model.input
        imagenet_model.layers[0]._name = 'image'
        x = imagenet_model.get_layer(imagenet_output_layer).output
    else: 
        image_input = Input(shape=(HEIGHT, WIDTH, 1), dtype='float32', name='image')
        conv_blocks_config = {
            'block1': {'num_conv': 1, 'filters':  64, 'pool_size': (2, 2)}, 
            'block2': {'num_conv': 1, 'filters': 128, 'pool_size': (2, 2)}, 
            'block3': {'num_conv': 2, 'filters': 256, 'pool_size': (2, 2)}, 
            'block4': {'num_conv': 2, 'filters': 512, 'pool_size': (1, 2)}, 
        }
        x = custom_cnn(conv_blocks_config, image_input)
        
    # Reshape accordingly before passing the output to the RNN
    x = reshape_for_cnn(x, dim_to_keep=-1)

    # RNN layers
    bigru_layers = [512, 512]
    for idx in range(len(bigru_layers)):
        x = Bidirectional(GRU(
            units = bigru_layers[idx], 
            return_sequences = True, 
            dropout = 0.2,
        ), name = f'bigru{idx + 1}')(x)

    # Output layer
    y_pred = Dense(
        units = char2num.vocabulary_size() + 1, # + 1 blank character for CTC loss
        activation = 'softmax', 
        name = 'rnn_output'
    )(x)

    # Compile the model and return
    model = Model(
        inputs = [image_input, label_input, label_length], 
        outputs = CTCLayer()(label_input, y_pred, label_length), 
        name = name
    )
    model.compile(optimizer=Adam(learning_rate=2e-4))
    return model

# %% [markdown]
# # Training

# %%
from dataset_handler import process_one_image
MAX_LENGTH = max([len(label) for label in labels])
PADDING_TOKEN = char2num.vocabulary_size()
AUTOTUNE = tf.data.AUTOTUNE
BATCH_SIZE = 16

# %% [markdown]
# ## Callbacks

# %%
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from custom_callbacks import EditDistanceCallback, EarlyStoppingWithStuck
early_stopping_callback = EarlyStoppingWithStuck(patience=5)

def scheduler(epoch, lr):
    if epoch == 0 or (epoch % 10) > 0: return lr # Keeps lr for 10 epochs
    return lr * tf.math.exp(-0.2) # Decreases it exponentially after that
schedule_lr_callback = LearningRateScheduler(scheduler, verbose=1)

# Reduce the learning rate once learning stagnates
reduce_lr_callback = ReduceLROnPlateau(
    monitor = 'val_loss', 
    patience = 2, # Reduce if no improvement after 2 epochs
    min_delta = 0.001, # The val_loss should at least improve 0.001
    factor = 0.5, # => new_lr = lr * factor
    verbose = 1
)

# %% [markdown]
# ## Data input pipeline

# %%
def process_images_labels(img_path, label, img_size=(HEIGHT, WIDTH)):
    image = process_one_image(img_path, img_size)
    label = char2num(tf.strings.unicode_split(label, input_encoding='UTF-8'))
    label_length = tf.shape(label, tf.int64)[0]
    label = tf.pad(
        label, 
        paddings = [[0, MAX_LENGTH - label_length]], 
        constant_values = PADDING_TOKEN
    )
    return {'image': image, 'label': label, 'label_length': label_length}

# %%
def prepare_tf_dataset(img_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((img_paths, labels)).map(
        process_images_labels, num_parallel_calls=AUTOTUNE
    )
    return dataset.batch(BATCH_SIZE).cache().prefetch(AUTOTUNE)

# %% [markdown]
# ## Cross validation with K-Fold

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10, shuffle=True)
valid_datasets = []
best_epochs = []
edist_logs = []
histories = []
models = []

# %%
# %%time
for fold_idx, (train_idx, valid_idx) in enumerate(kfold.split(img_paths, labels)):
    train_tf_dataset = prepare_tf_dataset(img_paths[train_idx], labels[train_idx])
    valid_tf_dataset = prepare_tf_dataset(img_paths[valid_idx], labels[valid_idx])
    valid_datasets.append((valid_tf_dataset, valid_idx))
    
    model = build_and_compile_model(f'Model_{fold_idx + 1}')
#     model = build_and_compile_model(
#         f'Model_{fold_idx + 1}', 
#         imagenet_model, # Use Imagenet model as CNN layers
#         imagenet_output_layer
#     )

    edit_distance_callback = EditDistanceCallback(Model(
        inputs = model.get_layer('image').input, 
        outputs = model.get_layer('rnn_output').output
    ), valid_tf_dataset, MAX_LENGTH) 
    
    print(f'Start training for Fold {fold_idx + 1}:')
    history = model.fit(
        train_tf_dataset,
        validation_data = valid_tf_dataset,
        epochs = 100,
        callbacks = [
#             checkpoint_callback,
#             schedule_lr_callback, 
            reduce_lr_callback, 
            edit_distance_callback, 
            early_stopping_callback,
        ],
        verbose = 1
    )
    print(f'Finish training for Fold {fold_idx + 1}\n')
    best_epochs.append(early_stopping_callback.best_epoch)
    edist_logs.append(edit_distance_callback.logs)
    histories.append(history)
    models.append(model)
# Out:
# Start training for Fold 1:
# Epoch 1/100
# 163/163 [==============================] - ETA: 0s - loss: 51.4151 - Mean edit distance: 8.0
# 163/163 [==============================] - 14s 47ms/step - loss: 51.4151 - val_loss: 50.9760 - lr: 2.0000e-04
# Epoch 2/100
# 162/163 [============================>.] - ETA: 0s - loss: 46.1402 - Mean edit distance: 8.0
# 163/163 [==============================] - 5s 30ms/step - loss: 46.1575 - val_loss: 49.8372 - lr: 2.0000e-04
# Epoch 3/100
# 162/163 [============================>.] - ETA: 0s - loss: 38.2378 - Mean edit distance: 7.730263
# 163/163 [==============================] - 5s 30ms/step - loss: 38.2242 - val_loss: 37.2562 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 21.6978 - Mean edit distance: 4.680921
# 163/163 [==============================] - 5s 31ms/step - loss: 21.6824 - val_loss: 20.2460 - lr: 2.0000e-04
# Epoch 5/100
# 162/163 [============================>.] - ETA: 0s - loss: 11.3500 - Mean edit distance: 2.881579
# 163/163 [==============================] - 5s 30ms/step - loss: 11.3423 - val_loss: 11.5992 - lr: 2.0000e-04
# Epoch 6/100
# 163/163 [==============================] - ETA: 0s - loss: 6.0583 - Mean edit distance: 2.5953948
# 163/163 [==============================] - 5s 30ms/step - loss: 6.0583 - val_loss: 9.1657 - lr: 2.0000e-04
# Epoch 7/100
# 161/163 [============================>.] - ETA: 0s - loss: 3.3080 - Mean edit distance: 2.1578948
# 163/163 [==============================] - 5s 31ms/step - loss: 3.2986 - val_loss: 6.7403 - lr: 2.0000e-04
# Epoch 8/100
# 163/163 [==============================] - ETA: 0s - loss: 1.8639 - Mean edit distance: 1.7236842
# 163/163 [==============================] - 5s 30ms/step - loss: 1.8639 - val_loss: 4.7801 - lr: 2.0000e-04
# Epoch 9/100
# 161/163 [============================>.] - ETA: 0s - loss: 1.0207 - Mean edit distance: 1.6743422
# 163/163 [==============================] - 5s 30ms/step - loss: 1.0180 - val_loss: 4.2110 - lr: 2.0000e-04
# Epoch 10/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.5611 - Mean edit distance: 1.6677631
# 163/163 [==============================] - 5s 31ms/step - loss: 0.5599 - val_loss: 4.0313 - lr: 2.0000e-04
# Epoch 11/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.3456 - Mean edit distance: 1.5427631
# 163/163 [==============================] - 5s 32ms/step - loss: 0.3454 - val_loss: 3.2819 - lr: 2.0000e-04
# Epoch 12/100
# 161/163 [============================>.] - ETA: 0s - loss: 0
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0070 - val_loss: 2.1821 - lr: 1.2500e-05
# Epoch 59/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0069
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#  - Mean edit distance: 1.4407895
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0069 - val_loss: 2.1786 - lr: 1.2500e-05
# Epoch 60/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0069 - Mean edit distance: 1.4309211
# Restored weights from the end of epoch: 55
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0069 - val_loss: 2.1793 - lr: 6.2500e-06
# Epoch 60: early stopping
# Finish training for Fold 1
#
# Start training for Fold 2:
# Epoch 1/100
# 162/163 [============================>.] - ETA: 0s - loss: 50.9247 - Mean edit distance: 8.0
# 163/163 [==============================] - 11s 44ms/step - loss: 50.9374 - val_loss: 52.1917 - lr: 2.0000e-04
# Epoch 2/100
# 161/163 [============================>.] - ETA: 0s - loss: 44.9017 - Mean edit distance: 7.9736843
# 163/163 [==============================] - 5s 31ms/step - loss: 44.9080 - val_loss: 45.4594 - lr: 2.0000e-04
# Epoch 3/100
# 162/163 [============================>.] - ETA: 0s - loss: 40.2316 - Mean edit distance: 7.6907897
# 163/163 [==============================] - 5s 32ms/step - loss: 40.2377 - val_loss: 40.6165 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 34.7760 - Mean edit distance: 7.575658
# 163/163 [==============================] - 5s 33ms/step - loss: 34.7768 - val_loss: 38.5126 - lr: 2.0000e-04
# Epoch 5/100
# 161/163 [============================>.] - ETA: 0s - loss: 28.7634 - Mean edit distance: 7.105263
# 163/163 [==============================] - 5s 32ms/step - loss: 28.7524 - val_loss: 34.9611 - lr: 2.0000e-04
# Epoch 6/100
# 161/163 [============================>.] - ETA: 0s - loss: 23.1025 - Mean edit distance: 7.1151314
# 163/163 [==============================] - 5s 32ms/step - loss: 23.0953 - val_loss: 34.3687 - lr: 2.0000e-04
# Epoch 7/100
# 161/163 [============================>.] - ETA: 0s - loss: 18.1595 - Mean edit distance: 7.236842
# 163/163 [==============================] - 5s 32ms/step - loss: 18.1577 - val_loss: 38.2807 - lr: 2.0000e-04
# Epoch 8/100
# 161/163 [============================>.] - ETA: 0s - loss: 14.1388 - Mean edit distance: 6.2730265
# 163/163 [==============================] - 5s 31ms/step - loss: 14.1308 - val_loss: 29.3050 - lr: 2.0000e-04
# Epoch 9/100
# 162/163 [============================>.] - ETA: 0s - loss: 10.6167 - Mean edit distance: 6.0657897
# 163/163 [==============================] - 5s 32ms/step - loss: 10.6119 - val_loss: 27.7925 - lr: 2.0000e-04
# Epoch 10/100
# 162/163 [============================>.] - ETA: 0s - loss: 7.5321 - Mean edit distance: 5.8092103
# Restored weights from the end of epoch: 5
# 163/163 [==============================] - 5s 31ms/step - loss: 7.5267 - val_loss: 26.7556 - lr: 2.0000e-04
# Epoch 10: early stopping
# Finish training for Fold 2
#
# Start training for Fold 3:
# Epoch 1/100
# 161/163 [============================>.] - ETA: 0s - loss: 51.2154 - Mean edit distance: 7.986842
# 163/163 [==============================] - 11s 42ms/step - loss: 51.2242 - val_loss: 51.7178 - lr: 2.0000e-04
# Epoch 2/100
# 161/163 [============================>.] - ETA: 0s - loss: 45.3587 - Mean edit distance: 7.9342103
# Epoch 6/100
# 161/163 [============================>.] - ETA: 0s - loss: 20.9948 - Mean edit distance: 7.1480265
# 163/163 [==============================] - 5s 32ms/step - loss: 20.9871 - val_loss: 30.6022 - lr: 2.0000e-04
# Epoch 7/100
# 162/163 [============================>.] - ETA: 0s - loss: 15.9530 - Mean edit distance: 6.8651314
# 163/163 [==============================] - 5s 31ms/step - loss: 15.9506 - val_loss: 31.9895 - lr: 2.0000e-04
# Epoch 8/100
# 161/163 [============================>.] - ETA: 0s - loss: 11.8270
# Epoch 8: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#  - Mean edit distance: 6.7598686
# 163/163 [==============================] - 5s 31ms/step - loss: 11.8176 - val_loss: 32.0271 - lr: 2.0000e-04
# Epoch 9/100
# 161/163 [============================>.] - ETA: 0s - loss: 8.0720 - Mean edit distance: 5.667763
# 163/163 [==============================] - 5s 31ms/step - loss: 8.0762 - val_loss: 24.2961 - lr: 1.0000e-04
# Epoch 10/100
# 162/163 [============================>.] - ETA: 0s - loss: 5.7451 - Mean edit distance: 5.8157897
# 163/163 [==============================] - 5s 31ms/step - loss: 5.7461 - val_loss: 24.5754 - lr: 1.0000e-04
# Epoch 11/100
# 161/163 [============================>.] - ETA: 0s - loss: 4.2161 - Mean edit distance: 5.6480265
# Restored weights from the end of epoch: 6
# 163/163 [==============================] - 5s 31ms/step - loss: 4.2186 - val_loss: 23.1948 - lr: 1.0000e-04
# Epoch 11: early stopping
# Finish training for Fold 4
#
# Start training for Fold 5:
# Epoch 1/100
# 161/163 [============================>.] - ETA: 0s - loss: 50.8883 - Mean edit distance: 7.9901314
# 163/163 [==============================] - 12s 46ms/step - loss: 50.8966 - val_loss: 52.2480 - lr: 2.0000e-04
# Epoch 2/100
# 162/163 [============================>.] - ETA: 0s - loss: 45.1237 - Mean edit distance: 7.9967103
# 163/163 [==============================] - 5s 32ms/step - loss: 45.1408 - val_loss: 46.8731 - lr: 2.0000e-04
# Epoch 3/100
# 162/163 [============================>.] - ETA: 0s - loss: 40.9642 - Mean edit distance: 7.9013157
# 163/163 [==============================] - 5s 33ms/step - loss: 40.9752 - val_loss: 43.4107 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 36.0666 - Mean edit distance: 7.8026314
# 163/163 [==============================] - 5s 33ms/step - loss: 36.0708 - val_loss: 42.7873 - lr: 2.0000e-04
# Epoch 5/100
# 162/163 [============================>.] - ETA: 0s - loss: 30.6096 - Mean edit distance: 7.4703946
# 163/163 [==============================] - 5s 32ms/step - loss: 30.6103 - val_loss: 38.7151 - lr: 2.0000e-04
# Epoch 6/100
# 161/163 [============================>.] - ETA: 0s - loss: 25.1317 - Mean edit distance: 7.1019735
# 163/163 [==============================] - 5s 33ms/step - loss: 25.1250 - val_loss: 36.2129 - lr: 2.0000e-04
# Epoch 7/100
# 162/163 [============================>.] - ETA: 0s - loss: 20.2155 - Mean edit distance: 7.3486843
# 163/163 [==============================] - 5s 32ms/step - loss: 20.2146 - val_loss: 37.6268 - lr: 2.0000e-04
# Epoch 8/100
# 161/163 [============================>.] - ETA: 0s - loss: 15.9717 - Mean edit distance: 7.1710525
# 163/163 [==============================] - 5s 33ms/step - loss: 15.9556 - val_loss: 34.5247 - lr: 2.0000e-04
# Epoch 9/100
# 162/163 [============================>.] - ETA: 0s - loss: 12.1863 - Mean edit distance: 6.4736843
# 163/163 [==============================] - 5s 32ms/step - loss: 12.1806 - val_loss: 31.8843 - lr: 2.0000e-04
# Epoch 10/100
# 161/163 [============================>.] - ETA: 0s - loss: 8.8928 - Mean edit distance: 6.200658
# Restored weights from the end of epoch: 5
# 163/163 [==============================] - 5s 32ms/step - loss: 8.8854 - val_loss: 28.7004 - lr: 2.0000e-04
# Epoch 10: early stopping
# Finish training for Fold 5
#
# Start training for Fold 6:
# Epoch 1/100
# 162/163 [============================>.] - ETA: 0s - loss: 50.9056 - Mean edit distance: 8.0
# 163/163 [==============================] - 12s 46ms/step - loss: 50.9228 - val_loss: 53.1247 - lr: 2.0000e-04
# Epoch 2/100
# 162/163 [============================>.] - ETA: 0s - loss: 45.0653 - Mean edit distance: 7.986842
# 163/163 [==============================] - 5s 32ms/step - loss: 45.0867 - val_loss: 47.3015 - lr: 2.0000e-04
# Epoch 3/100
# 162/163 [============================>.] - ETA: 0s - loss: 40.8024 - Mean edit distance: 7.825658
# 163/163 [==============================] - 5s 33ms/step - loss: 40.8164 - val_loss: 42.6839 - lr: 2.0000e-04
# Epoch 4/100
# 161/163 [============================>.] - ETA: 0s - loss: 35.6900 - Mean edit distance: 7.7236843
# 163/163 [==============================] - 5s 33ms/step - loss: 35.6801 - val_loss: 40.7858 - lr: 2.0000e-04
# Epoch 5/100
# 161/163 [============================>.] - ETA: 0s - loss: 29.7948 - Mean edit distance: 7.2796054
# 163/163 [==============================] - 5s 32ms/step - loss: 29.7817 - val_loss: 36.7678 - lr: 2.0000e-04
# Epoch 6/100
# 162/163 [============================>.] - ETA: 0s - loss: 24.0756 - Mean edit distance: 7.2894735
# 163/163 [==============================] - 5s 31ms/step - loss: 24.0741 - val_loss: 37.1291 - lr: 2.0000e-04
# Epoch 7/100
# 161/163 [============================>.] - ETA: 0s - loss: 19.0754
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
#  - Mean edit distance: 7.3092103
# 163/163 [==============================] - 5s 31ms/step - loss: 19.0668 - val_loss: 38.2384 - lr: 2.0000e-04
# Epoch 8/100
# 163/163 [==============================] - ETA: 0s - loss: 14.3600 - Mean edit distance: 6.450658
# 163/163 [==============================] - 5s 31ms/step - loss: 14.3600 - val_loss: 28.8682 - lr: 1.0000e-04
# Epoch 9/100
# 162/163 [============================>.] - ETA: 0s - loss: 11.0215 - Mean edit distance: 6.0953946
# 163/163 [==============================] - 5s 31ms/step - loss: 11.0213 - val_loss: 27.2420 - lr: 1.0000e-04
# Epoch 10/100
# 162/163 [============================>.] - ETA: 0s - loss: 8.4717 - Mean edit distance: 6.0
# Restored weights from the end of epoch: 5
# 163/163 [==============================] - 5s 31ms/step - loss: 8.4718 - val_loss: 26.9199 - lr: 1.0000e-04
# Epoch 10: early stopping
100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0162 - Mean edit distance: 1.4967105
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0162 - val_loss: 2.5582 - lr: 1.0000e-04
# Epoch 61/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0152 - Mean edit distance: 1.5098684
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0152 - val_loss: 2.5558 - lr: 1.0000e-04
# Epoch 62/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0141 - Mean edit distance: 1.4835526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0141 - val_loss: 2.5490 - lr: 1.0000e-04
# Epoch 63/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0133 - Mean edit distance: 1.4901316
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0133 - val_loss: 2.5427 - lr: 1.0000e-04
# Epoch 64/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0125 - Mean edit distance: 1.4802631
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0125 - val_loss: 2.5346 - lr: 1.0000e-04
# Epoch 65/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0117 - Mean edit distance: 1.4868422
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0117 - val_loss: 2.5397 - lr: 1.0000e-04
# Epoch 66/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0112 - Mean edit distance: 1.4868422
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0112 - val_loss: 2.5286 - lr: 1.0000e-04
# Epoch 67/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0105 - Mean edit distance: 1.4868422
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0105 - val_loss: 2.5189 - lr: 1.0000e-04
# Epoch 68/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0100 - Mean edit distance: 1.4967105
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0100 - val_loss: 2.5294 - lr: 1.0000e-04
# Epoch 69/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0094 - Mean edit distance: 1.4736842
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0094 - val_loss: 2.5102 - lr: 1.0000e-04
# Epoch 70/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0089 - Mean edit distance: 1.4703947
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0089 - val_loss: 2.5098 - lr: 1.0000e-04
# Epoch 71/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0085 - Mean edit distance: 1.4703947
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0085 - val_loss: 2.5092 - lr: 1.0000e-04
# Epoch 72/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0081 - Mean edit distance: 1.4802631
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0081 - val_loss: 2.5026 - lr: 1.0000e-04
# Epoch 73/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0077 - Mean edit distance: 1.4671053
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0077 - val_loss: 2.4891 - lr: 1.0000e-04
# Epoch 74/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0073 - Mean edit distance: 1.4638158
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0073 - val_loss: 2.4931 - lr: 1.0000e-04
# Epoch 75/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0070
# Epoch 75: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#  - Mean edit distance: 1.4638158
# 163/163 [==============================] - 5s 33ms/step - loss: 0.0070 - val_loss: 2.4942 - lr: 1.0000e-04
# Epoch 76/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0067 - Mean edit distance: 1.4473684
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0067 - val_loss: 2.4881 - lr: 5.0000e-05
# Epoch 77/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0065
# Epoch 77: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  - Mean edit distance: 1.4572369
# 163/163 [==============================] - 5s 32ms/step - loss: 0.0065 - val_loss: 2.4988 - lr: 5.0000e-05
# Epoch 78/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0064 - Mean edit distance: 1.4539474
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0064 - val_loss: 2.4971 - lr: 2.5000e-05
# Epoch 79/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0063
# Epoch 79: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  - Mean edit distance: 1.4506578
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0063 - val_loss: 2.4928 - lr: 2.5000e-05
# Epoch 80/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0062 - Mean edit distance: 1.4506578
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0062 - val_loss: 2.4965 - lr: 1.2500e-05
# Epoch 81/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0062
# Epoch 81: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#  - Mean edit distance: 1.4506578
# Restored weights from the end of epoch: 76
# 163/163 [==============================] - 5s 31ms/step - loss: 0.
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0114 - val_loss: 2.1848 - lr: 5.0000e-05
# Epoch 41/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0111
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#  - Mean edit distance: 1.6118422
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0111 - val_loss: 2.2038 - lr: 5.0000e-05
# Epoch 42/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0109 - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0109 - val_loss: 2.1867 - lr: 2.5000e-05
# Epoch 43/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0107 - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0107 - val_loss: 2.1812 - lr: 2.5000e-05
# Epoch 44/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0106 - Mean edit distance: 1.6019737
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0106 - val_loss: 2.1715 - lr: 2.5000e-05
# Epoch 45/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0105 - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0105 - val_loss: 2.1730 - lr: 2.5000e-05
# Epoch 46/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0103
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#  - Mean edit distance: 1.6019737
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0103 - val_loss: 2.1850 - lr: 2.5000e-05
# Epoch 47/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0102 - Mean edit distance: 1.6118422
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0102 - val_loss: 2.1688 - lr: 1.2500e-05
# Epoch 48/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0100 - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0100 - val_loss: 2.1733 - lr: 1.2500e-05
# Epoch 49/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0099 - Mean edit distance: 1.6052631
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0099 - val_loss: 2.1603 - lr: 1.2500e-05
# Epoch 50/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0098 - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0098 - val_loss: 2.1636 - lr: 1.2500e-05
# Epoch 51/100
# 162/163 [============================>.] - ETA: 0s - loss: 0.0097
# Epoch 51: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#  - Mean edit distance: 1.6085526
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0097 - val_loss: 2.1628 - lr: 1.2500e-05
# Epoch 52/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0096 - Mean edit distance: 1.6151316
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0096 - val_loss: 2.1632 - lr: 6.2500e-06
# Epoch 53/100
# 161/163 [============================>.] - ETA: 0s - loss: 0.0096
# Epoch 53: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
#  - Mean edit distance: 1.6151316
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0096 - val_loss: 2.1608 - lr: 6.2500e-06
# Epoch 54/100
# 163/163 [==============================] - ETA: 0s - loss: 0.0095 - Mean edit distance: 1.6184211
# Restored weights from the end of epoch: 49
# 163/163 [==============================] - 5s 31ms/step - loss: 0.0095 - val_loss: 2.1753 - lr: 3.1250e-06
# Epoch 54: early stopping
# Finish training for Fold 8
#
# Start training for Fold 9:
# Epoch 1/100
# 163/163 [==============================] - ETA: 0s - loss: 50.7271 - Mean edit distance: 7.9769735
# 163/163 [==============================] - 11s 43ms/step - loss: 50.7271 - val_loss: 60.0180 - lr: 2.0000e-04
# Epoch 2/100
# 161/163 [============================>.] - ETA: 0s - loss: 44.8395 - Mean edit distance: 7.9144735
# 163/163 [==============================] - 5s 31ms/step - loss: 44.8530 - val_loss: 46.9758 - lr: 2.0000e-04
# Epoch 3/100
# 163/163 [==============================] - ETA: 0s - loss: 40.3878 - Mean edit distance: 7.7203946
# 163/163 [==============================] - 5s 31ms/step - loss: 40.3878 - val_loss: 42.7472 - lr: 2.0000e-04
# Epoch 4/100
# 162/163 [============================>.] - ETA: 0s - loss: 35.2146 - Mean edit distance: 7.6644735
# 163/163 [==============================] - 5s 31ms/step - loss: 35.2254 - val_loss: 40.5048 - lr: 2.0000e-04
# Epoch 5/100
# 161/163 [============================>.] - ETA: 0s - loss: 29.5381 - Mean edit distance: 7.2171054
# Epoch 9/100
# 162/163 [============================>.] - ETA: 0s - loss: 12.1779 - Mean edit distance: 6.5104165
# 163/163 [==============================] - 5s 31ms/step - loss: 12.1723 - val_loss: 31.3598 - lr: 2.0000e-04
# Epoch 10/100
# 163/163 [==============================] - ETA: 0s - loss: 8.7129 - Mean edit distance: 6.2152777
# Restored weights from the end of epoch: 5
# 163/163 [==============================] - 5s 32ms/step - loss: 8.7129 - val_loss: 30.4159 - lr: 2.0000e-04
# Epoch 10: early stopping
# Finish training for Fold 10
#
# Wall time: 24min 2s

# %% [markdown]
# ## Get the best CRNN model and its results

# %%
best_loss = float('inf')
for fold_idx, model in enumerate(models):
    final_edist = edist_logs[fold_idx][best_epochs[fold_idx]]
    print(f'Fold {fold_idx + 1:02d} - Mean edit distance: {final_edist}')
    final_val_loss = model.evaluate(valid_datasets[fold_idx][0], verbose=1)
    if final_val_loss < best_loss:
        best_loss = final_val_loss
        best_fold_idx = fold_idx
# Out:
# Fold 01 - Mean edit distance: 1.4276316165924072
# 19/19 [==============================] - 0s 13ms/step - loss: 2.1651
# Fold 02 - Mean edit distance: 7.1052632331848145
# 19/19 [==============================] - 0s 13ms/step - loss: 34.9611
# Fold 03 - Mean edit distance: 7.648026466369629
# 19/19 [==============================] - 0s 13ms/step - loss: 39.3581
# Fold 04 - Mean edit distance: 7.148026466369629
# 19/19 [==============================] - 0s 13ms/step - loss: 30.6022
# Fold 05 - Mean edit distance: 7.470394611358643
# 19/19 [==============================] - 0s 13ms/step - loss: 38.7151
# Fold 06 - Mean edit distance: 7.279605388641357
# 19/19 [==============================] - 0s 13ms/step - loss: 36.7678
# Fold 07 - Mean edit distance: 1.4473683834075928
# 19/19 [==============================] - 0s 12ms/step - loss: 2.4881
# Fold 08 - Mean edit distance: 1.605263113975525
# 19/19 [==============================] - 0s 13ms/step - loss: 2.1603
# Fold 09 - Mean edit distance: 7.217105388641357
# 19/19 [==============================] - 0s 13ms/step - loss: 37.3709
# Fold 10 - Mean edit distance: 7.5625
# 18/18 [==============================] - 0s 13ms/step - loss: 40.9990

# %%
best_model = models[best_fold_idx]
best_model.save('crnn_trdg.h5')
best_model.summary()
# Out:
# Model: "Model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 148, 32, 1)  0           []
#                                 ]
#
#  block1_conv1 (Conv2D)          (None, 148, 32, 64)  640         ['image[0][0]']
#
#  block1_bn1 (BatchNormalization  (None, 148, 32, 64)  256        ['block1_conv1[0][0]']
#  )
#
#  block1_activation1 (LeakyReLU)  (None, 148, 32, 64)  0          ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)     (None, 74, 16, 64)   0           ['block1_activation1[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 74, 16, 128)  73856       ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization  (None, 74, 16, 128)  512        ['block2_conv1[0][0]']
#  )
#
#  block2_activation1 (LeakyReLU)  (None, 74, 16, 128)  0          ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 37, 8, 128)   0           ['block2_activation1[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 37, 8, 256)   295168      ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization  (None, 37, 8, 256)  1024        ['block3_conv1[0][0]']
#  )
#
#  block3_activation1 (LeakyReLU)  (None, 37, 8, 256)  0           ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 37, 8, 256)   590080      ['block3_activation1[0][0]']
#
#  block3_bn2 (BatchNormalization  (None, 37, 8, 256)  1024        ['block3_conv2[0][0]']
#  )
#
#  block3_activation2 (LeakyReLU)  (None, 37, 8, 256)  0           ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 18, 4, 256)   0           ['block3_activation2[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 18, 4, 512)   1180160     ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization  (None, 18, 4, 512)  2048        ['block4_conv1[0][0]']
#  )
#
#  block4_activation1 (LeakyReLU)  (None, 18, 4, 512)  0           ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 18, 4, 512)   2359808     ['block4_activation1[0][0]']
#
#  block4_bn2 (BatchNormalization  (None, 18, 4, 512)  2048        ['block4_conv2[0][0]']
#  )
#
#  block4_activation2 (LeakyReLU)  (None, 18, 4, 512)  0           ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 18, 2, 512)   0           ['block4_activation2[0][0]']
#
#  final_conv (Conv2D)            (None, 17, 1, 512)   1049088     ['block4_pool[0][0]']
#
#  final_bn (BatchNormalization)  (None, 17, 1, 512)   2048        ['final_conv[0][0]']
#
#  final_activation (LeakyReLU)   (None, 17, 1, 512)   0           ['final_bn[0][0]']
#
#  rnn_input (Reshape)            (None, 17, 512)      0           ['final_activation[0][0]']
#
#  bigru1 (Bidirectional)         (None, 17, 1024)     3151872     ['rnn_input[0][0]']
#
#  bigru2 (Bidirectional)         (None, 17, 1024)     4724736     ['bigru1[0][0]']
#
#  label (InputLayer)             [(None, None)]       0           []
#
#  rnn_output (Dense)             (None, 17, 1699)     1741475     ['bigru2[0][0]']
#
#  label_length (InputLayer)      [(None, 1)]          0           []
#
#  ctc_loss (CTCLayer)            (None, 17, 1699)     0           ['label[0][0]',
#                                                                   'rnn_output[0][0]',
#                                                                   'label_length[0][0]']
#
# ==================================================================================================
# Total params: 15,175,843
# Trainable params: 15,171,363
# Non-trainable params: 4,480
# __________________________________________________________________________________________________

# %%
from visualizer import plot_training_results
plot_training_results(
    histories[best_fold_idx], 
    edist_logs[best_fold_idx], 
    save_name = 'crnn_trdg_history.png'
)

# %% [markdown]
# # Inference

# %%
from tensorflow.keras.models import Model, load_model
from ctc import CTCLayer, decode_batch_predictions
best_valid_dataset = valid_datasets[best_fold_idx][0]
best_valid_idxs = valid_datasets[best_fold_idx][1]

# %% [markdown]
# ## Reload the model

# %%
reloaded_model = load_model('crnn_trdg.h5', custom_objects={'CTCLayer': CTCLayer})
reloaded_prediction_model = Model(
    inputs = reloaded_model.get_layer('image').input, 
    outputs = reloaded_model.get_layer('rnn_output').output
)
reloaded_model.summary(line_length=100)
# Out:
# Model: "Model_8"
# ____________________________________________________________________________________________________
#  Layer (type)                    Output Shape          Param #     Connected to
# ====================================================================================================
#  image (InputLayer)              [(None, 148, 32, 1)]  0           []
#
#  block1_conv1 (Conv2D)           (None, 148, 32, 64)   640         ['image[0][0]']
#
#  block1_bn1 (BatchNormalization)  (None, 148, 32, 64)  256         ['block1_conv1[0][0]']
#
#  block1_activation1 (LeakyReLU)  (None, 148, 32, 64)   0           ['block1_bn1[0][0]']
#
#  block1_pool (MaxPooling2D)      (None, 74, 16, 64)    0           ['block1_activation1[0][0]']
#
#  block2_conv1 (Conv2D)           (None, 74, 16, 128)   73856       ['block1_pool[0][0]']
#
#  block2_bn1 (BatchNormalization)  (None, 74, 16, 128)  512         ['block2_conv1[0][0]']
#
#  block2_activation1 (LeakyReLU)  (None, 74, 16, 128)   0           ['block2_bn1[0][0]']
#
#  block2_pool (MaxPooling2D)      (None, 37, 8, 128)    0           ['block2_activation1[0][0]']
#
#  block3_conv1 (Conv2D)           (None, 37, 8, 256)    295168      ['block2_pool[0][0]']
#
#  block3_bn1 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv1[0][0]']
#
#  block3_activation1 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn1[0][0]']
#
#  block3_conv2 (Conv2D)           (None, 37, 8, 256)    590080      ['block3_activation1[0][0]']
#
#  block3_bn2 (BatchNormalization)  (None, 37, 8, 256)   1024        ['block3_conv2[0][0]']
#
#  block3_activation2 (LeakyReLU)  (None, 37, 8, 256)    0           ['block3_bn2[0][0]']
#
#  block3_pool (MaxPooling2D)      (None, 18, 4, 256)    0           ['block3_activation2[0][0]']
#
#  block4_conv1 (Conv2D)           (None, 18, 4, 512)    1180160     ['block3_pool[0][0]']
#
#  block4_bn1 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv1[0][0]']
#
#  block4_activation1 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn1[0][0]']
#
#  block4_conv2 (Conv2D)           (None, 18, 4, 512)    2359808     ['block4_activation1[0][0]']
#
#  block4_bn2 (BatchNormalization)  (None, 18, 4, 512)   2048        ['block4_conv2[0][0]']
#
#  block4_activation2 (LeakyReLU)  (None, 18, 4, 512)    0           ['block4_bn2[0][0]']
#
#  block4_pool (MaxPooling2D)      (None, 18, 2, 512)    0           ['block4_activation2[0][0]']
#
#  final_conv (Conv2D)             (None, 17, 1, 512)    1049088     ['block4_pool[0][0]']
#
#  final_bn (BatchNormalization)   (None, 17, 1, 512)    2048        ['final_conv[0][0]']
#
#  final_activation (LeakyReLU)    (None, 17, 1, 512)    0           ['final_bn[0][0]']
#
#  rnn_input (Reshape)             (None, 17, 512)       0           ['final_activation[0][0]']
#
#  bigru1 (Bidirectional)          (None, 17, 1024)      3151872     ['rnn_input[0][0]']
#
#  bigru2 (Bidirectional)          (None, 17, 1024)      4724736     ['bigru1[0][0]']
#
#  label (InputLayer)              [(None, None)]        0           []
#
#  label_length (InputLayer)       [(None, 1)]           0           []
#
#  rnn_output (Dense)              (None, 17, 1699)      1741475     ['bigru2[0][0]']
#
#  ctc_loss (CTCLayer)             (None, 17, 1699)      0           ['label[0][0]',
#                                                                     'label_length[0][0]',
#                                                                     'rnn_output[0][0]']
#
# ====================================================================================================
# Total params: 15,175,843
# Trainable params: 15,171,363
# Non-trainable params: 4,480
# ____________________________________________________________________________________________________

# %% [markdown]
# ## On test dataset

# %%
from importlib import reload
import visualizer
reload(visualizer)
from visualizer import visualize_images_labels

# %%
for idx, batch in enumerate(best_valid_dataset.take(2)):
    batch_images, batch_labels = batch['image'], batch['label']
    valid_idxs = best_valid_idxs[idx * BATCH_SIZE: (idx + 1) * BATCH_SIZE]
    valid_labels = []
    
    for label in batch_labels:
        # Gather indices where label != padding_token.
        not_padding = tf.math.not_equal(label, PADDING_TOKEN)
        indices = tf.gather(label, tf.where(not_padding))
        label = tf.strings.reduce_join(num2char(indices)) # Convert to string
        valid_labels.append(label.numpy().decode('utf-8'))
        
    preds = reloaded_prediction_model.predict(batch_images)
    pred_labels = decode_batch_predictions(preds, MAX_LENGTH, 20, num2char)
    visualize_images_labels(
        img_paths = img_paths[valid_idxs], 
        labels = valid_labels, 
        pred_labels = pred_labels,
        font_path = FONT_PATH, 
        text_x = WIDTH + 3 # Position of actual label to plot
    )
    print(f'Batch {idx + 1}: {valid_labels}\n')
# Out:
# Batch 1: ['㐌停𥒥\U000f07ba鐄派', '㐌空朱﨤𣇜頭辰傕', '㗂嬌同望䏾襜𢠩恾', '㗂寃㐌悶拍𡗶呌𨖲', '㝵𠸗縸案苔𠫾', '㝵𡢐別固﨤堆庒\U000f047c', '㤕娘群拙双親', '䀡耒吏遣𢚸恒㤕車', '䜹浪碎分女兒', '䜹茹萱歇每情', '不情浽陣𩄲湄', '主東𦋦塊園春', '丿\U000f0993𠫾﨤信茄\U000f0742书', '云仙䜹訴每塘𧵆賖', '交朱囯状默筭法刑', '仍𢜠特准安身']
#
# Batch 2: ['仍\U000f047c煩悶𣎀𣈜', '仙浪各注迻些', '仙浪拠事爫牢', '仙浪翁舘渚唭', '会尼\U000f0778及群除会芇', '信春兜易𠫾𧗱朱能', '倍傍𦲿用花淶', '催催妾㐌負払自低', '傷台身分落類', '傷\U000f047c傷\U000f124e圣人', '六公欺𧘇買信事情', '六翁渃𬑉𣻆淶', '共𥪞\U000f070b㗂絲同', '其心户束拱𣳔書香', '其饒交𥛉\U000f070b茹', '判浪朕𢜝渃畨']

# %% [markdown]
# ## On random image

# %%
random_image = process_images_labels('../大越史記全書.jpg', '大越史記全書')
batch_images = tf.expand_dims(random_image['image'], axis=0)
batch_labels = tf.expand_dims(random_image['label'], axis=0)

# %%
preds = reloaded_prediction_model.predict(batch_images)
pred_labels = decode_batch_predictions(preds, MAX_LENGTH, 20, num2char)
visualize_images_labels(
    img_paths = [random_path], 
    labels = [random_label], 
    pred_labels = pred_labels,
    figsize = (5, 4),
    subplot_size = (1, 1), 
    show_legend = False,
    font_path = FONT_PATH, 
    text_x = WIDTH + 3 # Position of actual label to plot
)
print('Predicted text:', ''.join(pred_labels))
# Out:
# Predicted text: 大越史記玉書
